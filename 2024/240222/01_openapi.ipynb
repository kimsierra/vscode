# %%
import requests

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 3.5 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ---------------------------------------- 163.8/163.8 kB 5.0 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB ? eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB ? eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 requests-2.31.0 urllib3-2.2.1

# %%
## 웹서버에 요청을 보낸다
## get방식을 이용한 요청을 보낸다.
url = "https://www.google.com"

response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
## api주소
url = "http://172.16.12.155:8080/corona"
## 해당하는 주소에서 필수적으로 보내야되는 요청 변수
_params = {
    'serviceKey': 'aaa',
    '_limit' : 50
}
response = requests.get(
    url,
    params = _params
)

# %%
url2 = "http://172.16.12.155:8080/corona?serviceKey=aaa&_limit=50"

response2 = requests.get(url2)

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# [
#   {
#     "MyUnknownColumn": 0,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-08 09:09:05.982",
#     "deathCnt": 24305,
#     "decideCnt": 18188200,
#     "seq": 904,
#     "stateDt": 20220608,
#     "stateTime": "00:00",
#     "updateDt": null
#   },
#   {
#     "MyUnknownColumn": 1,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-07 09:09:00.897",
#     "deathCnt": 24299,
#     "decideCnt": 18174842,
#     "seq": 903,
#     "stateDt": 20220607,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-08 09:10:36.846"
#   },
#   {
#     "MyUnknownColumn": 2,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-06 09:00:06.734",
#     "deathCnt": 24279,
#     "decideCnt": 18168670,
#     "seq": 902,
#     "stateDt": 20220606,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-08 09:10:50.441"
#   },
#   {
#     "MyUnknownColumn": 3,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-05 08:53:19.426",
#     "deathCnt": 24258,
#     "decideCnt": 18163648,
#     "seq": 901,
#     "stateDt": 20220605,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-08 09:11:04.758"
#   },
#   {
#     "MyUnknownColumn": 4,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-04 08:56:49.219",
#     "deathCnt": 24238,
#     "decideCnt": 18153814,
#     "seq": 900,
#     "stateDt": 20220604,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-08 09:11:26.303"
#   },
#   {
#     "MyUnknownColumn": 5,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-03 09:08:18.729",
#     "deathCnt": 24229,
#     "decideCnt": 18141775,
#     "seq": 899,
#     "stateDt": 20220603,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-08 09:11:38.938"
#   },
#   {
#     "MyUnknownColumn": 6,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-02 08:58:19.746",
#     "deathCnt": 24212,
#     "decideCnt": 18129236,
#     "seq": 898,
#     "stateDt": 20220602,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-08 09:11:51.985"
#   },
#   {
#     "MyUnknownColumn": 7,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-06-01 09:07:30.461",
#     "deathCnt": 24197,
#     "decideCnt": 18119345,
#     "seq": 897,
#     "stateDt": 20220601,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-08 09:12:05.316"
#   },
#   {
#     "MyUnknownColumn": 8,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-31 08:55:39.977",
#     "deathCnt": 24176,
#     "decideCnt": 18103577,
#     "seq": 896,
#     "stateDt": 20220531,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-04 08:59:23.637"
#   },
#   {
#     "MyUnknownColumn": 9,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-30 09:01:30.847",
#     "deathCnt": 24167,
#     "decideCnt": 18086392,
#     "seq": 895,
#     "stateDt": 20220530,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-04 08:59:37.203"
#   },
#   {
#     "MyUnknownColumn": 10,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-29 09:05:28.382",
#     "deathCnt": 24158,
#     "decideCnt": 18080257,
#     "seq": 894,
#     "stateDt": 20220529,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-04 08:59:51.863"
#   },
#   {
#     "MyUnknownColumn": 11,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-28 09:09:18.909",
#     "deathCnt": 24139,
#     "decideCnt": 18067610,
#     "seq": 893,
#     "stateDt": 20220528,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-04 09:00:06.316"
#   },
#   {
#     "MyUnknownColumn": 12,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-27 09:03:34.444",
#     "deathCnt": 24103,
#     "decideCnt": 18053236,
#     "seq": 892,
#     "stateDt": 20220527,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-03 09:11:10.578"
#   },
#   {
#     "MyUnknownColumn": 13,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-26 09:13:37.732",
#     "deathCnt": 24063,
#     "decideCnt": 18036664,
#     "seq": 891,
#     "stateDt": 20220526,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-01 09:08:19.164"
#   },
#   {
#     "MyUnknownColumn": 14,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-25 09:02:44.294",
#     "deathCnt": 24029,
#     "decideCnt": 18017859,
#     "seq": 890,
#     "stateDt": 20220525,
#     "stateTime": "00:00",
#     "updateDt": "2022-06-01 09:08:25.254"
#   },
#   {
#     "MyUnknownColumn": 15,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-24 08:49:38.261",
#     "deathCnt": 24006,
#     "decideCnt": 17993923,
#     "seq": 889,
#     "stateDt": 20220524,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-31 08:58:44.451"
#   },
#   {
#     "MyUnknownColumn": 16,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-23 08:56:56.412",
#     "deathCnt": 23987,
#     "decideCnt": 17967592,
#     "seq": 888,
#     "stateDt": 20220523,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-28 09:10:13.674"
#   },
#   {
#     "MyUnknownColumn": 17,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-22 07:52:40.527",
#     "deathCnt": 23965,
#     "decideCnt": 17957621,
#     "seq": 887,
#     "stateDt": 20220522,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-28 09:10:20.33"
#   },
#   {
#     "MyUnknownColumn": 18,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-21 08:39:51.786",
#     "deathCnt": 23911,
#     "decideCnt": 17938332,
#     "seq": 886,
#     "stateDt": 20220521,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-28 09:10:27.211"
#   },
#   {
#     "MyUnknownColumn": 19,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-20 09:02:54.987",
#     "deathCnt": 23885,
#     "decideCnt": 17914882,
#     "seq": 885,
#     "stateDt": 20220520,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-27 09:04:41.621"
#   },
#   {
#     "MyUnknownColumn": 20,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-19 09:07:11.841",
#     "deathCnt": 23842,
#     "decideCnt": 17889769,
#     "seq": 884,
#     "stateDt": 20220519,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-26 09:16:54.036"
#   },
#   {
#     "MyUnknownColumn": 21,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-18 08:58:30.377",
#     "deathCnt": 23802,
#     "decideCnt": 17861660,
#     "seq": 883,
#     "stateDt": 20220518,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-25 09:05:49.683"
#   },
#   {
#     "MyUnknownColumn": 22,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-17 09:04:52.287",
#     "deathCnt": 23771,
#     "decideCnt": 17830327,
#     "seq": 882,
#     "stateDt": 20220517,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-24 09:18:48.656"
#   },
#   {
#     "MyUnknownColumn": 23,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-16 09:04:43.174",
#     "deathCnt": 23744,
#     "decideCnt": 17795242,
#     "seq": 881,
#     "stateDt": 20220516,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-21 08:47:40.875"
#   },
#   {
#     "MyUnknownColumn": 24,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-15 09:27:15.538",
#     "deathCnt": 23709,
#     "decideCnt": 17781952,
#     "seq": 880,
#     "stateDt": 20220515,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-21 08:47:54.484"
#   },
#   {
#     "MyUnknownColumn": 25,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-14 09:46:39.377",
#     "deathCnt": 23661,
#     "decideCnt": 17756527,
#     "seq": 879,
#     "stateDt": 20220514,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-21 08:48:13.125"
#   },
#   {
#     "MyUnknownColumn": 26,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-13 09:09:51.89",
#     "deathCnt": 23606,
#     "decideCnt": 17726955,
#     "seq": 878,
#     "stateDt": 20220513,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-20 09:06:42.817"
#   },
#   {
#     "MyUnknownColumn": 27,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-12 09:05:26.458",
#     "deathCnt": 23554,
#     "decideCnt": 17694520,
#     "seq": 877,
#     "stateDt": 20220512,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-19 17:37:18.336"
#   },
#   {
#     "MyUnknownColumn": 28,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-11 09:01:52.873",
#     "deathCnt": 23491,
#     "decideCnt": 17658638,
#     "seq": 876,
#     "stateDt": 20220511,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-19 17:38:10.681"
#   },
#   {
#     "MyUnknownColumn": 29,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-10 09:02:38.129",
#     "deathCnt": 23462,
#     "decideCnt": 17614757,
#     "seq": 875,
#     "stateDt": 20220510,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-17 09:06:40.689"
#   },
#   {
#     "MyUnknownColumn": 30,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-09 09:06:19.774",
#     "deathCnt": 23400,
#     "decideCnt": 17564861,
#     "seq": 874,
#     "stateDt": 20220509,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-14 10:34:58.518"
#   },
#   {
#     "MyUnknownColumn": 31,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-08 09:02:00.163",
#     "deathCnt": 23360,
#     "decideCnt": 17544273,
#     "seq": 873,
#     "stateDt": 20220508,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-14 10:35:16.208"
#   },
#   {
#     "MyUnknownColumn": 32,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-07 09:18:40.439",
#     "deathCnt": 23289,
#     "decideCnt": 17504225,
#     "seq": 872,
#     "stateDt": 20220507,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-14 10:35:34.039"
#   },
#   {
#     "MyUnknownColumn": 33,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-06 08:06:00.523",
#     "deathCnt": 23206,
#     "decideCnt": 17464662,
#     "seq": 871,
#     "stateDt": 20220506,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-13 09:11:27.572"
#   },
#   {
#     "MyUnknownColumn": 34,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-05 09:23:43.381",
#     "deathCnt": 23158,
#     "decideCnt": 17437984,
#     "seq": 870,
#     "stateDt": 20220505,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-12 09:06:57.564"
#   },
#   {
#     "MyUnknownColumn": 35,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-04 09:11:34.915",
#     "deathCnt": 23079,
#     "decideCnt": 17395705,
#     "seq": 869,
#     "stateDt": 20220504,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-11 09:03:27.014"
#   },
#   {
#     "MyUnknownColumn": 36,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-03 09:08:23.319",
#     "deathCnt": 23007,
#     "decideCnt": 17346659,
#     "seq": 868,
#     "stateDt": 20220503,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-10 10:09:55.309"
#   },
#   {
#     "MyUnknownColumn": 37,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-02 09:01:12.093",
#     "deathCnt": 22958,
#     "decideCnt": 17295553,
#     "seq": 867,
#     "stateDt": 20220502,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-07 09:20:27.275"
#   },
#   {
#     "MyUnknownColumn": 38,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-05-01 09:15:03.496",
#     "deathCnt": 22875,
#     "decideCnt": 17275477,
#     "seq": 866,
#     "stateDt": 20220501,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-07 09:20:49.891"
#   },
#   {
#     "MyUnknownColumn": 39,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-30 09:17:39.409",
#     "deathCnt": 22794,
#     "decideCnt": 17237717,
#     "seq": 865,
#     "stateDt": 20220430,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-07 09:21:13.949"
#   },
#   {
#     "MyUnknownColumn": 40,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-29 09:03:59.658",
#     "deathCnt": 22724,
#     "decideCnt": 17194473,
#     "seq": 864,
#     "stateDt": 20220429,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-05 09:26:15.183"
#   },
#   {
#     "MyUnknownColumn": 41,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-28 09:02:00.054",
#     "deathCnt": 22588,
#     "decideCnt": 17143917,
#     "seq": 863,
#     "stateDt": 20220428,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-05 09:26:29.55"
#   },
#   {
#     "MyUnknownColumn": 42,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-27 09:01:55.815",
#     "deathCnt": 22466,
#     "decideCnt": 17086471,
#     "seq": 862,
#     "stateDt": 20220427,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-04 09:13:13.366"
#   },
#   {
#     "MyUnknownColumn": 43,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-26 09:02:16.27",
#     "deathCnt": 22325,
#     "decideCnt": 17009707,
#     "seq": 861,
#     "stateDt": 20220426,
#     "stateTime": "00:00",
#     "updateDt": "2022-05-03 09:11:15.127"
#   },
#   {
#     "MyUnknownColumn": 44,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-25 09:02:21.688",
#     "deathCnt": 22243,
#     "decideCnt": 16929440,
#     "seq": 860,
#     "stateDt": 20220425,
#     "stateTime": "00:00",
#     "updateDt": "2022-04-30 09:23:49.525"
#   },
#   {
#     "MyUnknownColumn": 45,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-24 08:36:32.893",
#     "deathCnt": 22133,
#     "decideCnt": 16895079,
#     "seq": 859,
#     "stateDt": 20220424,
#     "stateTime": "00:00",
#     "updateDt": "2022-04-30 09:25:01.983"
#   },
#   {
#     "MyUnknownColumn": 46,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-23 08:54:03.35",
#     "deathCnt": 22024,
#     "decideCnt": 16830375,
#     "seq": 858,
#     "stateDt": 20220423,
#     "stateTime": "00:00",
#     "updateDt": "2022-04-30 09:24:15.874"
#   },
#   {
#     "MyUnknownColumn": 47,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-22 09:08:41.733",
#     "deathCnt": 21873,
#     "decideCnt": 16754952,
#     "seq": 857,
#     "stateDt": 20220422,
#     "stateTime": "00:00",
#     "updateDt": "2022-04-29 09:05:42.917"
#   },
#   {
#     "MyUnknownColumn": 48,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-21 09:05:31.131",
#     "deathCnt": 21667,
#     "decideCnt": 16673919,
#     "seq": 856,
#     "stateDt": 20220421,
#     "stateTime": "00:00",
#     "updateDt": "2022-04-28 09:04:37.11"
#   },
#   {
#     "MyUnknownColumn": 49,
#     "accDefRate": "",
#     "accExamCnt": "",
#     "createDt": "2022-04-20 09:05:36.813",
#     "deathCnt": 21520,
#     "decideCnt": 16583076,
#     "seq": 855,
#     "stateDt": 20220420,
#     "stateTime": "00:00",
#     "updateDt": "2022-04-27 09:03:39.849"
#   }
# ]

# %%
print(response2.content)
# Out:
# b'[\n  {\n    "MyUnknownColumn": 0,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-08 09:09:05.982",\n    "deathCnt": 24305,\n    "decideCnt": 18188200,\n    "seq": 904,\n    "stateDt": 20220608,\n    "stateTime": "00:00",\n    "updateDt": null\n  },\n  {\n    "MyUnknownColumn": 1,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-07 09:09:00.897",\n    "deathCnt": 24299,\n    "decideCnt": 18174842,\n    "seq": 903,\n    "stateDt": 20220607,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-08 09:10:36.846"\n  },\n  {\n    "MyUnknownColumn": 2,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-06 09:00:06.734",\n    "deathCnt": 24279,\n    "decideCnt": 18168670,\n    "seq": 902,\n    "stateDt": 20220606,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-08 09:10:50.441"\n  },\n  {\n    "MyUnknownColumn": 3,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-05 08:53:19.426",\n    "deathCnt": 24258,\n    "decideCnt": 18163648,\n    "seq": 901,\n    "stateDt": 20220605,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-08 09:11:04.758"\n  },\n  {\n    "MyUnknownColumn": 4,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-04 08:56:49.219",\n    "deathCnt": 24238,\n    "decideCnt": 18153814,\n    "seq": 900,\n    "stateDt": 20220604,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-08 09:11:26.303"\n  },\n  {\n    "MyUnknownColumn": 5,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-03 09:08:18.729",\n    "deathCnt": 24229,\n    "decideCnt": 18141775,\n    "seq": 899,\n    "stateDt": 20220603,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-08 09:11:38.938"\n  },\n  {\n    "MyUnknownColumn": 6,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-02 08:58:19.746",\n    "deathCnt": 24212,\n    "decideCnt": 18129236,\n    "seq": 898,\n    "stateDt": 20220602,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-08 09:11:51.985"\n  },\n  {\n    "MyUnknownColumn": 7,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-06-01 09:07:30.461",\n    "deathCnt": 24197,\n    "decideCnt": 18119345,\n    "seq": 897,\n    "stateDt": 20220601,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-08 09:12:05.316"\n  },\n  {\n    "MyUnknownColumn": 8,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-05-31 08:55:39.977",\n    "deathCnt": 24176,\n    "decideCnt": 18103577,\n    "seq": 896,\n    "stateDt": 20220531,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-04 08:59:23.637"\n  },\n  {\n    "MyUnknownColumn": 9,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-05-30 09:01:30.847",\n    "deathCnt": 24167,\n    "decideCnt": 18086392,\n    "seq": 895,\n    "stateDt": 20220530,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-04 08:59:37.203"\n  },\n  {\n    "MyUnknownColumn": 10,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-05-29 09:05:28.382",\n    "deathCnt": 24158,\n    "decideCnt": 18080257,\n    "seq": 894,\n    "stateDt": 20220529,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-04 08:59:51.863"\n  },\n  {\n    "MyUnknownColumn": 11,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-05-28 09:09:18.909",\n    "deathCnt": 24139,\n    "decideCnt": 18067610,\n    "seq": 893,\n    "stateDt": 20220528,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-04 09:00:06.316"\n  },\n  {\n    "MyUnknownColumn": 12,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-05-27 09:03:34.444",\n    "deathCnt": 24103,\n    "decideCnt": 18053236,\n    "seq": 892,\n    "stateDt": 20220527,\n    "stateTime": "00:00",\n    "updateDt": "2022-06-03 09:11:10.578"\n  },\n  {\n    "MyUnknownColumn": 13,\n    "accDefRate": "",\n    "accExamCnt": "",\n    "createDt": "2022-05-26 09:13:37.732",\n    "deathCnt": 24063,\n    "decideCnt": 18036664,\n    "seq": 891,\n    "stateDt ...

# %%
import json

# %%
json.loads(response.text)
# Out:
# [{'MyUnknownColumn': 0,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-08 09:09:05.982',
#   'deathCnt': 24305,
#   'decideCnt': 18188200,
#   'seq': 904,
#   'stateDt': 20220608,
#   'stateTime': '00:00',
#   'updateDt': None},
#  {'MyUnknownColumn': 1,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-07 09:09:00.897',
#   'deathCnt': 24299,
#   'decideCnt': 18174842,
#   'seq': 903,
#   'stateDt': 20220607,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:10:36.846'},
#  {'MyUnknownColumn': 2,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-06 09:00:06.734',
#   'deathCnt': 24279,
#   'decideCnt': 18168670,
#   'seq': 902,
#   'stateDt': 20220606,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:10:50.441'},
#  {'MyUnknownColumn': 3,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-05 08:53:19.426',
#   'deathCnt': 24258,
#   'decideCnt': 18163648,
#   'seq': 901,
#   'stateDt': 20220605,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:04.758'},
#  {'MyUnknownColumn': 4,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-04 08:56:49.219',
#   'deathCnt': 24238,
#   'decideCnt': 18153814,
#   'seq': 900,
#   'stateDt': 20220604,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:26.303'},
#  {'MyUnknownColumn': 5,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-03 09:08:18.729',
#   'deathCnt': 24229,
#   'decideCnt': 18141775,
#   'seq': 899,
#   'stateDt': 20220603,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:38.938'},
#  {'MyUnknownColumn': 6,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-02 08:58:19.746',
#   'deathCnt': 24212,
#   'decideCnt': 18129236,
#   'seq': 898,
#   'stateDt': 20220602,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:11:51.985'},
#  {'MyUnknownColumn': 7,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-06-01 09:07:30.461',
#   'deathCnt': 24197,
#   'decideCnt': 18119345,
#   'seq': 897,
#   'stateDt': 20220601,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-08 09:12:05.316'},
#  {'MyUnknownColumn': 8,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-31 08:55:39.977',
#   'deathCnt': 24176,
#   'decideCnt': 18103577,
#   'seq': 896,
#   'stateDt': 20220531,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 08:59:23.637'},
#  {'MyUnknownColumn': 9,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-30 09:01:30.847',
#   'deathCnt': 24167,
#   'decideCnt': 18086392,
#   'seq': 895,
#   'stateDt': 20220530,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 08:59:37.203'},
#  {'MyUnknownColumn': 10,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-29 09:05:28.382',
#   'deathCnt': 24158,
#   'decideCnt': 18080257,
#   'seq': 894,
#   'stateDt': 20220529,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 08:59:51.863'},
#  {'MyUnknownColumn': 11,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-28 09:09:18.909',
#   'deathCnt': 24139,
#   'decideCnt': 18067610,
#   'seq': 893,
#   'stateDt': 20220528,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-04 09:00:06.316'},
#  {'MyUnknownColumn': 12,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-27 09:03:34.444',
#   'deathCnt': 24103,
#   'decideCnt': 18053236,
#   'seq': 892,
#   'stateDt': 20220527,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-03 09:11:10.578'},
#  {'MyUnknownColumn': 13,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-26 09:13:37.732',
#   'deathCnt': 24063,
#   'decideCnt': 18036664,
#   'seq': 891,
#   'stateDt': 20220526,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-01 09:08:19.164'},
#  {'MyUnknownColumn': 14,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-25 09:02:44.294',
#   'deathCnt': 24029,
#   'decideCnt': 18017859,
#   'seq': 890,
#   'stateDt': 20220525,
#   'stateTime': '00:00',
#   'updateDt': '2022-06-01 09:08:25.254'},
#  {'MyUnknownColumn': 15,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-24 08:49:38.261',
#   'deathCnt': 24006,
#   'decideCnt': 17993923,
#   'seq': 889,
#   'stateDt': 20220524,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-31 08:58:44.451'},
#  {'MyUnknownColumn': 16,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-23 08:56:56.412',
#   'deathCnt': 23987,
#   'decideCnt': 17967592,
#   'seq': 888,
#   'stateDt': 20220523,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-28 09:10:13.674'},
#  {'MyUnknownColumn': 17,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-22 07:52:40.527',
#   'deathCnt': 23965,
#   'decideCnt': 17957621,
#   'seq': 887,
#   'stateDt': 20220522,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-28 09:10:20.33'},
#  {'MyUnknownColumn': 18,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-21 08:39:51.786',
#   'deathCnt': 23911,
#   'decideCnt': 17938332,
#   'seq': 886,
#   'stateDt': 20220521,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-28 09:10:27.211'},
#  {'MyUnknownColumn': 19,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-20 09:02:54.987',
#   'deathCnt': 23885,
#   'decideCnt': 17914882,
#   'seq': 885,
#   'stateDt': 20220520,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-27 09:04:41.621'},
#  {'MyUnknownColumn': 20,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-19 09:07:11.841',
#   'deathCnt': 23842,
#   'decideCnt': 17889769,
#   'seq': 884,
#   'stateDt': 20220519,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-26 09:16:54.036'},
#  {'MyUnknownColumn': 21,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-18 08:58:30.377',
#   'deathCnt': 23802,
#   'decideCnt': 17861660,
#   'seq': 883,
#   'stateDt': 20220518,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-25 09:05:49.683'},
#  {'MyUnknownColumn': 22,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-17 09:04:52.287',
#   'deathCnt': 23771,
#   'decideCnt': 17830327,
#   'seq': 882,
#   'stateDt': 20220517,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-24 09:18:48.656'},
#  {'MyUnknownColumn': 23,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-16 09:04:43.174',
#   'deathCnt': 23744,
#   'decideCnt': 17795242,
#   'seq': 881,
#   'stateDt': 20220516,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-21 08:47:40.875'},
#  {'MyUnknownColumn': 24,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-15 09:27:15.538',
#   'deathCnt': 23709,
#   'decideCnt': 17781952,
#   'seq': 880,
#   'stateDt': 20220515,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-21 08:47:54.484'},
#  {'MyUnknownColumn': 25,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-14 09:46:39.377',
#   'deathCnt': 23661,
#   'decideCnt': 17756527,
#   'seq': 879,
#   'stateDt': 20220514,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-21 08:48:13.125'},
#  {'MyUnknownColumn': 26,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-13 09:09:51.89',
#   'deathCnt': 23606,
#   'decideCnt': 17726955,
#   'seq': 878,
#   'stateDt': 20220513,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-20 09:06:42.817'},
#  {'MyUnknownColumn': 27,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-12 09:05:26.458',
#   'deathCnt': 23554,
#   'decideCnt': 17694520,
#   'seq': 877,
#   'stateDt': 20220512,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-19 17:37:18.336'},
#  {'MyUnknownColumn': 28,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-11 09:01:52.873',
#   'deathCnt': 23491,
#   'decideCnt': 17658638,
#   'seq': 876,
#   'stateDt': 20220511,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-19 17:38:10.681'},
#  {'MyUnknownColumn': 29,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-10 09:02:38.129',
#   'deathCnt': 23462,
#   'decideCnt': 17614757,
#   'seq': 875,
#   'stateDt': 20220510,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-17 09:06:40.689'},
#  {'MyUnknownColumn': 30,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-09 09:06:19.774',
#   'deathCnt': 23400,
#   'decideCnt': 17564861,
#   'seq': 874,
#   'stateDt': 20220509,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-14 10:34:58.518'},
#  {'MyUnknownColumn': 31,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-08 09:02:00.163',
#   'deathCnt': 23360,
#   'decideCnt': 17544273,
#   'seq': 873,
#   'stateDt': 20220508,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-14 10:35:16.208'},
#  {'MyUnknownColumn': 32,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-07 09:18:40.439',
#   'deathCnt': 23289,
#   'decideCnt': 17504225,
#   'seq': 872,
#   'stateDt': 20220507,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-14 10:35:34.039'},
#  {'MyUnknownColumn': 33,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-06 08:06:00.523',
#   'deathCnt': 23206,
#   'decideCnt': 17464662,
#   'seq': 871,
#   'stateDt': 20220506,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-13 09:11:27.572'},
#  {'MyUnknownColumn': 34,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-05 09:23:43.381',
#   'deathCnt': 23158,
#   'decideCnt': 17437984,
#   'seq': 870,
#   'stateDt': 20220505,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-12 09:06:57.564'},
#  {'MyUnknownColumn': 35,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-04 09:11:34.915',
#   'deathCnt': 23079,
#   'decideCnt': 17395705,
#   'seq': 869,
#   'stateDt': 20220504,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-11 09:03:27.014'},
#  {'MyUnknownColumn': 36,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-03 09:08:23.319',
#   'deathCnt': 23007,
#   'decideCnt': 17346659,
#   'seq': 868,
#   'stateDt': 20220503,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-10 10:09:55.309'},
#  {'MyUnknownColumn': 37,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-02 09:01:12.093',
#   'deathCnt': 22958,
#   'decideCnt': 17295553,
#   'seq': 867,
#   'stateDt': 20220502,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-07 09:20:27.275'},
#  {'MyUnknownColumn': 38,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-05-01 09:15:03.496',
#   'deathCnt': 22875,
#   'decideCnt': 17275477,
#   'seq': 866,
#   'stateDt': 20220501,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-07 09:20:49.891'},
#  {'MyUnknownColumn': 39,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-30 09:17:39.409',
#   'deathCnt': 22794,
#   'decideCnt': 17237717,
#   'seq': 865,
#   'stateDt': 20220430,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-07 09:21:13.949'},
#  {'MyUnknownColumn': 40,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-29 09:03:59.658',
#   'deathCnt': 22724,
#   'decideCnt': 17194473,
#   'seq': 864,
#   'stateDt': 20220429,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-05 09:26:15.183'},
#  {'MyUnknownColumn': 41,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-28 09:02:00.054',
#   'deathCnt': 22588,
#   'decideCnt': 17143917,
#   'seq': 863,
#   'stateDt': 20220428,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-05 09:26:29.55'},
#  {'MyUnknownColumn': 42,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-27 09:01:55.815',
#   'deathCnt': 22466,
#   'decideCnt': 17086471,
#   'seq': 862,
#   'stateDt': 20220427,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-04 09:13:13.366'},
#  {'MyUnknownColumn': 43,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-26 09:02:16.27',
#   'deathCnt': 22325,
#   'decideCnt': 17009707,
#   'seq': 861,
#   'stateDt': 20220426,
#   'stateTime': '00:00',
#   'updateDt': '2022-05-03 09:11:15.127'},
#  {'MyUnknownColumn': 44,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-25 09:02:21.688',
#   'deathCnt': 22243,
#   'decideCnt': 16929440,
#   'seq': 860,
#   'stateDt': 20220425,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-30 09:23:49.525'},
#  {'MyUnknownColumn': 45,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-24 08:36:32.893',
#   'deathCnt': 22133,
#   'decideCnt': 16895079,
#   'seq': 859,
#   'stateDt': 20220424,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-30 09:25:01.983'},
#  {'MyUnknownColumn': 46,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-23 08:54:03.35',
#   'deathCnt': 22024,
#   'decideCnt': 16830375,
#   'seq': 858,
#   'stateDt': 20220423,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-30 09:24:15.874'},
#  {'MyUnknownColumn': 47,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-22 09:08:41.733',
#   'deathCnt': 21873,
#   'decideCnt': 16754952,
#   'seq': 857,
#   'stateDt': 20220422,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-29 09:05:42.917'},
#  {'MyUnknownColumn': 48,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-21 09:05:31.131',
#   'deathCnt': 21667,
#   'decideCnt': 16673919,
#   'seq': 856,
#   'stateDt': 20220421,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-28 09:04:37.11'},
#  {'MyUnknownColumn': 49,
#   'accDefRate': '',
#   'accExamCnt': '',
#   'createDt': '2022-04-20 09:05:36.813',
#   'deathCnt': 21520,
#   'decideCnt': 16583076,
#   'seq': 855,
#   'stateDt': 20220420,
#   'stateTime': '00:00',
#   'updateDt': '2022-04-27 09:03:39.849'}]

# %%
## 공공데이터포털에서 데이터를 수집
url = "http://apis.data.go.kr/1741000/RegistrationPopulationByRegion/getRegistrationPopulationByRegion"
_params = {
    'ServiceKey' : "dtbWOdJ/Cz5HE0DGLU+CRPe7pOW0NIQBUcGEqsHZaTRiYCI/5+zugwzQjcvuId7NPdg6rUiW+ft3fm7yqyD4pw==",
    'pageNo': 1 ,
    'numOfRows' : 10
    }
res = requests.get(url, params = _params, verify=False)

# %%
print(res)
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
# <RegistrationPopulationByRegion>
#   <head>
#     <totalCount>266</totalCount>
#     <numOfRows>10</numOfRows>
#     <pageNo>1</pageNo>
#     <type>XML</type>
#     <RESULT>
#       <resultCode>INFO-0</resultCode>
#       <resultMsg>NOMAL SERVICE</resultMsg>
#     </RESULT>
#   </head>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>1</seq>
#     <regi>계</regi>
#     <population_tot>49540367</population_tot>
#     <population_man>24822897</population_man>
#     <population_female>24717470</population_female>
#     <houshol>19005339</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>2</seq>
#     <regi>서울</regi>
#     <population_tot>10200827</population_tot>
#     <population_man>5061809</population_man>
#     <population_female>5139018</population_female>
#     <houshol>4097562</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>3</seq>
#     <regi>부산</regi>
#     <population_tot>3564577</population_tot>
#     <population_man>1773154</population_man>
#     <population_female>1791423</population_female>
#     <houshol>1311724</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>4</seq>
#     <regi>대구</regi>
#     <population_tot>2492724</population_tot>
#     <population_man>1246873</population_man>
#     <population_female>1245851</population_female>
#     <houshol>894969</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>5</seq>
#     <regi>인천</regi>
#     <population_tot>2692696</population_tot>
#     <population_man>1356473</population_man>
#     <population_female>1336223</population_female>
#     <houshol>1014755</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>6</seq>
#     <regi>광주</regi>
#     <population_tot>1422702</population_tot>
#     <population_man>705817</population_man>
#     <population_female>716885</population_female>
#     <houshol>513021</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>7</seq>
#     <regi>대전</regi>
#     <population_tot>1480895</population_tot>
#     <population_man>741611</population_man>
#     <population_female>739284</population_female>
#     <houshol>531682</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>8</seq>
#     <regi>울산</regi>
#     <population_tot>1112407</population_tot>
#     <population_man>572815</population_man>
#     <population_female>539592</population_female>
#     <houshol>389735</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>9</seq>
#     <regi>경기</regi>
#     <population_tot>11292264</population_tot>
#     <population_man>5690673</population_man>
#     <population_female>5601591</population_female>
#     <houshol>4284475</houshol>
#   </row>
#   <row>
#     <wrttimeid>2008</wrttimeid>
#     <seq>10</seq>
#     <regi>강원</regi>
#     <population_tot>1508575</population_tot>
#     <population_man>759282</population_man>
#     <population_female>749293</population_female>
#     <houshol>606950</houshol>
#   </row>
# </RegistrationPopulationByRegion>

# %%
## xml데이터를 dict형태로 변환
# 라이브러리 설치
# !pip install xmltodict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
import xmltodict

# %%
data = xmltodict.parse(res.content)

# %%
type(data)
# Out:
# dict

# %%
from pprint import pprint

# %%
data = data['RegistrationPopulationByRegion']['row']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#   wrttimeid seq regi population_tot population_man population_female   houshol
# 0      2008   1    계       49540367       24822897          24717470  19005339
# 1      2008   2   서울       10200827        5061809           5139018   4097562
# 2      2008   3   부산        3564577        1773154           1791423   1311724
# 3      2008   4   대구        2492724        1246873           1245851    894969
# 4      2008   5   인천        2692696        1356473           1336223   1014755

# %% [markdown]
# 1. seq컬럼 제거하기
# 2. 컬럼의 이름 변경하기 -> ['년도','지역','전체 인구수','남자 인구수','여자 인구수','가구 수']

# %%
df.drop(columns = ['seq'], inplace=True)
#df.drop('seq',axis=1, inplace=True)

# %%
print(_df)
# Out:
#   wrttimeid regi population_tot population_man population_female   houshol
# 0      2008    계       49540367       24822897          24717470  19005339
# 1      2008   서울       10200827        5061809           5139018   4097562
# 2      2008   부산        3564577        1773154           1791423   1311724
# 3      2008   대구        2492724        1246873           1245851    894969
# 4      2008   인천        2692696        1356473           1336223   1014755
# 5      2008   광주        1422702         705817            716885    513021
# 6      2008   대전        1480895         741611            739284    531682
# 7      2008   울산        1112407         572815            539592    389735
# 8      2008   경기       11292264        5690673           5601591   4284475
# 9      2008   강원        1508575         759282            749293    606950

# %%
df.columns = ['년도','지역','전체 인구수','남자 인구수','여자 인구수','가구 수']

# %%
df.head()
# Out:
#      년도  지역    전체 인구수    남자 인구수    여자 인구수      가구 수
# 0  2008   계  49540367  24822897  24717470  19005339
# 1  2008  서울  10200827   5061809   5139018   4097562
# 2  2008  부산   3564577   1773154   1791423   1311724
# 3  2008  대구   2492724   1246873   1245851    894969
# 4  2008  인천   2692696   1356473   1336223   1014755

# %%
## 데이터프레임을 파일로 저장
## 컴퓨터의 입장 : DataFrame형식의 데이터를 csv형식으로 변환
df.to_csv("pop.csv",index=False)

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/250.0 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 250.0/250.0 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
df.to_excel('pop.xlsx', index=False)

# %%
### 데이터프레임을 sql에 저장
# !pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.27-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy)
#   Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Downloading SQLAlchemy-2.0.27-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.1 MB 1.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.6/2.1 MB 9.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.7/2.1 MB 15.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 13.2 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp312-cp312-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.6 kB ? eta -:--:--
#    --------------------------------------- 293.6/293.6 kB 17.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: typing-extensions, greenlet, sqlalchemy
# Successfully installed greenlet-3.0.3 sqlalchemy-2.0.27 typing-extensions-4.9.0

# %%
from sqlalchemy import create_engine
import pymysql

# %%
db_connection_str = "mysql+pymysql://root:1234@127.0.0.1/ubion10"
db_connection = create_engine(db_connection_str)
conn = db_connection.connect()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:644, in Connection.connect(self, sock)
#     643 try:
# --> 644     sock = socket.create_connection(
#     645         (self.host, self.port), self.connect_timeout, **kwargs
#     646     )
#     647     break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.752.0_x64__qbz5n2kfra8p0\Lib\socket.py:852, in create_connection(address, timeout, source_address, all_errors)
#     851 if not all_errors:
# --> 852     raise exceptions[0]
#     853 raise ExceptionGroup("create_connection failed", exceptions)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.752.0_x64__qbz5n2kfra8p0\Lib\socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:3282, in Engine.raw_connection(self)
#    3261 """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263 The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281 """
# -> 3282 return self.pool.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:168, in QueuePool._do_get(self)
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     357 else:
# --> 358     self.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:711, in Connection.connect(self, sock)
#     710         print(exc.traceback)
# --> 711     raise exc
#     713 # If e is neither DatabaseError or IOError, It's a bug.
#     714 # But raising AssertionError hides original error.
#     715 # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[63], line 3
#       1 db_connection_str = "mysql+pymysql://root:1234@127.0.0.1/ubion10"
#       2 db_connection = create_engine(db_connection_str)
# ----> 3 conn = db_connection.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:3258, in Engine.connect(self)
#    3235 def connect(self) -> Connection:
#    3236     """Return a new :class:`_engine.Connection` object.
#    3237
#    3238     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3255
#    3256     """
# -> 3258     return self._connection_cls(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:2422, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2420 elif should_wrap:
#    2421     assert sqlalchemy_exception is not None
# -> 2422     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2423 else:
#    2424     assert exc_info[1] is not None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:3282, in Engine.raw_connection(self)
#    3260 def raw_connection(self) -> PoolProxiedConnection:
#    3261     """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263     The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281     """
# -> 3282     return self.pool.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:168, in QueuePool._do_get(self)
#     166     return self._create_connection()
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#     170     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# --> 358     self.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:711, in Connection.connect(self, sock)
#     709     if DEBUG:
#     710         print(exc.traceback)
# --> 711     raise exc
#     713 # If e is neither DatabaseError or IOError, It's a bug.
#     714 # But raising AssertionError hides original error.
#     715 # So just reraise it.
#     716 raise
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
df.to_sql(
    name = 'pop_tabel',
    con = db_connection,
    if_exists= 'replace',
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:644, in Connection.connect(self, sock)
#     643 try:
# --> 644     sock = socket.create_connection(
#     645         (self.host, self.port), self.connect_timeout, **kwargs
#     646     )
#     647     break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.752.0_x64__qbz5n2kfra8p0\Lib\socket.py:852, in create_connection(address, timeout, source_address, all_errors)
#     851 if not all_errors:
# --> 852     raise exceptions[0]
#     853 raise ExceptionGroup("create_connection failed", exceptions)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.752.0_x64__qbz5n2kfra8p0\Lib\socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:3282, in Engine.raw_connection(self)
#    3261 """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263 The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281 """
# -> 3282 return self.pool.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:168, in QueuePool._do_get(self)
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     357 else:
# --> 358     self.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:711, in Connection.connect(self, sock)
#     710         print(exc.traceback)
# --> 711     raise exc
#     713 # If e is neither DatabaseError or IOError, It's a bug.
#     714 # But raising AssertionError hides original error.
#     715 # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df.to_sql(
#       2     name = 'pop_tabel',
#       3     con = db_connection,
#       4     if_exists= 'replace',
#       5     index=False
#       6 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:3081, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
#    3077 [(1,), (None,), (2,)]
#    3078 """  # noqa: E501
#    3079 from pandas.io import sql
# -> 3081 return sql.to_sql(
#    3082     self,
#    3083     name,
#    3084     con,
#    3085     schema=schema,
#    3086     if_exists=if_exists,
#    3087     index=index,
#    3088     index_label=index_label,
#    3089     chunksize=chunksize,
#    3090     dtype=dtype,
#    3091     method=method,
#    3092 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836 elif not isinstance(frame, DataFrame):
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
# --> 841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#    (...)
#     853         **engine_kwargs,
#     854     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:1639, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1637     self.exit_stack.callback(con.dispose)
#    1638 if isinstance(con, Engine):
# -> 1639     con = self.exit_stack.enter_context(con.connect())
#    1640 if need_transaction and not con.in_transaction():
#    1641     self.exit_stack.enter_context(con.begin())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:3258, in Engine.connect(self)
#    3235 def connect(self) -> Connection:
#    3236     """Return a new :class:`_engine.Connection` object.
#    3237
#    3238     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3255
#    3256     """
# -> 3258     return self._connection_cls(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:2422, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2420 elif should_wrap:
#    2421     assert sqlalchemy_exception is not None
# -> 2422     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2423 else:
#    2424     assert exc_info[1] is not None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\base.py:3282, in Engine.raw_connection(self)
#    3260 def raw_connection(self) -> PoolProxiedConnection:
#    3261     """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263     The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281     """
# -> 3282     return self.pool.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:168, in QueuePool._do_get(self)
#     166     return self._create_connection()
#     167 except:
# --> 168     with util.safe_reraise():
#     169         self._dec_overflow()
#     170     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# --> 358     self.connect()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pymysql\connections.py:711, in Connection.connect(self, sock)
#     709     if DEBUG:
#     710         print(exc.traceback)
# --> 711     raise exc
#     713 # If e is neither DatabaseError or IOError, It's a bug.
#     714 # But raising AssertionError hides original error.
#     715 # So just reraise it.
#     716 raise
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '127.0.0.1' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
