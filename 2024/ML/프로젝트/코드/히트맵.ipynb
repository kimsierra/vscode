# %% [markdown]
# #### 상관관계 분석
# - Heatmap

# %%
import pandas as pd

df = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트/data/all_features_testing(22개).xlsx')
df_features = df.drop(['날짜','label'], axis=1)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_10000\1638412444.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_features
# Out:
#           고용률    설비투자지수     건설기성액   WTI유가   소비자물가지수  기계류내수출하지수  수출입물가비  \
# 0    0.006734 -0.015169  0.040479 -0.0388 -0.001388     -0.010   0.008
# 1    0.000000  0.009479  0.010696 -0.0159  0.000000      0.018   0.007
# 2    0.001672  0.030516  0.055571  0.0499 -0.001217      0.001   0.003
# 3    0.000000  0.041002 -0.019089  0.0877  0.002146      0.004  -0.003
# 4    0.000000  0.020788  0.012227  0.0249  0.003541     -0.023  -0.005
# ..        ...       ...       ...     ...       ...        ...     ...
# 112  0.000000  0.069315 -0.002917 -0.0920 -0.000920      0.015  -0.002
# 113  0.000000 -0.038602 -0.015550 -0.1123  0.001749      0.023  -0.004
# 114  0.000000  0.002273  0.019838  0.0886  0.003124      0.008  -0.002
# 115  0.000000  0.019652  0.004808 -0.0690 -0.000824      0.001   0.002
# 116  0.000000 -0.077094  0.029782 -0.0011  0.001742     -0.036  -0.001
#
#          경상수지  미국생산자물가지수   소비자심리지수  ...  전체임금총액   소매판매액지수     전체실업률  \
# 0   -0.252263  -0.002571 -0.024952  ... -0.0053  0.000000  0.000000
# 1    0.906427   0.000000  0.024606  ... -0.0323  0.007203  0.000000
# 2   -0.289690  -0.000515  0.008646  ...  0.0567  0.004768  0.033333
# 3    0.020484   0.000516 -0.002857  ...  0.0232  0.009490  0.032258
# 4   -0.082603   0.003093  0.001910  ... -0.0366 -0.010576  0.000000
# ..        ...        ...       ...  ...     ...       ...       ...
# 112 -3.216346  -0.019616  0.032483  ... -0.0555  0.031369 -0.103448
# 113 -1.453728   0.001579  0.029213  ...  0.1034 -0.028571  0.076923
# 114 -0.590460   0.008492 -0.028384  ... -0.1109  0.014231  0.000000
# 115 -2.736097  -0.004429 -0.026966  ... -0.0128 -0.031805 -0.035714
# 116 -2.743049  -0.030802  0.040416  ...  0.2368  0.004831  0.111111
#
#      청년실업율(15~29세)    전업생산지수     미국ISM     미국PMI   미국건설지출    미국취업자수  미국비농업고용자수
# 0         0.040541  0.012346  0.049123 -0.019964  0.00012  0.309859   0.001371
# 1         0.000000 -0.002217 -0.113712 -0.040741 -0.00017  0.150538   0.001575
# 2        -0.038961 -0.003333 -0.064151  0.013514  0.00004 -0.163551   0.001315
# 3         0.094595 -0.002230  0.018145  0.000000  0.00005 -0.318436   0.000895
# 4         0.024691  0.007821  0.073267  0.028571 -0.00006  0.991803   0.001782
# ..             ...       ...       ...       ...      ...       ...        ...
# 112      -0.088235 -0.008050 -0.082716  0.000000 -0.00011 -0.647826   0.001588
# 113       0.064516 -0.001803 -0.253028 -0.017308 -0.00004  0.049383   0.001664
# 114      -0.030303 -0.006323 -0.064865 -0.001957 -0.00007  0.415686   0.002351
# 115       0.000000  0.008182  0.011561 -0.019608  0.00002 -0.285319   0.001676
# 116      -0.093750 -0.008115 -0.095238 -0.046000 -0.00003 -0.472868   0.000882
#
# [117 rows x 22 columns]

# %%
df_features.describe()
# Out:
#               고용률      설비투자지수       건설기성액       WTI유가     소비자물가지수   기계류내수출하지수  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean     0.000402    0.004191    0.003057    0.006956    0.001388    0.000880
# std      0.004153    0.045067    0.033432    0.134218    0.003327    0.015949
# min     -0.024390   -0.086079   -0.093642   -0.542400   -0.007443   -0.041000
# 25%     -0.001642   -0.032428   -0.017674   -0.059400   -0.000920   -0.010000
# 50%      0.000000    0.003518    0.002333    0.006500    0.001464    0.001000
# 75%      0.003236    0.027290    0.022433    0.069300    0.003541    0.011000
# max      0.015228    0.141040    0.110926    0.883800    0.010629    0.040000
#
#            수출입물가비        경상수지   미국생산자물가지수     소비자심리지수  ...      전체임금총액  \
# count  117.000000  117.000000  117.000000  117.000000  ...  117.000000
# mean    -0.000154    0.404527    0.002035   -0.000396  ...    0.008438
# std      0.008692    4.048423    0.010662    0.040780  ...    0.094796
# min     -0.022000  -10.448616   -0.032241   -0.186735  ...   -0.217500
# 25%     -0.006000   -0.289690   -0.002685   -0.019589  ...   -0.036600
# 50%     -0.001000   -0.034436    0.002595    0.004587  ...   -0.007400
# 75%      0.004000    0.261958    0.006796    0.023069  ...    0.051400
# max      0.034000   35.358808    0.034391    0.148699  ...    0.255100
#
#           소매판매액지수       전체실업률  청년실업율(15~29세)      전업생산지수       미국ISM  \
# count  117.000000  117.000000     117.000000  117.000000  117.000000
# mean     0.002095    0.002047       0.000432    0.001853   -0.000466
# std      0.019872    0.064963       0.071272    0.010046    0.091584
# min     -0.052114   -0.176471      -0.200000   -0.031853   -0.333674
# 25%     -0.009146   -0.030303      -0.038961   -0.005071   -0.055118
# 50%      0.004082    0.000000       0.000000    0.001908    0.000000
# 75%      0.013472    0.028571       0.040541    0.008563    0.049383
# max      0.051867    0.210526       0.188889    0.028154    0.238095
#
#             미국PMI      미국건설지출      미국취업자수   미국비농업고용자수
# count  117.000000  117.000000  117.000000  117.000000
# mean    -0.000541    0.000006    0.599376    0.001195
# std      0.037994    0.000089    4.420450    0.013387
# min     -0.168932   -0.000290   -6.344697   -0.135701
# 25%     -0.015180   -0.000050   -0.396226    0.001098
# 50%     -0.001957    0.000010   -0.021127    0.001585
# 75%      0.014363    0.000060    0.576850    0.002211
# max      0.263158    0.000220   44.400000    0.034689
#
# [8 rows x 22 columns]

# %%
df2 = pd.DataFrame(df_features)
df2
# Out:
#           고용률    설비투자지수     건설기성액   WTI유가   소비자물가지수  기계류내수출하지수  수출입물가비  \
# 0    0.006734 -0.015169  0.040479 -0.0388 -0.001388     -0.010   0.008
# 1    0.000000  0.009479  0.010696 -0.0159  0.000000      0.018   0.007
# 2    0.001672  0.030516  0.055571  0.0499 -0.001217      0.001   0.003
# 3    0.000000  0.041002 -0.019089  0.0877  0.002146      0.004  -0.003
# 4    0.000000  0.020788  0.012227  0.0249  0.003541     -0.023  -0.005
# ..        ...       ...       ...     ...       ...        ...     ...
# 112  0.000000  0.069315 -0.002917 -0.0920 -0.000920      0.015  -0.002
# 113  0.000000 -0.038602 -0.015550 -0.1123  0.001749      0.023  -0.004
# 114  0.000000  0.002273  0.019838  0.0886  0.003124      0.008  -0.002
# 115  0.000000  0.019652  0.004808 -0.0690 -0.000824      0.001   0.002
# 116  0.000000 -0.077094  0.029782 -0.0011  0.001742     -0.036  -0.001
#
#          경상수지  미국생산자물가지수   소비자심리지수  ...  전체임금총액   소매판매액지수     전체실업률  \
# 0   -0.252263  -0.002571 -0.024952  ... -0.0053  0.000000  0.000000
# 1    0.906427   0.000000  0.024606  ... -0.0323  0.007203  0.000000
# 2   -0.289690  -0.000515  0.008646  ...  0.0567  0.004768  0.033333
# 3    0.020484   0.000516 -0.002857  ...  0.0232  0.009490  0.032258
# 4   -0.082603   0.003093  0.001910  ... -0.0366 -0.010576  0.000000
# ..        ...        ...       ...  ...     ...       ...       ...
# 112 -3.216346  -0.019616  0.032483  ... -0.0555  0.031369 -0.103448
# 113 -1.453728   0.001579  0.029213  ...  0.1034 -0.028571  0.076923
# 114 -0.590460   0.008492 -0.028384  ... -0.1109  0.014231  0.000000
# 115 -2.736097  -0.004429 -0.026966  ... -0.0128 -0.031805 -0.035714
# 116 -2.743049  -0.030802  0.040416  ...  0.2368  0.004831  0.111111
#
#      청년실업율(15~29세)    전업생산지수     미국ISM     미국PMI   미국건설지출    미국취업자수  미국비농업고용자수
# 0         0.040541  0.012346  0.049123 -0.019964  0.00012  0.309859   0.001371
# 1         0.000000 -0.002217 -0.113712 -0.040741 -0.00017  0.150538   0.001575
# 2        -0.038961 -0.003333 -0.064151  0.013514  0.00004 -0.163551   0.001315
# 3         0.094595 -0.002230  0.018145  0.000000  0.00005 -0.318436   0.000895
# 4         0.024691  0.007821  0.073267  0.028571 -0.00006  0.991803   0.001782
# ..             ...       ...       ...       ...      ...       ...        ...
# 112      -0.088235 -0.008050 -0.082716  0.000000 -0.00011 -0.647826   0.001588
# 113       0.064516 -0.001803 -0.253028 -0.017308 -0.00004  0.049383   0.001664
# 114      -0.030303 -0.006323 -0.064865 -0.001957 -0.00007  0.415686   0.002351
# 115       0.000000  0.008182  0.011561 -0.019608  0.00002 -0.285319   0.001676
# 116      -0.093750 -0.008115 -0.095238 -0.046000 -0.00003 -0.472868   0.000882
#
# [117 rows x 22 columns]

# %%
correlation_matrix = df2.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
plt.figure(figsize=(12, 10))
df2_heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
corr_pairs = correlation_matrix.stack().reset_index()
corr_pairs.columns = ['Feature 1', 'Feature 2', 'Correlation']

# Remove self-correlation pairs (where features are the same)
corr_pairs = corr_pairs[corr_pairs['Feature 1'] != corr_pairs['Feature 2']]

# %%
corr_pairs['Absolute Correlation'] = corr_pairs['Correlation'].abs()

# Sort the pairs by absolute correlation in descending order
sorted_corr_pairs = corr_pairs.sort_values(by='Absolute Correlation', ascending=False)

# Display the top correlated pairs
sorted_corr_pairs.head(10)
# Out:
#          Feature 1      Feature 2  Correlation  Absolute Correlation
# 323          전체실업률  청년실업율(15~29세)     0.636930              0.636930
# 344  청년실업율(15~29세)          전체실업률     0.636930              0.636930
# 135         수출입물가비          WTI유가    -0.532163              0.532163
# 72           WTI유가         수출입물가비    -0.532163              0.532163
# 140         수출입물가비      미국생산자물가지수    -0.503694              0.503694
# 182      미국생산자물가지수         수출입물가비    -0.503694              0.503694
# 417          미국PMI      미국비농업고용자수     0.449443              0.449443
# 480      미국비농업고용자수          미국PMI     0.449443              0.449443
# 14             고용률          전체실업률    -0.420773              0.420773
# 308          전체실업률            고용률    -0.420773              0.420773

# %%
# Reset the index of the top 10 sorted correlation pairs for a clean view
top_corr_pairs_reset_index = sorted_corr_pairs.head(10).reset_index(drop=True)
top_corr_pairs_reset_index
# Out:
#        Feature 1      Feature 2  Correlation  Absolute Correlation
# 0          전체실업률  청년실업율(15~29세)     0.636930              0.636930
# 1  청년실업율(15~29세)          전체실업률     0.636930              0.636930
# 2         수출입물가비          WTI유가    -0.532163              0.532163
# 3          WTI유가         수출입물가비    -0.532163              0.532163
# 4         수출입물가비      미국생산자물가지수    -0.503694              0.503694
# 5      미국생산자물가지수         수출입물가비    -0.503694              0.503694
# 6          미국PMI      미국비농업고용자수     0.449443              0.449443
# 7      미국비농업고용자수          미국PMI     0.449443              0.449443
# 8            고용률          전체실업률    -0.420773              0.420773
# 9          전체실업률            고용률    -0.420773              0.420773

# %%
# 상관계수를 저장할 딕셔너리
correlation_results = {}

# 모든 열 쌍에 대한 상관계수 계산
for i, col1 in enumerate(df2.columns):
    for j, col2 in enumerate(df2.columns):
        if i < j:
            # 상관계수 계산
            correlation_coefficient, p_value = scipy.stats.pearsonr(df[col1], df[col2])
            # 딕셔너리에 저장
            correlation_results[(col1, col2)] = (correlation_coefficient, p_value)

# 결과 출력
for cols, (corr, p_val) in correlation_results.items():
    print(f"열 '{cols[0]}'와(과) '{cols[1]}'의 상관계수: {corr}, p-value: {p_val}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       6 for j, col2 in enumerate(df2.columns):
#       7     if i < j:
#       8         # 상관계수 계산
# ----> 9         correlation_coefficient, p_value = scipy.stats.pearsonr(df[col1], df[col2])
#      10         # 딕셔너리에 저장
#      11         correlation_results[(col1, col2)] = (correlation_coefficient, p_value)
#
# NameError: name 'scipy' is not defined
