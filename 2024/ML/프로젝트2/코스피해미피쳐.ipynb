# %%
import pandas as pd
df = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스피혜미피쳐.xlsx')
df
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_5476\2065067030.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                      회사명  거래소코드     회계년도  자산(*)(IFRS연결)(천원)  \
# 0     (주)HJ매그놀리아용평호텔앤리조트  70960  2016/12        928945970.0
# 1     (주)HJ매그놀리아용평호텔앤리조트  70960  2017/12        868156494.0
# 2     (주)HJ매그놀리아용평호텔앤리조트  70960  2018/12        812775928.0
# 3     (주)HJ매그놀리아용평호텔앤리조트  70960  2019/12        849935619.0
# 4     (주)HJ매그놀리아용평호텔앤리조트  70960  2020/12        911905132.0
# ...                  ...    ...      ...                ...
# ...

# %%
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '자산(*)(IFRS연결)(천원)', '매출액(수익)(*)(IFRS연결)(천원)',
#        '유형자산(*)(IFRS연결)(천원)', '인건비(IFRS연결)(백만원)', '재고자산(*)(IFRS연결)(천원)',
#        '[제조]   유동부채(*)(IFRS연결)', '[제조]   유동자산(*)(IFRS연결)'],
#       dtype='object')

# %%
strs = ['(*)(IFRS연결)(천원)', '(수익)(*)(IFRS연결)(천원)','(*)(IFRS연결)(천원)', '(IFRS연결)(백만원)',
        '(*)(IFRS연결)(천원)','(*)(IFRS연결)']

for s in strs:

    # filterd_df.columns = filterd_df.columns.str.replace(s, "")
    df.columns = df.columns.str.replace(s, "")
    
df.columns =df.columns.str.strip()
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '자산', '매출액(수익)', '유형자산', '인건비', '재고자산',
#        '[제조]   유동부채', '[제조]   유동자산'],
#       dtype='object')
