# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # 코스닥 재무피쳐 정리

# %%
kod = pd.read_excel('data/코스닥재무피쳐(최종).xlsx')

# %%
kod.isna().sum()
# Out:
# 회사명                    0
# 거래소코드                  0
# 회계년도                   0
# 총자본증가율               199
# 정상영업이익증가율            428
# 순이익증가율               199
# 자기자본증가율              199
# 매출액증가율               199
# 종업원수증가율              532
# 매출액총이익률                0
# 매출액정상영업이익률           428
# 매출액순이익률              428
# 자기자본정상영업이익률          428
# 자기자본순이익률             428
# 금융비용부담률              428
# 수지비율(관계기업투자손익 제외)    428
# 사내유보 대 자기자본비율        532
# 총자본회전률               428
# 자기자본회전률              428
# 타인자본회전률              428
# 유동자산회전률              428
# 당좌자산회전률              428
# 재고자산회전률                0
# 매출채권회전률              428
# 순운전자본회전률             428
# 운전자본회전률              428
# 종업원1인당 부가가치          533
# 노동장비율                533
# 기계장비율                533
# 자본집약도                533
# 총자본투자효율              428
# 설비투자효율               428
# 1주당순이익                 0
# 1주당 CASH FLOW        428
# 유보율                  428
# 기계투자효율               428
# 부가가치율                428
# 노동소득분배율                0
# 자기자본구성비율             428
# 유동비율                 428
# 당좌비율                 428
# 현금비율                 428
# 재고자산 대 순운전자본비율       389
# 매출채권 대 매입채무비율        428
# 부채비율                 428
# CASH FLOW 대 부채비율     428
# CASH FLOW 대 차입금비율    428
# CASH FLOW 대 총자본비율    428
# CASH FLOW 대 매출액비율    428
# 1주당매출액               428
# 1주당순자산               532
# 총자산영업이익률             388
# 총자산순이익률              388
# dtype: int64

# %%
kod
# Out:
#             회사명  거래소코드     회계년도      총자본증가율  정상영업이익증가율       순이익증가율  \
# 0      (주)CMG제약  58820  2012/12  109.147119       0.00  -341.571868
# 1      (주)CMG제약  58820  2013/12   -2.093352       0.00   104.447063
# 2      (주)CMG제약  58820  2014/12    3.855597     -44.10   -46.641074
# 3      (주)CMG제약  58820  2015/12   -2.644307       0.00 -2409.614083
# 4      (주)CMG제약  58820  2016/12   96.310506       0.00   147.338409
# ...         ...    ...      ...         ...        ...          ...
# 13418   흥구석유(주)  24060  2018/12    0.000000      45.37     0.000000
# 13419   흥구석유(주)  24060  2019/12    0.000000     -54.16     0.000000
# 13420   흥구석유(주)  24060  2020/12    0.000000       0.00     0.000000
# 13421   흥구석유(주)  24060  2021/12    0.000000       0.00     0.000000
# 13422   흥구석유(주)  24060  2022/12    0.000000       0.00     0.000000
#
#           자기자본증가율     매출액증가율  종업원수증가율    매출액총이익률  ...  매출채권 대 매입채무비율   부채비율  \
# 0       75.170505  -8.429134    -0.74  28.339513  ...         323.41  80.77
# 1       55.100407  25.510008     1.49  38.698504  ...         282.72  14.11
# 2        0.010946  11.520576    20.59  37.070669  ...         285.31  18.50
# 3       -4.480893  18.851969    -4.88  36.255153  ...         254.69  20.78
# 4      116.010163  21.921286     2.56  40.359438  ...         219.41   9.76
# ...           ...        ...      ...        ...  ...            ...    ...
# 13418    0.000000   0.000000    -9.68  77.698333  ...      139592.04   6.76
# 13419    0.000000   0.000000    -5.95  77.698333  ...       53375.77   8.65
# 13420    0.000000   0.000000   -13.92  77.698333  ...       21857.98   5.18
# 13421    0.000000   0.000000     4.41  77.698333  ...       26625.60   4.75
# 13422    0.000000   0.000000    -2.82  77.698333  ...       29726.54  17.29
#
#        CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  CASH FLOW 대 총자본비율  \
# 0                 -8.10             -11.83              -3.62
# 1                -39.85            -194.73              -4.93
# 2                -17.73            -104.12              -2.77
# 3                 16.12           24988.82               2.77
# 4                 29.03               0.00               2.58
# ...                 ...                ...                ...
# 13418             69.29               0.00               4.39
# 13419             43.35               0.00               3.45
# 13420             29.75             290.96               1.46
# 13421             15.11             155.06               0.69
# 13422              6.58               9.96               0.97
#
#        CASH FLOW 대 매출액비율    1주당매출액   1주당순자산  총자산영업이익률    총자산순이익률
# 0                 -12.71    332.74   643.72 -7.364118 -11.662368
# 1                 -13.51    235.52   492.83  1.415156   0.529722
# 2                  -7.06    262.65   447.56  0.761729   0.272160
# 3                   5.80    306.26   397.60 -4.549868  -6.456587
# 4                   8.69    361.04   958.84  1.559520   1.556945
# ...                  ...       ...      ...       ...        ...
# 13418               1.99  11080.55  4576.04  1.452600   3.151081
# 13419               1.92  10044.58  4984.23  0.598557   9.912404
# 13420               1.07   7656.25  5157.49 -0.589810   5.722998
# 13421               0.43   8814.25  5159.02 -0.034865   1.692535
# 13422               0.62   9781.18  5193.68  1.448075   2.828591
#
# [13423 rows x 53 columns]

# %%
kod.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '총자본증가율', '정상영업이익증가율', '순이익증가율', '자기자본증가율',
#        '매출액증가율', '종업원수증가율', '매출액총이익률', '매출액정상영업이익률', '매출액순이익률', '자기자본정상영업이익률',
#        '자기자본순이익률', '금융비용부담률', '수지비율(관계기업투자손익 제외)', '사내유보 대 자기자본비율', '총자본회전률',
#        '자기자본회전률', '타인자본회전률', '유동자산회전률', '당좌자산회전률', '재고자산회전률', '매출채권회전률',
#        '순운전자본회전률', '운전자본회전률', '종업원1인당 부가가치', '노동장비율', '기계장비율', '자본집약도',
#        '총자본투자효율', '설비투자효율', '1주당순이익', '1주당 CASH FLOW', '유보율', '기계투자효율',
#        '부가가치율', '노동소득분배율', '자기자본구성비율', '유동비율', '당좌비율', '현금비율',
#        '재고자산 대 순운전자본비율', '매출채권 대 매입채무비율', '부채비율', 'CASH FLOW 대 부채비율',
#        'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '1주당매출액',
#        '1주당순자산', '총자산영업이익률', '총자산순이익률'],
#       dtype='object')

# %% [markdown]
# ## 코스닥 스펙합병 기업 제거

# %%
sp_enp =['(주)본느','(주)세화피앤씨','(주)아이엘사이언스','(주)알로이스','(주)에스에이티','(주)원바이오젠','(주)원익피앤이','(주)인산가','(주)자비스','(주)정다운','(주)카이노스메드','(주)티에스트릴리온','(주)포인트엔지니어링','(주)한국비엔씨','(주)휴럼','나무기술(주)','씨아이에스(주)','엠에프엠코리아(주)','원텍(주)','패션플랫폼(주)']

# %%
for i in sp_enp:
    ind = kod[kod['회사명'] == i].index
    kod = kod.drop(index = ind).reset_index(drop=True)

# %%
kod
# Out:
#             회사명  거래소코드     회계년도      총자본증가율  정상영업이익증가율       순이익증가율  \
# 0      (주)CMG제약  58820  2012/12  109.147119       0.00  -341.571868
# 1      (주)CMG제약  58820  2013/12   -2.093352       0.00   104.447063
# 2      (주)CMG제약  58820  2014/12    3.855597     -44.10   -46.641074
# 3      (주)CMG제약  58820  2015/12   -2.644307       0.00 -2409.614083
# 4      (주)CMG제약  58820  2016/12   96.310506       0.00   147.338409
# ...         ...    ...      ...         ...        ...          ...
# 13221   흥구석유(주)  24060  2018/12    0.000000      45.37     0.000000
# 13222   흥구석유(주)  24060  2019/12    0.000000     -54.16     0.000000
# 13223   흥구석유(주)  24060  2020/12    0.000000       0.00     0.000000
# 13224   흥구석유(주)  24060  2021/12    0.000000       0.00     0.000000
# 13225   흥구석유(주)  24060  2022/12    0.000000       0.00     0.000000
#
#           자기자본증가율     매출액증가율  종업원수증가율    매출액총이익률  ...  매출채권 대 매입채무비율   부채비율  \
# 0       75.170505  -8.429134    -0.74  28.339513  ...         323.41  80.77
# 1       55.100407  25.510008     1.49  38.698504  ...         282.72  14.11
# 2        0.010946  11.520576    20.59  37.070669  ...         285.31  18.50
# 3       -4.480893  18.851969    -4.88  36.255153  ...         254.69  20.78
# 4      116.010163  21.921286     2.56  40.359438  ...         219.41   9.76
# ...           ...        ...      ...        ...  ...            ...    ...
# 13221    0.000000   0.000000    -9.68  77.698333  ...      139592.04   6.76
# 13222    0.000000   0.000000    -5.95  77.698333  ...       53375.77   8.65
# 13223    0.000000   0.000000   -13.92  77.698333  ...       21857.98   5.18
# 13224    0.000000   0.000000     4.41  77.698333  ...       26625.60   4.75
# 13225    0.000000   0.000000    -2.82  77.698333  ...       29726.54  17.29
#
#        CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  CASH FLOW 대 총자본비율  \
# 0                 -8.10             -11.83              -3.62
# 1                -39.85            -194.73              -4.93
# 2                -17.73            -104.12              -2.77
# 3                 16.12           24988.82               2.77
# 4                 29.03               0.00               2.58
# ...                 ...                ...                ...
# 13221             69.29               0.00               4.39
# 13222             43.35               0.00               3.45
# 13223             29.75             290.96               1.46
# 13224             15.11             155.06               0.69
# 13225              6.58               9.96               0.97
#
#        CASH FLOW 대 매출액비율    1주당매출액   1주당순자산  총자산영업이익률    총자산순이익률
# 0                 -12.71    332.74   643.72 -7.364118 -11.662368
# 1                 -13.51    235.52   492.83  1.415156   0.529722
# 2                  -7.06    262.65   447.56  0.761729   0.272160
# 3                   5.80    306.26   397.60 -4.549868  -6.456587
# 4                   8.69    361.04   958.84  1.559520   1.556945
# ...                  ...       ...      ...       ...        ...
# 13221               1.99  11080.55  4576.04  1.452600   3.151081
# 13222               1.92  10044.58  4984.23  0.598557   9.912404
# 13223               1.07   7656.25  5157.49 -0.589810   5.722998
# 13224               0.43   8814.25  5159.02 -0.034865   1.692535
# 13225               0.62   9781.18  5193.68  1.448075   2.828591
#
# [13226 rows x 53 columns]

# %%
kod.isna().sum()
# Out:
# 회사명                    0
# 거래소코드                  0
# 회계년도                   0
# 총자본증가율               185
# 정상영업이익증가율            379
# 순이익증가율               185
# 자기자본증가율              185
# 매출액증가율               185
# 종업원수증가율              483
# 매출액총이익률                0
# 매출액정상영업이익률           379
# 매출액순이익률              379
# 자기자본정상영업이익률          379
# 자기자본순이익률             379
# 금융비용부담률              379
# 수지비율(관계기업투자손익 제외)    379
# 사내유보 대 자기자본비율        483
# 총자본회전률               379
# 자기자본회전률              379
# 타인자본회전률              379
# 유동자산회전률              379
# 당좌자산회전률              379
# 재고자산회전률                0
# 매출채권회전률              379
# 순운전자본회전률             379
# 운전자본회전률              379
# 종업원1인당 부가가치          484
# 노동장비율                484
# 기계장비율                484
# 자본집약도                484
# 총자본투자효율              379
# 설비투자효율               379
# 1주당순이익                 0
# 1주당 CASH FLOW        379
# 유보율                  379
# 기계투자효율               379
# 부가가치율                379
# 노동소득분배율                0
# 자기자본구성비율             379
# 유동비율                 379
# 당좌비율                 379
# 현금비율                 379
# 재고자산 대 순운전자본비율       350
# 매출채권 대 매입채무비율        379
# 부채비율                 379
# CASH FLOW 대 부채비율     379
# CASH FLOW 대 차입금비율    379
# CASH FLOW 대 총자본비율    379
# CASH FLOW 대 매출액비율    379
# 1주당매출액               379
# 1주당순자산               483
# 총자산영업이익률             348
# 총자산순이익률              348
# dtype: int64

# %% [markdown]
# ## 해외 법인 회사 제거

# %%
ind= kod[kod["거래소코드"] > 900000].index.tolist()
kod = kod.drop(index = ind).reset_index(drop= True)

# %%
kod.isna().sum()
# Out:
# 회사명                    0
# 거래소코드                  0
# 회계년도                   0
# 총자본증가율               179
# 정상영업이익증가율            373
# 순이익증가율               179
# 자기자본증가율              179
# 매출액증가율               179
# 종업원수증가율              375
# 매출액총이익률                0
# 매출액정상영업이익률           373
# 매출액순이익률              373
# 자기자본정상영업이익률          373
# 자기자본순이익률             373
# 금융비용부담률              373
# 수지비율(관계기업투자손익 제외)    373
# 사내유보 대 자기자본비율        375
# 총자본회전률               373
# 자기자본회전률              373
# 타인자본회전률              373
# 유동자산회전률              373
# 당좌자산회전률              373
# 재고자산회전률                0
# 매출채권회전률              373
# 순운전자본회전률             373
# 운전자본회전률              373
# 종업원1인당 부가가치          376
# 노동장비율                376
# 기계장비율                376
# 자본집약도                376
# 총자본투자효율              373
# 설비투자효율               373
# 1주당순이익                 0
# 1주당 CASH FLOW        373
# 유보율                  373
# 기계투자효율               373
# 부가가치율                373
# 노동소득분배율                0
# 자기자본구성비율             373
# 유동비율                 373
# 당좌비율                 373
# 현금비율                 373
# 재고자산 대 순운전자본비율       350
# 매출채권 대 매입채무비율        373
# 부채비율                 373
# CASH FLOW 대 부채비율     373
# CASH FLOW 대 차입금비율    373
# CASH FLOW 대 총자본비율    373
# CASH FLOW 대 매출액비율    373
# 1주당매출액               373
# 1주당순자산               375
# 총자산영업이익률             348
# 총자산순이익률              348
# dtype: int64

# %%
kod
# Out:
#             회사명  거래소코드     회계년도      총자본증가율  정상영업이익증가율       순이익증가율  \
# 0      (주)CMG제약  58820  2012/12  109.147119       0.00  -341.571868
# 1      (주)CMG제약  58820  2013/12   -2.093352       0.00   104.447063
# 2      (주)CMG제약  58820  2014/12    3.855597     -44.10   -46.641074
# 3      (주)CMG제약  58820  2015/12   -2.644307       0.00 -2409.614083
# 4      (주)CMG제약  58820  2016/12   96.310506       0.00   147.338409
# ...         ...    ...      ...         ...        ...          ...
# 13071   흥구석유(주)  24060  2018/12    0.000000      45.37     0.000000
# 13072   흥구석유(주)  24060  2019/12    0.000000     -54.16     0.000000
# 13073   흥구석유(주)  24060  2020/12    0.000000       0.00     0.000000
# 13074   흥구석유(주)  24060  2021/12    0.000000       0.00     0.000000
# 13075   흥구석유(주)  24060  2022/12    0.000000       0.00     0.000000
#
#           자기자본증가율     매출액증가율  종업원수증가율    매출액총이익률  ...  매출채권 대 매입채무비율   부채비율  \
# 0       75.170505  -8.429134    -0.74  28.339513  ...         323.41  80.77
# 1       55.100407  25.510008     1.49  38.698504  ...         282.72  14.11
# 2        0.010946  11.520576    20.59  37.070669  ...         285.31  18.50
# 3       -4.480893  18.851969    -4.88  36.255153  ...         254.69  20.78
# 4      116.010163  21.921286     2.56  40.359438  ...         219.41   9.76
# ...           ...        ...      ...        ...  ...            ...    ...
# 13071    0.000000   0.000000    -9.68  77.698333  ...      139592.04   6.76
# 13072    0.000000   0.000000    -5.95  77.698333  ...       53375.77   8.65
# 13073    0.000000   0.000000   -13.92  77.698333  ...       21857.98   5.18
# 13074    0.000000   0.000000     4.41  77.698333  ...       26625.60   4.75
# 13075    0.000000   0.000000    -2.82  77.698333  ...       29726.54  17.29
#
#        CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  CASH FLOW 대 총자본비율  \
# 0                 -8.10             -11.83              -3.62
# 1                -39.85            -194.73              -4.93
# 2                -17.73            -104.12              -2.77
# 3                 16.12           24988.82               2.77
# 4                 29.03               0.00               2.58
# ...                 ...                ...                ...
# 13071             69.29               0.00               4.39
# 13072             43.35               0.00               3.45
# 13073             29.75             290.96               1.46
# 13074             15.11             155.06               0.69
# 13075              6.58               9.96               0.97
#
#        CASH FLOW 대 매출액비율    1주당매출액   1주당순자산  총자산영업이익률    총자산순이익률
# 0                 -12.71    332.74   643.72 -7.364118 -11.662368
# 1                 -13.51    235.52   492.83  1.415156   0.529722
# 2                  -7.06    262.65   447.56  0.761729   0.272160
# 3                   5.80    306.26   397.60 -4.549868  -6.456587
# 4                   8.69    361.04   958.84  1.559520   1.556945
# ...                  ...       ...      ...       ...        ...
# 13071               1.99  11080.55  4576.04  1.452600   3.151081
# 13072               1.92  10044.58  4984.23  0.598557   9.912404
# 13073               1.07   7656.25  5157.49 -0.589810   5.722998
# 13074               0.43   8814.25  5159.02 -0.034865   1.692535
# 13075               0.62   9781.18  5193.68  1.448075   2.828591
#
# [13076 rows x 53 columns]

# %%
kod.to_csv('data/코스닥재무피쳐_정리(최종).csv')

# %% [markdown]
# # 코스피 재무피쳐 정리

# %%
kop = pd.read_excel('data/코스피재무피쳐(최종).xlsx')

# %% [markdown]
# ## 동일 회사 중복 제거 및 해외 법인 회사 제거

# %%
kop.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 총자본증가율               46
# 정상영업이익증가율            46
# 순이익증가율               46
# 자기자본증가율              46
# 매출액증가율               46
# 종업원수증가율              67
# 매출액총이익률               0
# 매출액정상영업이익률           46
# 매출액순이익률              46
# 자기자본정상영업이익률          46
# 자기자본순이익률             46
# 금융비용부담률              46
# 수지비율(관계기업투자손익 제외)    46
# 사내유보 대 자기자본비율        67
# 총자본회전률               46
# 자기자본회전률              46
# 타인자본회전률              46
# 유동자산회전률              46
# 당좌자산회전률              46
# 재고자산회전률               0
# 매출채권회전률              46
# 순운전자본회전률             46
# 운전자본회전률              46
# 종업원1인당 부가가치          68
# 노동장비율                68
# 기계장비율                68
# 자본집약도                68
# 총자본투자효율              46
# 설비투자효율               46
# 1주당순이익                0
# 1주당 CASH FLOW        46
# 유보율                  46
# 기계투자효율               46
# 부가가치율                46
# 노동소득분배율               0
# 자기자본구성비율             46
# 유동비율                 46
# 당좌비율                 46
# 현금비율                 45
# 재고자산 대 순운전자본비율        2
# 매출채권 대 매입채무비율        46
# 부채비율                 46
# CASH FLOW 대 부채비율     46
# CASH FLOW 대 차입금비율    46
# CASH FLOW 대 총자본비율    46
# CASH FLOW 대 매출액비율    46
# 1주당매출액               46
# 1주당순자산               67
# 총자산영업이익률              0
# 총자산순이익률               0
# dtype: int64

# %%
temp = kop[kop['회사명'] == '에스케이(주)']
ind = temp[kop['거래소코드'] == 3600].index
kop = kop.drop(index = ind)

# %%
ind= kop[kop["거래소코드"] > 900000].index.tolist()
kos = kop.drop(index = ind).reset_index(drop= True)

# %%
kop.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 총자본증가율               46
# 정상영업이익증가율            46
# 순이익증가율               46
# 자기자본증가율              46
# 매출액증가율               46
# 종업원수증가율              67
# 매출액총이익률               0
# 매출액정상영업이익률           46
# 매출액순이익률              46
# 자기자본정상영업이익률          46
# 자기자본순이익률             46
# 금융비용부담률              46
# 수지비율(관계기업투자손익 제외)    46
# 사내유보 대 자기자본비율        67
# 총자본회전률               46
# 자기자본회전률              46
# 타인자본회전률              46
# 유동자산회전률              46
# 당좌자산회전률              46
# 재고자산회전률               0
# 매출채권회전률              46
# 순운전자본회전률             46
# 운전자본회전률              46
# 종업원1인당 부가가치          68
# 노동장비율                68
# 기계장비율                68
# 자본집약도                68
# 총자본투자효율              46
# 설비투자효율               46
# 1주당순이익                0
# 1주당 CASH FLOW        46
# 유보율                  46
# 기계투자효율               46
# 부가가치율                46
# 노동소득분배율               0
# 자기자본구성비율             46
# 유동비율                 46
# 당좌비율                 46
# 현금비율                 45
# 재고자산 대 순운전자본비율        2
# 매출채권 대 매입채무비율        46
# 부채비율                 46
# CASH FLOW 대 부채비율     46
# CASH FLOW 대 차입금비율    46
# CASH FLOW 대 총자본비율    46
# CASH FLOW 대 매출액비율    46
# 1주당매출액               46
# 1주당순자산               67
# 총자산영업이익률              0
# 총자산순이익률               0
# dtype: int64

# %%
kop
# Out:
#                      회사명  거래소코드     회계년도     총자본증가율  정상영업이익증가율      순이익증가율  \
# 0     (주)HJ매그놀리아용평호텔앤리조트  70960  2016/12  -4.300000      14.92   23.290000
# 1     (주)HJ매그놀리아용평호텔앤리조트  70960  2017/12  -6.543919      10.28   18.377986
# 2     (주)HJ매그놀리아용평호텔앤리조트  70960  2018/12  -6.379099     -26.67  -39.917467
# 3     (주)HJ매그놀리아용평호텔앤리조트  70960  2019/12   4.571948    -116.79 -235.397865
# 4     (주)HJ매그놀리아용평호텔앤리조트  70960  2020/12   7.291083       0.00  -27.339679
# ...                  ...    ...      ...        ...        ...         ...
# 7620             흥아해운(주)   3280  2018/12  -5.331246       0.00  -17.741050
# 7621             흥아해운(주)   3280  2019/12 -46.377560       0.00   40.655814
# 7622             흥아해운(주)   3280  2020/12 -33.456899       0.00    0.934827
# 7623             흥아해운(주)   3280  2021/12 -13.765894       0.00  132.306680
# 7624             흥아해운(주)   3280  2022/12  28.209311       0.00   44.860023
#
#          자기자본증가율      매출액증가율  종업원수증가율    매출액총이익률  ...  매출채권 대 매입채무비율     부채비율  \
# 0      26.730000   19.510000     0.00  23.238812  ...        7094.91   134.32
# 1       2.961110   -0.486319     2.56  22.571195  ...        5053.47   112.69
# 2       1.467335  -13.491608     7.79  22.908533  ...        1474.81    96.24
# 3      -4.439785  -28.644211     1.73  10.258773  ...        1205.05   114.75
# 4      -4.550718   -1.555679    -6.25   7.149238  ...        4125.71   141.39
# ...          ...         ...      ...        ...  ...            ...      ...
# 7620  -37.418411   -9.870781   -13.57  -0.928795  ...          59.32   998.73
# 7621  -57.730479  -86.447605   -57.41   5.542378  ...          15.30  1293.83
# 7622 -185.007728  -12.947450    -9.44   8.259590  ...          14.07     0.00
# 7623 -491.646312   -8.111781    12.05   6.941889  ...          44.97   140.24
# 7624   31.440659  117.634226     0.87  25.278355  ...          64.91   134.33
#
#       CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  CASH FLOW 대 총자본비율  \
# 0                 1.67               6.90               0.96
# 1                -0.13              -0.42              -0.07
# 2                 8.82              22.80               4.33
# 3                 8.38              21.06               4.48
# 4                 6.98              19.92               4.09
# ...                ...                ...                ...
# 7620             -2.78              -8.01              -2.53
# 7621             -5.73              -7.34              -5.32
# 7622             -2.56              -3.17              -2.79
# 7623             -2.28              -2.81              -1.33
# 7624              8.28              10.66               4.75
#
#       CASH FLOW 대 매출액비율   1주당매출액   1주당순자산  총자산영업이익률    총자산순이익률
# 0                  4.23  4782.96  8769.03  3.269731   1.541671
# 1                 -0.28  4356.18  8146.08  3.858408   1.952787
# 2                 19.38  3768.46  8287.53  3.022085   1.253229
# 3                 29.40  2689.02  7979.61 -0.485229  -1.622658
# 4                 29.24  2647.18  7604.52 -0.762389  -1.925871
# ...                 ...      ...      ...       ...        ...
# 7620              -2.70  4448.67   330.21 -4.677870 -10.767739
# 7621             -22.44   781.48   133.10 -2.868993 -11.916704
# 7622              -9.00   761.90     0.00 -2.021628 -17.740837
# 7623              -4.03   453.10   599.33 -0.758066   6.646414
# 7624               8.46   739.77   532.29  9.360792   7.509592
#
# [7622 rows x 53 columns]

# %%
kop.to_csv('data/코스피재무피쳐_정리(최종).csv')
