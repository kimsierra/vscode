# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Ridge

from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import classification_report
import warnings

# 특정 경고 메시지 무시
warnings.filterwarnings("ignore")

# %% [markdown]
# # 데이터 불러오기

# %%
# 데이터 불러기기
data = pd.read_excel('????????????????.xlsx')

### 날짜 datatime 형식으로 변환
data['날짜'] = pd.to_datetime(data['날짜'])

### 피쳐 정보 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   날짜                 117 non-null    datetime64[ns]
#  1   경상수지               117 non-null    float64
#  2   고용률                117 non-null    float64
#  3   WTI유가              117 non-null    float64
#  4   건설기성액(십억원)         117 non-null    float64
#  5   국내설비투자지수           117 non-null    float64
#  6   국내소매판매액지수          117 non-null    float64
#  7   미국ISM(제조업물가지수)     117 non-null    float64
#  8   미국취업자수증감(만명)       117 non-null    float64
#  9   미국생산자물가지수          117 non-null    float64
#  10  종합주택매매가격지수         117 non-null    float64
#  11  소비자물가지수            117 non-null    float64
#  12  소비자심리지수(CCSI)      117 non-null    float64
#  13  실업급여지급건수(월)        117 non-null    float64
#  14  전체임금총액(원)          117 non-null    float64
#  15  미국PMI(제조업구매담당자지수)  117 non-null    float64
#  16  label              117 non-null    int64
# dtypes: datetime64[ns](1), float64(15), int64(1)
# memory usage: 15.7 KB

# %% [markdown]
# # 데이터 Split

# %%
X_data = df.drop(columns=['회사명', '거래소코드', '회계년도', '부실'])
y_data = df['부실']
# Out:
# ((81, 17), (36, 17))

# %%
X_train,X_test,y_train,y_test = train_test_split(X_data,y_data,test_size=0.3,stratify=y_data,random_state = 777)

# %% [markdown]
# # 모델 선언

# %%
# 모델 생성
tree = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)
xgb = XGBClassifier(random_state=42)
lgb = LGBMClassifier(random_state=42)
cat = CatBoostClassifier(random_state=42, verbose=0)

# 모델 학습
tree.fit(X_train, y_train)
rf.fit(X_train, y_train)
xgb.fit(X_train, y_train)
lgb.fit(X_train, y_train)
cat.fit(X_train, y_train)

# 테스트 세트로 예측
y_pred = tree.predict(X_test)
y_pred_rf = rf.predict(X_test)
y_pred_xgb = xgb.predict(X_test)
y_pred_lgb = lgb.predict(X_test)
y_pred_cat = cat.predict(X_test)

# 정확도 계산 및 기록
# acc_test = accuracy_score(y_test, y_pred)
# acc_test_list.append(acc_test)
# Out:
# [LightGBM] [Info] Number of positive: 38, number of negative: 43
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000246 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 81, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.469136 -> initscore=-0.123614
# [LightGBM] [Info] Start training from score -0.123614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# # DT 모델 성능 평가 결과

# %%
print("DecisionTreeClassifier 성능:")
print(f"정확도: {accuracy_score(y_test, y_pred):.2f}")
print(f"정밀도: {precision_score(y_test, y_pred):.2f}")
print(f"재현율: {recall_score(y_test, y_pred):.2f}")
print(f"F1 점수: {f1_score(y_test, y_pred):.2f}")
print(classification_report(y_test, y_pred))
# Out:
# DecisionTreeClassifier 성능:
# 정확도: 0.61
# 정밀도: 0.59
# 재현율: 0.89
# F1 점수: 0.71
#               precision    recall  f1-score   support
#
#            0       0.71      0.29      0.42        17
#            1       0.59      0.89      0.71        19
#
#     accuracy                           0.61        36
#    macro avg       0.65      0.59      0.56        36
# weighted avg       0.65      0.61      0.57        36
#               feature  importance
# 0          종합주택매매가격지수    0.323281
# 1             소비자물가지수    0.168921
# 2           전체임금총액(원)    0.152088
# 3            국내설비투자지수    0.088151
# 4          건설기성액(십억원)    0.055797
# 5        미국취업자수증감(만명)    0.053978
# 6         실업급여지급건수(월)    0.047919
# 7                경상수지    0.044828
# 8           미국생산자물가지수    0.044064
# 9      미국ISM(제조업물가지수)    0.020973
# 10                고용률    0.000000
# 11              WTI유가    0.000000
# 12          국내소매판매액지수    0.000000
# 13      소비자심리지수(CCSI)    0.000000
# 14  미국PMI(제조업구매담당자지수)    0.000000

# %% [markdown]
# # RF 모델 성능 평가 결과

# %%
print("RandomForestClassifier 성능:")
print(f"정확도: {accuracy_score(y_test, y_pred_rf):.2f}")
print(f"정밀도: {precision_score(y_test, y_pred_rf):.2f}")
print(f"재현율: {recall_score(y_test, y_pred_rf):.2f}")
print(f"F1 점수: {f1_score(y_test, y_pred_rf):.2f}")
print(classification_report(y_test, y_pred_rf))
# Out:
# RandomForestClassifier 성능:
# 정확도: 0.61
# 정밀도: 0.61
# 재현율: 0.74
# F1 점수: 0.67
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.53        17
#            1       0.61      0.74      0.67        19
#
#     accuracy                           0.61        36
#    macro avg       0.61      0.60      0.60        36
# weighted avg       0.61      0.61      0.60        36
#               feature  importance
# 0          종합주택매매가격지수    0.147176
# 1          건설기성액(십억원)    0.087831
# 2           미국생산자물가지수    0.070058
# 3             소비자물가지수    0.068956
# 4               WTI유가    0.064545
# 5   미국PMI(제조업구매담당자지수)    0.063958
# 6        미국취업자수증감(만명)    0.062678
# 7       소비자심리지수(CCSI)    0.061711
# 8                경상수지    0.060947
# 9      미국ISM(제조업물가지수)    0.060000
# 10           국내설비투자지수    0.058315
# 11        실업급여지급건수(월)    0.053263
# 12                고용률    0.050330
# 13          전체임금총액(원)    0.050159
# 14          국내소매판매액지수    0.040072

# %% [markdown]
# # LGBM 모델 성능 평가 결과

# %%
# y_pred_rf = lgb.predict(X_test)
print("LGBMClassifier 성능:")
print(f"정확도: {accuracy_score(y_test, y_pred_lgb):.2f}")
print(f"정밀도: {precision_score(y_test, y_pred_lgb):.2f}")
print(f"재현율: {recall_score(y_test, y_pred_lgb):.2f}")
print(f"F1 점수: {f1_score(y_test, y_pred_lgb):.2f}")
# print(f"정확도: {accuracy_score(y_test, y_pred_lgb):.2f}")
# print(f"정밀도: {precision_score(y_test, y_pred_lgb):.2f}")
# print(f"재현율: {recall_score(y_test, y_pred_lgb):.2f}")
# print(f"F1 점수: {f1_score(y_test, y_pred_lgb):.2f}")
print(classification_report(y_test, y_pred_lgb))
# Out:
# LGBMClassifier 성능:
# 정확도: 0.64
# 정밀도: 0.67
# 재현율: 0.63
# F1 점수: 0.65
#               precision    recall  f1-score   support
#
#            0       0.61      0.65      0.63        17
#            1       0.67      0.63      0.65        19
#
#     accuracy                           0.64        36
#    macro avg       0.64      0.64      0.64        36
# weighted avg       0.64      0.64      0.64        36
#                    importance
# 종합주택매매가격지수                 29
# 건설기성액(십억원)                 26
# 국내설비투자지수                   26
# 미국취업자수증감(만명)               20
# 미국생산자물가지수                  20
# 소비자물가지수                    16
# 고용률                        15
# 미국PMI(제조업구매담당자지수)          15
# 경상수지                       12
# 미국ISM(제조업물가지수)             12
# 국내소매판매액지수                  11
# WTI유가                      10
# 소비자심리지수(CCSI)               7
# 전체임금총액(원)                   4
# 실업급여지급건수(월)                 0

# %% [markdown]
# # XGB 모델 성능 평가 결과

# %%
print("XGBClassifier 성능:")
print(f"정확도: {accuracy_score(y_test, y_pred_xgb):.2f}")
print(f"정밀도: {precision_score(y_test, y_pred_xgb):.2f}")
print(f"재현율: {recall_score(y_test, y_pred_xgb):.2f}")
print(f"F1 점수: {f1_score(y_test, y_pred_xgb):.2f}")
print(classification_report(y_test, y_pred_xgb))
# Out:
# XGBClassifier 성능:
# 정확도: 0.58
# 정밀도: 0.58
# 재현율: 0.79
# F1 점수: 0.67
#               precision    recall  f1-score   support
#
#            0       0.60      0.35      0.44        17
#            1       0.58      0.79      0.67        19
#
#     accuracy                           0.58        36
#    macro avg       0.59      0.57      0.56        36
# weighted avg       0.59      0.58      0.56        36
#               feature  importance
# 0          종합주택매매가격지수    0.168107
# 1           국내소매판매액지수    0.160789
# 2          건설기성액(십억원)    0.080407
# 3           미국생산자물가지수    0.078251
# 4      미국ISM(제조업물가지수)    0.073846
# 5               WTI유가    0.065729
# 6            국내설비투자지수    0.063563
# 7        미국취업자수증감(만명)    0.055181
# 8                 고용률    0.051540
# 9         실업급여지급건수(월)    0.049769
# 10               경상수지    0.036777
# 11            소비자물가지수    0.034102
# 12      소비자심리지수(CCSI)    0.030793
# 13  미국PMI(제조업구매담당자지수)    0.029878
# 14          전체임금총액(원)    0.021268

# %% [markdown]
# # Cat 모델 성능 평가 결과

# %%
print("CatBoostClassifier 성능:")
# print(f"정확도: {accuracy_score(y_test, y_pred_cat):.2f}")
# print(f"정밀도: {precision_score(y_test, y_pred_cat, average='macro'):.2f}")
# print(f"재현율: {recall_score(y_test, y_pred_cat, average='macro'):.2f}")
# print(f"F1 점수: {f1_score(y_test, y_pred_cat, average='macro'):.2f}")
print(f"정확도: {accuracy_score(y_test, y_pred_lgb):.2f}")
print(f"정밀도: {precision_score(y_test, y_pred_lgb):.2f}")
print(f"재현율: {recall_score(y_test, y_pred_lgb):.2f}")
print(f"F1 점수: {f1_score(y_test, y_pred_lgb):.2f}")
print(classification_report(y_test, y_pred_cat))
# Out:
# CatBoostClassifier 성능:
# 정확도: 0.64
# 정밀도: 0.67
# 재현율: 0.63
# F1 점수: 0.65
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59        17
#            1       0.63      0.63      0.63        19
#
#     accuracy                           0.61        36
#    macro avg       0.61      0.61      0.61        36
# weighted avg       0.61      0.61      0.61        36
#                    importance
# 종합주택매매가격지수          15.929697
# 건설기성액(십억원)          10.367585
# 국내설비투자지수             8.041834
# 미국PMI(제조업구매담당자지수)    6.729671
# 경상수지                 6.524646
# 미국취업자수증감(만명)         6.321242
# 미국생산자물가지수            5.864008
# 전체임금총액(원)            5.832573
# 고용률                  5.636860
# WTI유가                5.466824
# 소비자물가지수              5.357503
# 미국ISM(제조업물가지수)       5.160918
# 국내소매판매액지수            5.006793
# 실업급여지급건수(월)          4.218583
# 소비자심리지수(CCSI)        3.541262

# %% [markdown]
# ## Grid_ Search CV

# %%
# grid GridSearchCV불러오기
from sklearn.model_selection import GridSearchCV

# %%
# 데이터 가져오기
df = pd.read_excel('./data/filtered_features.xlsx')
train_data = df.drop(['날짜', 'label'], axis=1)
train_label = df['label']

# %%
# 변수 선언
rf_model = RandomForestClassifier(random_state=42)

# 옵션 설정
param_grid = {
    'n_estimators': [100],
    'max_depth': [None, 1,2.3,5,9,10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1],
    'max_features': ['sqrt', 'log2', None]
}
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5)

# 학습시키기, 지도학습이니까, feature, lable불러오기
grid_search.fit(train_data, train_label)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [None, 1, 2.3, 5, 9, 10],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [1], 'min_samples_split': [2, 5],
#                          'n_estimators': [100]})

# %%
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Best parameters found:  {'max_depth': 1, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best cross-validation score: 0.62

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=1, max_features=None, random_state=42)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 1,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
grid_search.best_score_
# Out:
# 0.6173913043478262

# %% [markdown]
# ## 시계열

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# 시계열 데이터를 위한 시계열 교차 검증 생성
tscv = TimeSeriesSplit(n_splits=5)

# %%
# GridSearchCV를 통해 모델 튜닝
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=tscv)

# %%
# 모델 학습
grid_search.fit(X_train, y_train)

# 최적의 하이퍼파라미터와 점수 확인
print("Best parameters found:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters found: {'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Best cross-validation score: 0.4769230769230769
