# %%
import pandas as pd
all_features = pd.read_csv('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/연결_개별_합(코스닥).csv', index_col=0)
all_features
# Out:
#             회사명  거래소코드     회계년도  총자본증가율  정상영업이익증가율  순이익증가율  자기자본증가율  매출액증가율  \
# 0      (주)CMG제약  58820  2012/12  109.15       0.00    0.00    75.17   -8.43
# 1      (주)CMG제약  58820  2013/12   -2.09       0.00    0.00    55.10   25.51
# 2      (주)CMG제약  58820  2014/12    3.86     -44.10  -46.64     0.01   11.52
# 3      (주)CMG제약  58820  2015/12   -2.64       0.00    0.00    -4.48   18.85
# 4      (주)CMG제약  58820  2016/12   96.31       0.00    0.00   116.01   21.92
# ...         ...    ...      ...     ...        ...     ...      ...     ...
# 13418   흥구석유(주)  24060  2018/12   -5.89      45.37   14.78     0.99    6.87
# 13419   흥구석유(주)  24060  2019/12   11.24     -54.16  249.94     9.31   -9.35
# 13420   흥구석유(주)  24060  2020/12    0.07       0.00  -42.22     3.38  -23.78
# 13421   흥구석유(주)  24060  2021/12   -1.28       0.00  -70.81    -0.88   15.12
# 13422   흥구석유(주)  24060  2022/12   13.66       0.00   89.95     1.51   10.97
#
# ...

# %%
# Reattempting to count the number of missing values in each column
missing_values_counts = all_features.isnull().sum()
missing_values_counts
# Out:
# 회사명                    0
# 거래소코드                  0
# 회계년도                   0
# 총자본증가율               428
# 정상영업이익증가율            428
# 순이익증가율               428
# 자기자본증가율              428
# 매출액증가율               428
# 종업원수증가율              532
# 매출액총이익률              428
# 매출액정상영업이익률           428
# 매출액순이익률              428
# 자기자본정상영업이익률          428
# 자기자본순이익률             428
# 금융비용부담률              428
# 수지비율(관계기업투자손익 제외)    428
# 사내유보 대 자기자본비율        532
# 총자본회전률               428
# 자기자본회전률              428
# 타인자본회전률              428
# 유동자산회전률              428
# 당좌자산회전률              428
# 재고자산회전률              428
# 매출채권회전률              428
# 순운전자본회전률             428
# 운전자본회전률              428
# 종업원1인당 부가가치          533
# 노동장비율                533
# 기계장비율                533
# 자본집약도                533
# 총자본투자효율              428
# 설비투자효율               428
# 1주당순이익               428
# 1주당 CASH FLOW        428
# 유보율                  428
# 기계투자효율               428
# 부가가치율                428
# ...

# %%
zero_counts = (all_features == 0).sum()
zero_counts
# Out:
# 회사명                     0
# 거래소코드                   0
# 회계년도                    0
# 총자본증가율               1029
# 정상영업이익증가율            5407
# 순이익증가율               6243
# 자기자본증가율              1078
# 매출액증가율               1050
# 종업원수증가율              1109
# 매출액총이익률               756
# 매출액정상영업이익률             24
# 매출액순이익률                25
# 자기자본정상영업이익률            77
# 자기자본순이익률               57
# 금융비용부담률                97
# 수지비율(관계기업투자손익 제외)       0
# 사내유보 대 자기자본비율         328
# 총자본회전률                 45
# 자기자본회전률               115
# 타인자본회전률                30
# 유동자산회전률                38
# 당좌자산회전률                38
# 재고자산회전률               919
# 매출채권회전률                88
# 순운전자본회전률               40
# 운전자본회전률              6278
# 종업원1인당 부가가치            33
# 노동장비율                7430
# 기계장비율                8062
# 자본집약도                7420
# 총자본투자효율                 0
# 설비투자효율                 10
# 1주당순이익                305
# 1주당 CASH FLOW           2
# 유보율                    13
# ...

# %%
HS_features = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스닥개별연결_재무피쳐(최종).xlsx')
HS_features
# Out:
#             회사명  거래소코드       회계년도     매출액증가율      총자본증가율  영업현금흐름 대 차입금비율  \
# 0      (주)CMG제약  58820 2012-12-01  -8.429134  109.147119       -0.061628
# 1      (주)CMG제약  58820 2013-12-01  25.510008   -2.093352       -0.569610
# 2      (주)CMG제약  58820 2014-12-01  11.520576    3.855597        0.079960
# 3      (주)CMG제약  58820 2015-12-01  18.851969   -2.644307        0.247812
# 4      (주)CMG제약  58820 2016-12-01  21.921286   96.310506        0.336434
# ...         ...    ...        ...        ...         ...             ...
# 13418   흥구석유(주)  24060 2018-12-01   0.000000    0.000000        0.402471
# 13419   흥구석유(주)  24060 2019-12-01   0.000000    0.000000        0.402471
# 13420   흥구석유(주)  24060 2020-12-01   0.000000    0.000000        0.402471
# 13421   흥구석유(주)  24060 2021-12-01   0.000000    0.000000        0.402471
# 13422   흥구석유(주)  24060 2022-12-01   0.000000    0.000000        0.402471
#
#          매출액총이익률      노동소득분배율  매출채권 대 매입채무비율    재고자산회전률
# ...

# %%
missing_values_counts = HS_features.isnull().sum()
missing_values_counts
# Out:
# 회사명                 0
# 거래소코드               0
# 회계년도                0
# 매출액증가율            788
# 총자본증가율            786
# 영업현금흐름 대 차입금비율      0
# 매출액총이익률             9
# 노동소득분배율             0
# 매출채권 대 매입채무비율       0
# 재고자산회전률             5
# dtype: int64

# %%
zero_counts2 = (HS_features == 0).sum()
zero_counts2
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 매출액증가율            2969
# 총자본증가율            2969
# 영업현금흐름 대 차입금비율       1
# 매출액총이익률              0
# 노동소득분배율            119
# 매출채권 대 매입채무비율        2
# 재고자산회전률              4
# dtype: int64

# %%
HK_features = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스닥효경개별연결피쳐(최종2).xlsx')
HK_features
# Out:
#             회사명  거래소코드       회계년도       순이익증가율     자기자본증가율    정상영업이익증가율  \
# 0      (주)CMG제약  58820 2012-12-01  -341.571868   75.170505  -341.571868
# 1      (주)CMG제약  58820 2013-12-01   104.447063   55.100407   104.672418
# 2      (주)CMG제약  58820 2014-12-01   -46.641074    0.010946   -51.708584
# 3      (주)CMG제약  58820 2015-12-01 -2409.614083   -4.480893 -2409.614083
# 4      (주)CMG제약  58820 2016-12-01   147.338409  116.010163   146.395090
# ...         ...    ...        ...          ...         ...          ...
# 13418   흥구석유(주)  24060 2018-12-01     0.000000    0.000000     0.000000
# 13419   흥구석유(주)  24060 2019-12-01     0.000000    0.000000     0.000000
# 13420   흥구석유(주)  24060 2020-12-01     0.000000    0.000000     0.000000
# 13421   흥구석유(주)  24060 2021-12-01     0.000000    0.000000     0.000000
# 13422   흥구석유(주)  24060 2022-12-01     0.000000    0.000000     0.000000
#
#          기계투자효율  사내유보 대 자기자본비율    1주당순이익
# 0      0.006543      -4.499535 -0.100872
# ...

# %%
zero_counts3 = (HK_features == 0).sum()
zero_counts3
# Out:
# 회사명                 0
# 거래소코드               0
# 회계년도                0
# 순이익증가율           2969
# 자기자본증가율          2969
# 정상영업이익증가율        2969
# 기계투자효율              0
# 사내유보 대 자기자본비율       0
# 1주당순이익              0
# dtype: int64

# %%
missing_values_counts = HK_features.isnull().sum()
missing_values_counts
# Out:
# 회사명                0
# 거래소코드              0
# 회계년도               0
# 순이익증가율           786
# 자기자본증가율          786
# 정상영업이익증가율        786
# 기계투자효율             0
# 사내유보 대 자기자본비율      0
# 1주당순이익             0
# dtype: int64

# %%
HM_features = pd.read_csv('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스닥_해미피쳐_연결_개별_수정.csv',index_col=0)
HM_features
# Out:
#             회사명  거래소코드     회계년도     자본집약도        기계장비율         노동장비율  \
# 0      (주)CMG제약  58820  2012/12  3.513176  1629.802531   1975.058302
# 1      (주)CMG제약  58820  2013/12  2.740524  1932.498068   2166.973242
# 2      (주)CMG제약  58820  2014/12  2.552164  3243.381771   3363.264195
# 3      (주)CMG제약  58820  2015/12  2.090564  3152.587768   2866.039720
# 4      (주)CMG제약  58820  2016/12  3.366104  1523.322604   2529.704680
# ...         ...    ...      ...       ...          ...           ...
# 13418   흥구석유(주)  24060  2018/12  0.452478    50.129136  10770.479102
# 13419   흥구석유(주)  24060  2019/12  0.555268    41.906371  10480.382034
# 13420   흥구석유(주)  24060  2020/12  0.729002    36.048388   9663.259680
# 13421   흥구석유(주)  24060  2021/12  0.625102    36.746132   9844.379686
# 13422   흥구석유(주)  24060  2022/12  0.640241    31.778910   9709.760699
#
#           운전자본회전률  재고자산 대 순운전자본비율
# 0        4.031983        7.330001
# 1        6.237351       14.120364
# ...

# %%
zero_counts3 = (HM_features == 0).sum()
zero_counts3
# Out:
# 회사명               0
# 거래소코드             0
# 회계년도              0
# 자본집약도             0
# 기계장비율             0
# 노동장비율             0
# 운전자본회전률           0
# 재고자산 대 순운전자본비율    0
# dtype: int64

# %%
missing_values_counts = HM_features.isnull().sum()
missing_values_counts
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 자본집약도              393
# 기계장비율              402
# 노동장비율              433
# 운전자본회전률            415
# 재고자산 대 순운전자본비율    1406
# dtype: int64

# %%
import pandas as pd

# 파일 경로 설정
file_path_all_features = 'C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/연결_개별_합(코스닥).csv'
file_path_HS = 'C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스닥개별연결_재무피쳐(최종).xlsx'
file_path_HK = 'C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스닥효경개별연결피쳐(최종2).xlsx'
file_path_HM = 'C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스닥_해미피쳐_연결_개별_수정.csv'

# CSV 파일 불러오기
all_features = pd.read_csv(file_path_all_features, index_col=0)

# 엑셀 파일 불러오기
HS_features = pd.read_excel(file_path_HS)
HK_features = pd.read_excel(file_path_HK)

# CSV 파일 불러오기
HM_features = pd.read_csv(file_path_HM, index_col=0)

# 필요한 컬럼들 선택
HS_columns = ['매출액증가율', '총자본증가율', '매출액총이익률', '노동소득분배율', '재고자산회전률']
HK_columns = ['순이익증가율', '자기자본증가율', '1주당순이익']
HM_columns = ['재고자산 대 순운전자본비율']

# all_features의 컬럼을 업데이트
all_features.update(HS_features[HS_columns])
all_features.update(HK_features[HK_columns])
all_features.update(HM_features[HM_columns])

all_features.to_excel('코스닥재무피쳐(최종).xlsx', index=False)
