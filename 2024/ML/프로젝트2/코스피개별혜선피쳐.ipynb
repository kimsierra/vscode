# %%
import pandas as pd
df = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스피개별혜선피쳐.xlsx')
df.head(4)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_14992\694727797.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                   회사명  거래소코드     회계년도  [제조]자산(*)(IFRS)  [제조]부채(*)(IFRS)  \
# 0  (주)HJ매그놀리아용평호텔앤리조트  70960  2016/12      928470114.0      532114901.0
# 1  (주)HJ매그놀리아용평호텔앤리조트  70960  2017/12      867690629.0      459554363.0
# 2  (주)HJ매그놀리아용평호텔앤리조트  70960  2018/12      812458177.0      398152851.0
# 3  (주)HJ매그놀리아용평호텔앤리조트  70960  2019/12      849651476.0      453811376.0
#
#    [제조]매출액(수익)(*)(IFRS)  [제조]매출총이익(손실)(IFRS)  \
# 0           209952933.0           48911195.0
# 1           209351156.0           47395448.0
# 2           181087610.0           41556494.0
# 3           129092848.0           13188991.0
#
#    [제조]      매입채무 및 기타유동채무(*)(IFRS)  [제조]      매출채권 및 기타유동채권(*)(IFRS)  \
# 0                        80105201.0                       144803354.0
# 1                        89393902.0                        93082110.0
# 2                        57957804.0                        26213375.0
# 3                        61492223.0                        25870249.0
#
#    [제조]매출원가(*)(IFRS)  [제조]판매비와 관리비(물류원가 등 포함)(*)(IFRS)  [제조]   급여(IFRS)  \
# 0        161041738.0                        18588903.0        3494795.0
# 1        161955708.0                        13830515.0        3549238.0
# 2        139531115.0                        16990706.0        4098324.0
# 3        115903858.0                        17406974.0        3933753.0
#
#    [제조]   금융비용(IFRS)  [제조]영업활동으로 인한 현금흐름(간접법)(*)(IFRS)  \
# 0                0.0                       -19047195.0
# 1                0.0                        17810277.0
# 2                0.0                        52429970.0
# 3                0.0                        23614041.0
#
#    [제조]      재고자산(*)(IFRS)  [제조]인건비(IFRS)  [제조]부가가치(IFRS)
# 0               14198271.0       19532.55        69525.07
# 1               14040984.0       20309.96        75331.84
# 2               13390230.0       23315.93        71632.23
# 3               15948793.0       23532.68        42571.41

# %%
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[제조]자산(*)(IFRS)', '[제조]부채(*)(IFRS)',
#        '[제조]매출액(수익)(*)(IFRS)', '[제조]매출총이익(손실)(IFRS)',
#        '[제조]      매입채무 및 기타유동채무(*)(IFRS)', '[제조]      매출채권 및 기타유동채권(*)(IFRS)',
#        '[제조]매출원가(*)(IFRS)', '[제조]판매비와 관리비(물류원가 등 포함)(*)(IFRS)',
#        '[제조]   급여(IFRS)', '[제조]   금융비용(IFRS)',
#        '[제조]영업활동으로 인한 현금흐름(간접법)(*)(IFRS)', '[제조]      재고자산(*)(IFRS)',
#        '[제조]인건비(IFRS)', '[제조]부가가치(IFRS)'],
#       dtype='object')

# %%
strs = ['(*)(IFRS)', '(*)(IFRS)','(수익)(*)(IFRS)','(손실)(IFRS)', '(*)(IFRS)','(수익)','[제조]',
        '(IFRS)','(물류원가 등 포함)','(*)(IFRS)','(간접법)','(*)(IFRS)']

for s in strs:

    # filterd_df.columns = filterd_df.columns.str.replace(s, "")
    df.columns = df.columns.str.replace(s, "")
    
df.columns =df.columns.str.strip()
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '자산', '부채', '매출액', '매출총이익', '매입채무 및 기타유동채무',
#        '매출채권 및 기타유동채권', '매출원가', '판매비와 관리비', '급여', '금융비용', '영업활동으로 인한 현금흐름',
#        '재고자산', '인건비', '부가가치'],
#       dtype='object')

# %%
df['회계년도'] = pd.to_datetime(df['회계년도'])
df.head(3)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_14992\2119935644.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['회계년도'] = pd.to_datetime(df['회계년도'])
#                   회사명  거래소코드       회계년도           자산           부채  \
# 0  (주)HJ매그놀리아용평호텔앤리조트  70960 2016-12-01  928470114.0  532114901.0
# 1  (주)HJ매그놀리아용평호텔앤리조트  70960 2017-12-01  867690629.0  459554363.0
# 2  (주)HJ매그놀리아용평호텔앤리조트  70960 2018-12-01  812458177.0  398152851.0
#
#            매출액       매출총이익  매입채무 및 기타유동채무  매출채권 및 기타유동채권         매출원가  \
# 0  209952933.0  48911195.0     80105201.0    144803354.0  161041738.0
# 1  209351156.0  47395448.0     89393902.0     93082110.0  161955708.0
# 2  181087610.0  41556494.0     57957804.0     26213375.0  139531115.0
#
#      판매비와 관리비         급여  금융비용  영업활동으로 인한 현금흐름        재고자산       인건비      부가가치
# 0  18588903.0  3494795.0   0.0     -19047195.0  14198271.0  19532.55  69525.07
# 1  13830515.0  3549238.0   0.0      17810277.0  14040984.0  20309.96  75331.84
# 2  16990706.0  4098324.0   0.0      52429970.0  13390230.0  23315.93  71632.23

# %%
# 전기매출액 구하기 (전기매출액은 현재 매출액의 한 칸 앞에 위치한 값)
df['전기매출액'] = df.groupby('회사명')['매출액'].shift(1)

# 매출액 증가율 계산 (분모에 절대값 적용)
df['매출액증가율'] = ((df['매출액'] - df['전기매출액']) / abs(df['전기매출액'])) * 100
# 새로운 파일로 저장
df.to_excel('코스피그룹화(개별절대값).xlsx', index=False)

# %%
# 데이터셋 불러오기
df = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스피그룹화(개별절대값).xlsx')

# 전기말자산 구하기 (전기말자산은 현재 자산의 한 칸 앞에 위치한 값)
df['전기말자산'] = df.groupby('회사명')['자산'].shift(1)

# 총자본증가율 계산
df['총자본증가율(%)'] = ((df['자산'] - df['전기말자산']) / abs(df['전기말자산'])) * 100

# 영업현금흐름 대 차입금비율 계산
df['영업현금흐름 대 차입금비율'] = df['영업활동으로 인한 현금흐름'] / df['부채']

# 매출액총이익률 계산
df['매출액총이익률(%)'] = (df['매출총이익'] / df['매출액']) * 100

# 노동소득분배율 계산
# df['노동소득분배율(%)'] = (df['급여'] / df['부가가치(백만원)']) * 100 / 1000
df['노동소득분배율'] = df['인건비'] / (
    (df['매출액'] - df['매출원가'] - df['판매비와 관리비']) +
    df['인건비'] + df['금융비용']) * 100 / 1000

# 매출채권 대 매입채무비율 계산
df['매출채권 대 매입채무비율'] = (df['매출채권 및 기타유동채권'] / df['매입채무 및 기타유동채무']) * 100

# 재고자산회전율 계산
df['재고자산회전율'] = df['매출액'] / ((df['재고자산'] + df['재고자산'].shift(1)) / 2)

# 결과를 새로운 파일로 저장
df.to_excel('코스피그룹화(절대값전체피쳐).xlsx', index=False)

# %%
df.head(4)
# Out:
#                   회사명  거래소코드       회계년도           자산           부채  \
# 0  (주)HJ매그놀리아용평호텔앤리조트  70960 2016-12-01  928470114.0  532114901.0
# 1  (주)HJ매그놀리아용평호텔앤리조트  70960 2017-12-01  867690629.0  459554363.0
# 2  (주)HJ매그놀리아용평호텔앤리조트  70960 2018-12-01  812458177.0  398152851.0
# 3  (주)HJ매그놀리아용평호텔앤리조트  70960 2019-12-01  849651476.0  453811376.0
#
#            매출액       매출총이익  매입채무 및 기타유동채무  매출채권 및 기타유동채권         매출원가  ...  \
# 0  209952933.0  48911195.0     80105201.0    144803354.0  161041738.0  ...
# 1  209351156.0  47395448.0     89393902.0     93082110.0  161955708.0  ...
# 2  181087610.0  41556494.0     57957804.0     26213375.0  139531115.0  ...
# 3  129092848.0  13188991.0     61492223.0     25870249.0  115903858.0  ...
#
#        부가가치        전기매출액     매출액증가율        전기말자산  총자본증가율(%)  영업현금흐름 대 차입금비율  \
# 0  69525.07          NaN        NaN          NaN        NaN       -0.035795
# 1  75331.84  209952933.0  -0.286625  928470114.0  -6.546197        0.038756
# 2  71632.23  209351156.0 -13.500545  867690629.0  -6.365454        0.131683
# 3  42571.41  181087610.0 -28.712490  812458177.0   4.577872        0.052035
#
#    매출액총이익률(%)   노동소득분배율  매출채권 대 매입채무비율    재고자산회전율
# 0   23.296267  0.000064     180.766482        NaN
# 1   22.639210  0.000060     104.125794  14.826960
# 2   22.948281  0.000095      45.228379  13.203033
# 3   10.216671 -0.000561      42.070766   8.800078
#
# [4 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# 회사명                 0
# 거래소코드               0
# 회계년도                0
# 자산                 26
# 부채                 26
# 매출액                26
# 매출총이익              26
# 매입채무 및 기타유동채무      26
# 매출채권 및 기타유동채권      26
# 매출원가               26
# 판매비와 관리비           26
# 급여                 26
# 금융비용               26
# 영업활동으로 인한 현금흐름     26
# 재고자산               26
# 인건비                77
# 부가가치               77
# 전기매출액             820
# 매출액증가율            820
# 전기말자산             820
# 총자본증가율(%)         820
# 영업현금흐름 대 차입금비율     26
# 매출액총이익률(%)         29
# 노동소득분배율            77
# 매출채권 대 매입채무비율      26
# 재고자산회전율            31
# dtype: int64

# %%
df['급여'].value_counts(ascending=True)
# Out:
# 급여
# 3494795.0       1
# 5982422.0       1
# 5519347.0       1
# 5330453.0       1
# 5391953.0       1
#                ..
# 151023000.0     2
# 2074079.0       2
# 15765000.0      2
# 11041000.0      2
# 0.0            41
# Name: count, Length: 8215, dtype: int64

# %%
list_1=list(df.columns)

# %%
import numpy as np
list_2 = []
cnt = 0
for i in list_1: 
    cnt = 0

    ind2 = np.where(df[i] == 0)
    cnt = len(df.iloc[ind2[0],:])
    list_2.append(cnt)
list_2
# Out:
# [0,
#  0,
#  0,
#  0,
#  0,
#  3,
#  3,
#  1,
#  4,
#  710,
#  0,
#  41,
#  8260,
#  1,
#  826,
#  106,
#  0,
#  3,
#  4,
#  0,
#  0,
#  1,
#  0,
#  106,
#  4,
#  3]

# %%
for pair in zip(list_1, list_2):
    print(pair)
# Out:
# ('회사명', 0)
# ('거래소코드', 0)
# ('회계년도', 0)
# ('자산', 0)
# ('부채', 0)
# ('매출액', 3)
# ('매출총이익', 3)
# ('매입채무 및 기타유동채무', 1)
# ('매출채권 및 기타유동채권', 4)
# ('매출원가', 710)
# ('판매비와 관리비', 0)
# ('급여', 41)
# ('금융비용', 8260)
# ('영업활동으로 인한 현금흐름', 1)
# ('재고자산', 826)
# ('인건비', 106)
# ('부가가치', 0)
# ('전기매출액', 3)
# ('매출액증가율', 4)
# ('전기말자산', 0)
# ('총자본증가율(%)', 0)
# ('영업현금흐름 대 차입금비율', 1)
# ('매출액총이익률(%)', 0)
# ('노동소득분배율', 106)
# ('매출채권 대 매입채무비율', 4)
# ('재고자산회전율', 3)

# %%
df.describe()
# Out:
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                거래소코드                           회계년도            자산  \
# count    8287.000000                           8287  8.261000e+03
# mean    43759.318209  2017-07-18 04:09:10.838662912  2.406986e+09
# min        20.000000            2011-03-01 00:00:00  6.882779e+06
# 25%      4490.000000            2014-12-01 00:00:00  1.875848e+08
# 50%     11720.000000            2017-12-01 00:00:00  4.053806e+08
# 75%     51630.000000            2020-12-01 00:00:00  1.108680e+09
# max    950070.000000            2022-12-01 00:00:00  2.600838e+11
# std     80856.606804                            NaN  1.022486e+10
#
#                  부채           매출액         매출총이익  매입채무 및 기타유동채무  매출채권 및 기타유동채권  \
# count  8.261000e+03  8.261000e+03  8.261000e+03   8.261000e+03   8.261000e+03
# mean   1.036494e+09  1.764052e+09  3.779608e+08   2.967223e+08   2.989137e+08
# min    5.521500e+04  0.000000e+00 -3.193181e+10   0.000000e+00   0.000000e+00
# 25%    5.562076e+07  1.121348e+08  1.622897e+07   1.344376e+07   1.924016e+07
# 50%    1.453736e+08  2.744766e+08  4.481720e+07   3.955442e+07   5.203283e+07
# 75%    4.454617e+08  8.393580e+08  1.447729e+08   1.353401e+08   1.500398e+08
# max    1.089631e+11  2.118675e+11  6.871536e+10   3.616651e+10   3.492074e+10
# std    3.876035e+09  7.698004e+09  2.285017e+09   1.237895e+09   1.241335e+09
#
#                매출원가      판매비와 관리비  ...          부가가치         전기매출액  \
# count  8.261000e+03  8.261000e+03  ...  8.210000e+03  7.467000e+03
# mean   1.386091e+09  2.683647e+08  ...  3.539493e+05  1.738789e+09
# min    0.000000e+00 -2.826160e+08  ... -2.719035e+07  0.000000e+00
# 25%    6.924801e+07  1.209854e+07  ...  1.797894e+04  1.115512e+08
# 50%    2.079279e+08  3.081831e+07  ...  5.060124e+04  2.704348e+08
# 75%    6.216479e+08  1.001240e+08  ...  1.521833e+05  8.180514e+08
# max    1.525894e+11  3.395876e+10  ...  7.298901e+07  1.997447e+11
# std    5.944356e+09  1.429130e+09  ...  2.267755e+06  7.499999e+09
#
#             매출액증가율         전기말자산    총자본증가율(%)  영업현금흐름 대 차입금비율   매출액총이익률(%)  \
# count  7467.000000  7.467000e+03  7467.000000     8261.000000  8258.000000
# mean           inf  2.359609e+09     5.089735        0.261172    26.553341
# min    -100.000000  7.109775e+06   -85.491020      -28.434114  -480.681169
# 25%      -6.500510  1.837939e+08    -2.409820        0.013455     9.463049
# 50%       2.526804  3.935728e+08     2.585985        0.107349    15.844660
# 75%      12.506765  1.071090e+09     8.850810        0.249519    31.569037
# max            inf  2.511122e+11   454.938423       82.704309   100.000000
# std            NaN  9.966593e+09    23.439728        2.001263    29.738572
#
#            노동소득분배율  매출채권 대 매입채무비율      재고자산회전율
# count  8210.000000    8261.000000  8256.000000
# mean      0.000259            inf          inf
# min      -0.414989       0.000000     0.000000
# 25%       0.000029      86.260052     5.683108
# 50%       0.000122     127.825856    10.348412
# 75%       0.000287     189.477404    27.172780
# max       0.645486            inf          inf
# std       0.009401            NaN          NaN
#
# [8 rows x 25 columns]
