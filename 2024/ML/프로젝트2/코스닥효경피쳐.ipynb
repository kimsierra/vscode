# %%
import pandas as pd
df1 = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥효경개별피쳐.xlsx')
df2 = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥효경연결피쳐.xlsx')
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_5596\78081189.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
common_columns = ['회사명', '거래소코드', '회계년도']

# 병합 (공통된 키를 기준으로 병합, 예를 들어 'ID' 열이 공통 열이라고 가정)
merged_df = pd.merge(df1, df2, on=common_columns, how='outer')

# '연결'이 포함된 열 이름만 선택
connected_columns = [col for col in merged_df.columns if '연결' in col]

# '연결'이 포함된 열을 기준으로 결측치 채우기
merged_df[connected_columns] = merged_df[connected_columns].fillna(method='ffill').fillna(method='bfill')

# '연결'이 포함되지 않은 열 제거
columns_to_drop = [col for col in merged_df.columns if '연결' not in col and col not in common_columns]
merged_df.drop(columns=columns_to_drop, inplace=True)

# # 결측치 채우기 (두 데이터프레임에서의 결측치를 서로 보완)
# merged_df.fillna(method='ffill', inplace=True)  # 앞의 값으로 채우기
# merged_df.fillna(method='bfill', inplace=True)  # 뒤의 값으로 채우기

merged_df.to_excel('코스닥효경개별연결피쳐1.xlsx', index=False)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_5596\3930958888.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_df[connected_columns] = merged_df[connected_columns].fillna(method='ffill').fillna(method='bfill')

# %%
merged_df = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥효경개별연결피쳐1.xlsx')
merged_df
# Out:
#             회사명  거래소코드     회계년도  [제조]자본(*)(IFRS연결)  [제조]당기순이익(손실)(IFRS연결)  \
# 0      (주)CMG제약  58820  2011/12           18034249               -1508282
# 1      (주)CMG제약  58820  2012/12           31590685               -6660149
# 2      (주)CMG제약  58820  2013/12           48997281                 296181
# 3      (주)CMG제약  58820  2014/12           49002644                 158039
# 4      (주)CMG제약  58820  2015/12           46806888               -3650091
# ...         ...    ...      ...                ...                    ...
# 14380   흥구석유(주)  24060  2018/12          849454435               60681762
# 14381   흥구석유(주)  24060  2019/12          849454435               60681762
# 14382   흥구석유(주)  24060  2020/12          849454435               60681762
# 14383   흥구석유(주)  24060  2021/12          849454435               60681762
# 14384   흥구석유(주)  24060  2022/12          849454435               60681762
#
#        [제조]계속영업이익(손실)(IFRS연결)  [제조]         기계장치(IFRS연결)  [제조]부가가치(IFRS연결)  \
# 0                    -1508282                    3944218           3472.17
# 1                    -6660149                    4288368            269.31
# 2                      311190                    4595388           6994.90
# 3                      158039                    7950710           7061.34
# 4                    -3650091                    8328336           4315.37
# ...                       ...                        ...               ...
# 14380                63908252                   45129871         132036.05
# 14381                63908252                   45129871         132036.05
# 14382                63908252                   45129871         132036.05
# 14383                63908252                   45129871         132036.05
# 14384                63908252                   45129871         132036.05
#
#        [제조]종업원수(IFRS연결)  [제조]      자본잉여금(*)(IFRS연결)  \
# 0                   NaN                    39417707
# 1                   NaN                    50958557
# 2                   NaN                    57681858
# 3                   NaN                    57681858
# 4                   NaN                    58464138
# ...                 ...                         ...
# 14380               NaN                   327289035
# 14381               NaN                   327289035
# 14382               NaN                   327289035
# 14383               NaN                   327289035
# 14384               NaN                   327289035
#
#        [제조]      이익잉여금(결손금)(*)(IFRS연결)  [제조]* 발행한 주식총수(*)(IFRS연결)
# 0                            -45215050                   43693200
# 1                            -52379991                   66025540
# 2                            -52201720                   86626866
# 3                            -52393918                   86626866
# 4                            -56413575                   88297244
# ...                                ...                        ...
# 14380                        899140037                   12385455
# 14381                        899140037                   12385455
# 14382                        899140037                   12385455
# 14383                        899140037                   12385455
# 14384                        899140037                   12385455
#
# [14385 rows x 12 columns]

# %%
merged_df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[제조]자본(*)(IFRS연결)', '[제조]당기순이익(손실)(IFRS연결)',
#        '[제조]계속영업이익(손실)(IFRS연결)', '[제조]         기계장치(IFRS연결)',
#        '[제조]부가가치(IFRS연결)', '[제조]종업원수(IFRS연결)', '[제조]      자본잉여금(*)(IFRS연결)',
#        '[제조]      이익잉여금(결손금)(*)(IFRS연결)', '[제조]* 발행한 주식총수(*)(IFRS연결)'],
#       dtype='object')

# %%
strs = ['(*)(IFRS연결)', '(손실)(IFRS연결)','(손실)(IFRS연결)','[제조]', '(IFRS연결)','(결손금)(*)(IFRS연결)',
       '(결손금)','*']

for s in strs:

    # filterd_df.columns = filterd_df.columns.str.replace(s, "")
    merged_df.columns = merged_df.columns.str.replace(s, "")
    
merged_df.columns =merged_df.columns.str.strip()
merged_df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '자본', '당기순이익', '계속영업이익', '기계장치', '부가가치', '종업원수',
#        '자본잉여금', '이익잉여금', '발행한 주식총수'],
#       dtype='object')

# %%
merged_df['회계년도'] = pd.to_datetime(merged_df['회계년도'])
merged_df.head(3)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_5596\3767706004.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   merged_df['회계년도'] = pd.to_datetime(merged_df['회계년도'])
#         회사명  거래소코드       회계년도        자본    당기순이익   계속영업이익     기계장치     부가가치  \
# 0  (주)CMG제약  58820 2011-12-01  18034249 -1508282 -1508282  3944218  3472.17
# 1  (주)CMG제약  58820 2012-12-01  31590685 -6660149 -6660149  4288368   269.31
# 2  (주)CMG제약  58820 2013-12-01  48997281   296181   311190  4595388  6994.90
#
#    종업원수     자본잉여금     이익잉여금  발행한 주식총수
# 0   NaN  39417707 -45215050  43693200
# 1   NaN  50958557 -52379991  66025540
# 2   NaN  57681858 -52201720  86626866

# %%
merged_df.isna().sum()
# Out:
# 회사명             0
# 거래소코드           0
# 회계년도            0
# 자본              0
# 당기순이익           0
# 계속영업이익          0
# 기계장치            0
# 부가가치            0
# 종업원수        14385
# 자본잉여금           0
# 이익잉여금           0
# 발행한 주식총수        0
# dtype: int64

# %%
# 전기매출액 구하기 (전기매출액은 현재 매출액의 한 칸 앞에 위치한 값)
merged_df['전기순이익'] = merged_df.groupby('회사명')['당기순이익'].shift(1)

# 매출액 증가율 계산 (분모에 절대값 적용)
merged_df['순이익증가율'] = ((merged_df['당기순이익'] - merged_df['전기순이익']) / abs(merged_df['전기순이익'])) * 100
# 새로운 파일로 저장
merged_df.to_excel('코스닥효경개별연결그룹화(절대값).xlsx', index=False)

# %%
# 데이터셋 불러오기
merged_df2 = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥효경개별연결그룹화(절대값).xlsx')

# 전기말자산 구하기 (전기말자산은 현재 자산의 한 칸 앞에 위치한 값)
merged_df2['전기말 정상영업이익'] = merged_df2.groupby('회사명')['계속영업이익'].shift(1)
merged_df2['전기말 종업원수'] = merged_df2.groupby('회사명')['종업원수'].shift(1)
merged_df2['전기말 자본'] = merged_df2.groupby('회사명')['자본'].shift(1)    

# 자기자본증가율
merged_df2['자기자본증가율'] = ((merged_df2['자본'] / merged_df2['전기말 자본']) * 100) - 100

# 정상영업이익증가율
merged_df2['정상영업이익증가율'] = ((merged_df2['계속영업이익'] - merged_df2['전기말 정상영업이익']) / abs(merged_df2['전기순이익'])) * 100

# 기계투자효율
merged_df2['기계장치평균'] = (merged_df2['기계장치'] + merged_df2['기계장치'].shift(1)) / 2
merged_df2['기계투자효율'] = (merged_df2['부가가치'] / merged_df2['기계장치평균']) * 100

# 종업원수증가율
merged_df2['종업원수증가율'] = (merged_df2['종업원수'] - merged_df2['전기말 종업원수']) / abs(merged_df2['전기말 종업원수']) * 100

# 사내유보 대 자기자본비율
merged_df2['사내유보 대 자기자본비율'] = ((merged_df2['자본잉여금']+ merged_df2['이익잉여금']) / merged_df2['자본']) * 100

# 1주당순이익
merged_df2['1주당순이익'] = merged_df2['당기순이익'] / merged_df2['발행한 주식총수']

# 결과를 새로운 파일로 저장
merged_df2.to_excel('코스닥효경개별연결그룹화(절대값전체피쳐).xlsx', index=False)

# %%
merged_df2.isna().sum()
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 자본                   0
# 당기순이익                0
# 계속영업이익               0
# 기계장치                 0
# 부가가치                 0
# 종업원수             14385
# 자본잉여금                0
# 이익잉여금                0
# 발행한 주식총수             0
# 전기순이익             1748
# 순이익증가율            1748
# 전기말 정상영업이익        1748
# 전기말 종업원수         14385
# 전기말 자본            1748
# 자기자본증가율           1748
# 정상영업이익증가율         1748
# 기계장치평균               1
# 기계투자효율               1
# 종업원수증가율          14385
# 사내유보 대 자기자본비율        0
# 1주당순이익               0
# dtype: int64

# %%
# '회계년도'가 2012-01-01 이후인 데이터만 선택
merged_df2_after_2012 = merged_df2[merged_df2['회계년도'] >= '2012-01-01']
merged_df2_after_2012
# Out:
#             회사명  거래소코드       회계년도         자본     당기순이익    계속영업이익      기계장치  \
# 1      (주)CMG제약  58820 2012-12-01   31590685  -6660149  -6660149   4288368
# 2      (주)CMG제약  58820 2013-12-01   48997281    296181    311190   4595388
# 3      (주)CMG제약  58820 2014-12-01   49002644    158039    158039   7950710
# 4      (주)CMG제약  58820 2015-12-01   46806888  -3650091  -3650091   8328336
# 5      (주)CMG제약  58820 2016-12-01  101107635   1727895   1693463   8523793
# ...         ...    ...        ...        ...       ...       ...       ...
# 14380   흥구석유(주)  24060 2018-12-01  849454435  60681762  63908252  45129871
# 14381   흥구석유(주)  24060 2019-12-01  849454435  60681762  63908252  45129871
# 14382   흥구석유(주)  24060 2020-12-01  849454435  60681762  63908252  45129871
# 14383   흥구석유(주)  24060 2021-12-01  849454435  60681762  63908252  45129871
# 14384   흥구석유(주)  24060 2022-12-01  849454435  60681762  63908252  45129871
#
#             부가가치  종업원수      자본잉여금  ...  전기말 정상영업이익  전기말 종업원수       전기말 자본  \
# 1         269.31   NaN   50958557  ...  -1508282.0       NaN   18034249.0
# 2        6994.90   NaN   57681858  ...  -6660149.0       NaN   31590685.0
# 3        7061.34   NaN   57681858  ...    311190.0       NaN   48997281.0
# 4        4315.37   NaN   58464138  ...    158039.0       NaN   49002644.0
# 5       10518.86   NaN  101107429  ...  -3650091.0       NaN   46806888.0
# ...          ...   ...        ...  ...         ...       ...          ...
# 14380  132036.05   NaN  327289035  ...  63908252.0       NaN  849454435.0
# 14381  132036.05   NaN  327289035  ...  63908252.0       NaN  849454435.0
# 14382  132036.05   NaN  327289035  ...  63908252.0       NaN  849454435.0
# 14383  132036.05   NaN  327289035  ...  63908252.0       NaN  849454435.0
# 14384  132036.05   NaN  327289035  ...  63908252.0       NaN  849454435.0
#
#           자기자본증가율    정상영업이익증가율      기계장치평균    기계투자효율  종업원수증가율  사내유보 대 자기자본비율  \
# 1       75.170505  -341.571868   4116293.0  0.006543      NaN      -4.499535
# 2       55.100407   104.672418   4441878.0  0.157476      NaN      11.184576
# 3        0.010946   -51.708584   6273049.0  0.112566      NaN      10.791132
# 4       -4.480893 -2409.614083   8139523.0  0.053017      NaN       4.380900
# 5      116.010163   146.395090   8426064.5  0.124837      NaN      46.050826
# ...           ...          ...         ...       ...      ...            ...
# 14380    0.000000     0.000000  45129871.0  0.292569      NaN     144.378441
# 14381    0.000000     0.000000  45129871.0  0.292569      NaN     144.378441
# 14382    0.000000     0.000000  45129871.0  0.292569      NaN     144.378441
# 14383    0.000000     0.000000  45129871.0  0.292569      NaN     144.378441
# 14384    0.000000     0.000000  45129871.0  0.292569      NaN     144.378441
#
#          1주당순이익
# 1     -0.100872
# 2      0.003419
# 3      0.001824
# 4     -0.041339
# 5      0.015895
# ...         ...
# 14380  4.899437
# 14381  4.899437
# 14382  4.899437
# 14383  4.899437
# 14384  4.899437
#
# [13423 rows x 24 columns]

# %%
merged_df2_after_2012.isna().sum()
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 자본                   0
# 당기순이익                0
# 계속영업이익               0
# 기계장치                 0
# 부가가치                 0
# 종업원수             13423
# 자본잉여금                0
# 이익잉여금                0
# 발행한 주식총수             0
# 전기순이익              786
# 순이익증가율             786
# 전기말 정상영업이익         786
# 전기말 종업원수         13423
# 전기말 자본             786
# 자기자본증가율            786
# 정상영업이익증가율          786
# 기계장치평균               0
# 기계투자효율               0
# 종업원수증가율          13423
# 사내유보 대 자기자본비율        0
# 1주당순이익               0
# dtype: int64

# %%
# 결과를 새로운 파일로 저장
merged_df2_after_2012.to_excel('코스닥효경개별연결그룹화(최종).xlsx', index=False)

# %%
merged_df2_after_2012.describe()
# Out:
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\core\_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                거래소코드                           회계년도            자본  \
# count   13423.000000                          13423  1.342300e+04
# mean   111974.264322  2018-05-14 16:48:57.286746624  1.259145e+08
# min       250.000000            2012-03-01 00:00:00 -5.429694e+08
# 25%     42075.000000            2015-12-01 00:00:00  3.798991e+07
# 50%     75970.000000            2018-12-01 00:00:00  7.000160e+07
# 75%    139670.000000            2020-12-01 00:00:00  1.348652e+08
# max    950220.000000            2022-12-01 00:00:00  5.437357e+09
# std    119168.201318                            NaN  2.332470e+08
#
#               당기순이익        계속영업이익          기계장치          부가가치  종업원수  \
# count  1.342300e+04  1.342300e+04  1.342300e+04  1.342300e+04   0.0
# mean   4.163825e+06  3.824894e+06  3.899796e+07  3.989220e+04   NaN
# min   -7.716168e+08 -7.716168e+08  0.000000e+00 -7.107779e+05   NaN
# 25%   -5.040427e+06 -4.938036e+06  5.138330e+05  6.588250e+03   NaN
# 50%    2.061917e+06  2.007859e+06  6.968524e+06  1.985949e+04   NaN
# 75%    1.010846e+07  9.960700e+06  3.059486e+07  4.539477e+04   NaN
# max    1.444437e+09  9.018288e+08  5.298704e+09  2.189782e+06   NaN
# std    4.124340e+07  3.673175e+07  1.404135e+08  8.858700e+04   NaN
#
#               자본잉여금         이익잉여금  ...    전기말 정상영업이익  전기말 종업원수        전기말 자본  \
# count  1.342300e+04  1.342300e+04  ...  1.263700e+04       0.0  1.263700e+04
# mean   5.348505e+07  4.971914e+07  ...  3.777235e+06       NaN  1.213100e+08
# min   -1.418795e+08 -9.121843e+08  ... -7.716168e+08       NaN -1.270834e+08
# 25%    1.530808e+07 -7.413777e+06  ... -4.500124e+06       NaN  3.746877e+07
# 50%    3.189695e+07  2.406357e+07  ...  2.107916e+06       NaN  6.837440e+07
# 75%    6.264204e+07  7.213468e+07  ...  9.706708e+06       NaN  1.289988e+08
# max    3.105014e+09  2.227903e+09  ...  9.018288e+08       NaN  5.437357e+09
# std    9.785455e+07  1.371928e+08  ...  3.446441e+07       NaN  2.234293e+08
#
#             자기자본증가율     정상영업이익증가율        기계장치평균        기계투자효율  종업원수증가율  \
# count  12637.000000  1.263700e+04  1.342300e+04  1.342300e+04      0.0
# mean      11.096478 -3.508745e+02  3.839686e+07           NaN      NaN
# min    -1558.450003 -3.011778e+06  0.000000e+00          -inf      NaN
# 25%        0.000000 -4.590167e+01  7.006892e+05  4.604855e-02      NaN
# 50%        1.060607  0.000000e+00  7.388998e+06  1.536828e-01      NaN
# 75%       12.727043  4.794758e+01  3.061305e+07  1.310777e+00      NaN
# max     6248.967365  2.598470e+04  5.298704e+09           inf      NaN
# std      111.342262  2.706356e+04  1.360432e+08           NaN      NaN
#
#        사내유보 대 자기자본비율        1주당순이익
# count   13423.000000  1.342300e+04
# mean      102.574131           inf
# min     -5297.727243 -4.163834e+01
# 25%        66.703311 -1.969131e-01
# 50%        86.386004  1.033733e-01
# 75%        95.038861  6.296403e-01
# max     10789.229997           inf
# std       570.095658           NaN
#
# [8 rows x 23 columns]
