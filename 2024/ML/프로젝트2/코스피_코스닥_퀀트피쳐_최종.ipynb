# %%
import pandas as pd
df1 = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스피_퀀트_개별연결피쳐_계산.xlsx')
df2 = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스닥_퀀트_개별연결피쳐_계산.xlsx')
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_4460\1926092114.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 두 데이터프레임을 세로로 이어붙이기
combined_df = pd.concat([df1, df2], axis=0)
combined_df.to_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스피_코스닥_퀀트피쳐_합.xlsx', index=False)

# %%
combined_df
# Out:
#                       회사명  거래소코드       회계년도     당기순이익    영업현금흐름          자산  \
# 0      (주)HJ매그놀리아용평호텔앤리조트  70960 2016-12-01  14321286 -18994098   928945970
# 1      (주)HJ매그놀리아용평호텔앤리조트  70960 2017-12-01  16953250  17809537   868156494
# 2      (주)HJ매그놀리아용평호텔앤리조트  70960 2018-12-01  10185942  52504906   812775928
# 3      (주)HJ매그놀리아용평호텔앤리조트  70960 2019-12-01 -13791548  23600746   849935619
# 4      (주)HJ매그놀리아용평호텔앤리조트  70960 2020-12-01 -17562113  50920805   911905132
# ...                   ...    ...        ...       ...       ...         ...
# 14380             흥구석유(주)  24060 2018-12-01  60681762  80626442  1049782929
# 14381             흥구석유(주)  24060 2019-12-01  60681762  80626442  1049782929
# 14382             흥구석유(주)  24060 2020-12-01  60681762  80626442  1049782929
# 14383             흥구석유(주)  24060 2021-12-01  60681762  80626442  1049782929
# 14384             흥구석유(주)  24060 2022-12-01  60681762  80626442  1049782929
#
# ...

# %%
combined_df.isna().sum()
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 당기순이익                0
# 영업현금흐름               0
# 자산                   0
# 자본                   0
# 유동비율                 0
# 부채비율                 0
# 매출액총이익률              0
# 총자본회전률               0
# 자기자본정상영업이익률          0
# 순이익증가율               0
# 타인자본회전률              0
# 순운전자본회전률             0
# CASH FLOW 대 부채비율     0
# CASH FLOW 대 총자본비율    0
# ROA                  0
# dtype: int64

# %%
# Count the number of zeros in each column
zero_counts = (combined_df == 0).sum()
zero_counts
# Out:
# 회사명                      0
# 거래소코드                    0
# 회계년도                     0
# 당기순이익                    0
# 영업현금흐름                   2
# 자산                       0
# 자본                       0
# 유동비율                     0
# 부채비율                   242
# 매출액총이익률               1130
# 총자본회전률                  27
# 자기자본정상영업이익률            263
# 순이익증가율               10348
# 타인자본회전률                 16
# 순운전자본회전률                23
# CASH FLOW 대 부채비율        14
# CASH FLOW 대 총자본비율       17
# ROA                      0
# dtype: int64
