# %%
import pandas as pd
df1 = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥혜선피쳐.xlsx')
df2 = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥개별혜선피쳐.xlsx')

# %%
common_columns = ['회사명', '거래소코드', '회계년도']

# 병합 (공통된 키를 기준으로 병합, 예를 들어 'ID' 열이 공통 열이라고 가정)
merged_df = pd.merge(df1, df2, on=common_columns, how='outer')

# '연결'이 포함된 열 이름만 선택
connected_columns = [col for col in merged_df.columns if '연결' in col]

# '연결'이 포함된 열을 기준으로 결측치 채우기
merged_df[connected_columns] = merged_df[connected_columns].fillna(method='ffill').fillna(method='bfill')

# '연결'이 포함되지 않은 열 제거
columns_to_drop = [col for col in merged_df.columns if '연결' not in col and col not in common_columns]
merged_df.drop(columns=columns_to_drop, inplace=True)

# # 결측치 채우기 (두 데이터프레임에서의 결측치를 서로 보완)
# merged_df.fillna(method='ffill', inplace=True)  # 앞의 값으로 채우기
# merged_df.fillna(method='bfill', inplace=True)  # 뒤의 값으로 채우기

merged_df.to_excel('코스닥개별연결피쳐1.xlsx', index=False)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_17360\1523222906.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_df[connected_columns] = merged_df[connected_columns].fillna(method='ffill').fillna(method='bfill')

# %%
merged_df = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥개별연결피쳐1.xlsx')
merged_df
# Out:
#             회사명  거래소코드     회계년도  부가가치(IFRS연결)(백만원)  부채(*)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12            3472.17            9270949
# 1      (주)CMG제약  58820  2012/12             269.31           25517350
# 2      (주)CMG제약  58820  2013/12            6994.90            6915281
# 3      (주)CMG제약  58820  2014/12            7061.34            9065682
# 4      (주)CMG제약  58820  2015/12            4315.37            9725933
# ...         ...    ...      ...                ...                ...
# 14380   흥구석유(주)  24060  2018/12          132036.05          200328493
# 14381   흥구석유(주)  24060  2019/12          132036.05          200328493
# 14382   흥구석유(주)  24060  2020/12          132036.05          200328493
# 14383   흥구석유(주)  24060  2021/12          132036.05          200328493
# 14384   흥구석유(주)  24060  2022/12          132036.05          200328493
#
#        영업활동으로 인한 현금흐름(간접법)(*)(IFRS연결)(천원)  자산(*)(IFRS연결)(천원)  급여(IFRS연결)(천원)  \
# 0                                -2560438           27305198         2531024
# 1                                -1572581           57108035         2612433
# 2                                -3939013           55912563         2746274
# 3                                  724893           58068326         3096733
# 4                                 2410205           56532821         3490274
# ...                                   ...                ...             ...
# 14380                            80626442         1049782929        26866091
# 14381                            80626442         1049782929        26866091
# 14382                            80626442         1049782929        26866091
# 14383                            80626442         1049782929        26866091
# 14384                            80626442         1049782929        26866091
#
#        매출총이익(손실)(IFRS연결)(천원)  매출액(수익)(*)(IFRS연결)(천원)  \
# 0                    7425905                17751704
# 1                    4606698                16255389
# 2                    7895323                20402140
# 3                    8434535                22752584
# 4                    9804080                27041894
# ...                      ...                     ...
# 14380              218856883               281675135
# 14381              218856883               281675135
# 14382              218856883               281675135
# 14383              218856883               281675135
# 14384              218856883               281675135
#
#        [제조]      매출채권 및 기타유동채권(*)(IFRS연결)  [제조]      매입채무 및 기타유동채무(*)(IFRS연결)  \
# 0                                 9533102                             3385786
# 1                                 9084190                             4414147
# 2                                11089670                             5423103
# 3                                13503998                             7034077
# 4                                12375263                             8667854
# ...                                   ...                                 ...
# 14380                            57709230                            24781948
# 14381                            57709230                            24781948
# 14382                            57709230                            24781948
# 14383                            57709230                            24781948
# 14384                            57709230                            24781948
#
#        [제조]      재고자산(*)(IFRS연결)  [제조]매출원가(*)(IFRS연결)  \
# 0                        2743103             10325799
# 1                        2955172             11648690
# 2                        4618718             12506817
# 3                        4913103             14318048
# 4                        5455617             17237814
# ...                          ...                  ...
# 14380                   26906647             62818252
# 14381                   26906647             62818252
# 14382                   26906647             62818252
# 14383                   26906647             62818252
# 14384                   26906647             62818252
#
#        [제조]판매비와 관리비(물류원가 등 포함)(*)(IFRS연결)  [제조]   금융비용(IFRS연결)  \
# 0                                 6802089                    0
# 1                                 8812202                    0
# 2                                 7104073                    0
# 3                                 7992213                    0
# 4                                12376249                    0
# ...                                   ...                  ...
# 14380                           117478389                    0
# 14381                           117478389                    0
# 14382                           117478389                    0
# 14383                           117478389                    0
# 14384                           117478389                    0
#
#        [제조]인건비(IFRS연결)  [제조]   이자비용(IFRS연결)
# 0              3118.67               181404
# 1              4712.51               542880
# 2              4986.26              1134104
# 3              5599.85               122840
# 4              6218.50                79830
# ...                ...                  ...
# 14380         53384.14              3111578
# 14381         53384.14              3111578
# 14382         53384.14              3111578
# 14383         53384.14              3111578
# 14384         53384.14              3111578
#
# [14385 rows x 18 columns]

# %%
merged_df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '부가가치(IFRS연결)(백만원)', '부채(*)(IFRS연결)(천원)',
#        '영업활동으로 인한 현금흐름(간접법)(*)(IFRS연결)(천원)', '자산(*)(IFRS연결)(천원)',
#        '급여(IFRS연결)(천원)', '매출총이익(손실)(IFRS연결)(천원)', '매출액(수익)(*)(IFRS연결)(천원)',
#        '[제조]      매출채권 및 기타유동채권(*)(IFRS연결)',
#        '[제조]      매입채무 및 기타유동채무(*)(IFRS연결)', '[제조]      재고자산(*)(IFRS연결)',
#        '[제조]매출원가(*)(IFRS연결)', '[제조]판매비와 관리비(물류원가 등 포함)(*)(IFRS연결)',
#        '[제조]   금융비용(IFRS연결)', '[제조]인건비(IFRS연결)', '[제조]   이자비용(IFRS연결)'],
#       dtype='object')

# %%
strs = ['(IFRS연결)', '(*)(IFRS연결)(천원)','(*)(천원)','(손실)(천원)', '(간접법)','(*)(IFRS연결)(천원)',
        '(수익)','(*)(IFRS연결)(천원)','(IFRS연결)(천원)','(손실)(IFRS연결)(천원)','(수익)(*)(IFRS연결)(천원)',
        '(*)(IFRS연결)','[제조]','(천원)','(*)','(물류원가 등 포함)']

for s in strs:

    # filterd_df.columns = filterd_df.columns.str.replace(s, "")
    merged_df.columns = merged_df.columns.str.replace(s, "")
    
merged_df.columns =merged_df.columns.str.strip()
merged_df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '부가가치(백만원)', '부채', '영업활동으로 인한 현금흐름', '자산', '급여',
#        '매출총이익', '매출액', '매출채권 및 기타유동채권', '매입채무 및 기타유동채무', '재고자산', '매출원가',
#        '판매비와 관리비', '금융비용', '인건비', '이자비용'],
#       dtype='object')

# %%
new_column_names = {'영업활동으로 인한 현금흐름': '영업현금흐름'}

# rename() 메서드를 사용하여 열 이름 변경
df = merged_df.rename(columns=new_column_names)

# 변경된 열 이름 출력
print(df.columns)
# Out:
# Index(['회사명', '거래소코드', '회계년도', '부가가치(백만원)', '부채', '영업현금흐름', '자산', '급여',
#        '매출총이익', '매출액', '매출채권 및 기타유동채권', '매입채무 및 기타유동채무', '재고자산', '매출원가',
#        '판매비와 관리비', '금융비용', '인건비', '이자비용'],
#       dtype='object')

# %%
df['회계년도'] = pd.to_datetime(df['회계년도'])
df.head(3)
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_17360\2119935644.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['회계년도'] = pd.to_datetime(df['회계년도'])
#         회사명  거래소코드       회계년도  부가가치(백만원)        부채   영업현금흐름        자산  \
# 0  (주)CMG제약  58820 2011-12-01    3472.17   9270949 -2560438  27305198
# 1  (주)CMG제약  58820 2012-12-01     269.31  25517350 -1572581  57108035
# 2  (주)CMG제약  58820 2013-12-01    6994.90   6915281 -3939013  55912563
#
#         급여    매출총이익       매출액  매출채권 및 기타유동채권  매입채무 및 기타유동채무     재고자산  \
# 0  2531024  7425905  17751704        9533102        3385786  2743103
# 1  2612433  4606698  16255389        9084190        4414147  2955172
# 2  2746274  7895323  20402140       11089670        5423103  4618718
#
#        매출원가  판매비와 관리비  금융비용      인건비     이자비용
# 0  10325799   6802089     0  3118.67   181404
# 1  11648690   8812202     0  4712.51   542880
# 2  12506817   7104073     0  4986.26  1134104

# %%
df.isna().sum()
# Out:
# 회사명              0
# 거래소코드            0
# 회계년도             0
# 부가가치(백만원)        0
# 부채               0
# 영업현금흐름           0
# 자산               0
# 급여               0
# 매출총이익            0
# 매출액              0
# 매출채권 및 기타유동채권    0
# 매입채무 및 기타유동채무    0
# 재고자산             0
# 매출원가             0
# 판매비와 관리비         0
# 금융비용             0
# 인건비              0
# 이자비용             0
# dtype: int64

# %%
# 전기매출액 구하기 (전기매출액은 현재 매출액의 한 칸 앞에 위치한 값)
df['전기매출액'] = df.groupby('회사명')['매출액'].shift(1)

# 매출액 증가율 계산 (분모에 절대값 적용)
df['매출액증가율'] = ((df['매출액'] - df['전기매출액']) / abs(df['전기매출액'])) * 100
# 새로운 파일로 저장
df.to_excel('코스닥개별연결그룹화(절대값).xlsx', index=False)

# %%
# 데이터셋 불러오기
df = pd.read_excel('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥개별연결그룹화(절대값).xlsx')

# 전기말자산 구하기 (전기말자산은 현재 자산의 한 칸 앞에 위치한 값)
df['전기말자산'] = df.groupby('회사명')['자산'].shift(1)

# 총자본증가율 계산
df['총자본증가율(%)'] = ((df['자산'] - df['전기말자산']) / abs(df['전기말자산'])) * 100

# 영업현금흐름 대 차입금비율 계산
df['영업현금흐름 대 차입금비율'] = df['영업현금흐름'] / df['부채']

# 매출액총이익률 계산
df['매출액총이익률(%)'] = (df['매출총이익'] / df['매출액']) * 100

# 노동소득분배율 계산
# df['노동소득분배율(%)'] = (df['급여'] / df['부가가치(백만원)']) * 100
df['노동소득분배율'] = df['인건비'] / df['부가가치(백만원)'] * 100

# 매출채권 대 매입채무비율 계산
df['매출채권 대 매입채무비율'] = (df['매출채권 및 기타유동채권'] / df['매입채무 및 기타유동채무']) * 100

# 재고자산회전율 계산
df['재고자산회전율'] = df['매출액'] / ((df['재고자산'] + df['재고자산'].shift(1)) / 2)

# 결과를 새로운 파일로 저장
df.to_excel('코스닥개별연결그룹화(절대값전체피쳐).xlsx', index=False)

# %%
df
# Out:
#             회사명  거래소코드       회계년도  부가가치(백만원)         부채    영업현금흐름          자산  \
# 0      (주)CMG제약  58820 2011-12-01    3472.17    9270949  -2560438    27305198
# 1      (주)CMG제약  58820 2012-12-01     269.31   25517350  -1572581    57108035
# 2      (주)CMG제약  58820 2013-12-01    6994.90    6915281  -3939013    55912563
# 3      (주)CMG제약  58820 2014-12-01    7061.34    9065682    724893    58068326
# 4      (주)CMG제약  58820 2015-12-01    4315.37    9725933   2410205    56532821
# ...         ...    ...        ...        ...        ...       ...         ...
# 14380   흥구석유(주)  24060 2018-12-01  132036.05  200328493  80626442  1049782929
# 14381   흥구석유(주)  24060 2019-12-01  132036.05  200328493  80626442  1049782929
# 14382   흥구석유(주)  24060 2020-12-01  132036.05  200328493  80626442  1049782929
# 14383   흥구석유(주)  24060 2021-12-01  132036.05  200328493  80626442  1049782929
# 14384   흥구석유(주)  24060 2022-12-01  132036.05  200328493  80626442  1049782929
#
#              급여      매출총이익        매출액  ...     이자비용        전기매출액     매출액증가율  \
# 0       2531024    7425905   17751704  ...   181404          NaN        NaN
# 1       2612433    4606698   16255389  ...   542880   17751704.0  -8.429134
# 2       2746274    7895323   20402140  ...  1134104   16255389.0  25.510008
# 3       3096733    8434535   22752584  ...   122840   20402140.0  11.520576
# 4       3490274    9804080   27041894  ...    79830   22752584.0  18.851969
# ...         ...        ...        ...  ...      ...          ...        ...
# 14380  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14381  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14382  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14383  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14384  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
#
#               전기말자산   총자본증가율(%)  영업현금흐름 대 차입금비율  매출액총이익률(%)      노동소득분배율  \
# 0               NaN         NaN       -0.276179   41.832069    89.819047
# 1      2.730520e+07  109.147119       -0.061628   28.339513  1749.845902
# 2      5.710804e+07   -2.093352       -0.569610   38.698504    71.284221
# 3      5.591256e+07    3.855597        0.079960   37.070669    79.302937
# 4      5.806833e+07   -2.644307        0.247812   36.255153   144.101201
# ...             ...         ...             ...         ...          ...
# 14380  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14381  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14382  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14383  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14384  1.049783e+09    0.000000        0.402471   77.698333    40.431488
#
#        매출채권 대 매입채무비율    재고자산회전율
# 0         281.562450        NaN
# 1         205.797179   5.705372
# 2         204.489386   5.387493
# 3         191.979673   4.774027
# 4         142.771936   5.216053
# ...              ...        ...
# 14380     232.868013  10.468608
# 14381     232.868013  10.468608
# 14382     232.868013  10.468608
# 14383     232.868013  10.468608
# 14384     232.868013  10.468608
#
# [14385 rows x 27 columns]

# %%
df.isna().sum()
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 부가가치(백만원)            0
# 부채                   0
# 영업현금흐름               0
# 자산                   0
# 급여                   0
# 매출총이익                0
# 매출액                  0
# 매출채권 및 기타유동채권        0
# 매입채무 및 기타유동채무        0
# 재고자산                 0
# 매출원가                 0
# 판매비와 관리비             0
# 금융비용                 0
# 인건비                  0
# 이자비용                 0
# 전기매출액             1748
# 매출액증가율            1750
# 전기말자산             1748
# 총자본증가율(%)         1748
# 영업현금흐름 대 차입금비율       0
# 매출액총이익률(%)           9
# 노동소득분배율              0
# 매출채권 대 매입채무비율        0
# 재고자산회전율              6
# dtype: int64

# %%
# '회계년도'가 2012-01-01 이후인 데이터만 선택
df_after_2012 = df[df['회계년도'] >= '2012-01-01']
df_after_2012
# Out:
#             회사명  거래소코드       회계년도  부가가치(백만원)         부채    영업현금흐름          자산  \
# 1      (주)CMG제약  58820 2012-12-01     269.31   25517350  -1572581    57108035
# 2      (주)CMG제약  58820 2013-12-01    6994.90    6915281  -3939013    55912563
# 3      (주)CMG제약  58820 2014-12-01    7061.34    9065682    724893    58068326
# 4      (주)CMG제약  58820 2015-12-01    4315.37    9725933   2410205    56532821
# 5      (주)CMG제약  58820 2016-12-01   10518.86    9872232   3321352   110979867
# ...         ...    ...        ...        ...        ...       ...         ...
# 14380   흥구석유(주)  24060 2018-12-01  132036.05  200328493  80626442  1049782929
# 14381   흥구석유(주)  24060 2019-12-01  132036.05  200328493  80626442  1049782929
# 14382   흥구석유(주)  24060 2020-12-01  132036.05  200328493  80626442  1049782929
# 14383   흥구석유(주)  24060 2021-12-01  132036.05  200328493  80626442  1049782929
# 14384   흥구석유(주)  24060 2022-12-01  132036.05  200328493  80626442  1049782929
#
#              급여      매출총이익        매출액  ...     이자비용        전기매출액     매출액증가율  \
# 1       2612433    4606698   16255389  ...   542880   17751704.0  -8.429134
# 2       2746274    7895323   20402140  ...  1134104   16255389.0  25.510008
# 3       3096733    8434535   22752584  ...   122840   20402140.0  11.520576
# 4       3490274    9804080   27041894  ...    79830   22752584.0  18.851969
# 5       3954558   13306436   32969825  ...        0   27041894.0  21.921286
# ...         ...        ...        ...  ...      ...          ...        ...
# 14380  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14381  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14382  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14383  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
# 14384  26866091  218856883  281675135  ...  3111578  281675135.0   0.000000
#
#               전기말자산   총자본증가율(%)  영업현금흐름 대 차입금비율  매출액총이익률(%)      노동소득분배율  \
# 1      2.730520e+07  109.147119       -0.061628   28.339513  1749.845902
# 2      5.710804e+07   -2.093352       -0.569610   38.698504    71.284221
# 3      5.591256e+07    3.855597        0.079960   37.070669    79.302937
# 4      5.806833e+07   -2.644307        0.247812   36.255153   144.101201
# 5      5.653282e+07   96.310506        0.336434   40.359438    63.532740
# ...             ...         ...             ...         ...          ...
# 14380  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14381  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14382  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14383  1.049783e+09    0.000000        0.402471   77.698333    40.431488
# 14384  1.049783e+09    0.000000        0.402471   77.698333    40.431488
#
#        매출채권 대 매입채무비율    재고자산회전율
# 1         205.797179   5.705372
# 2         204.489386   5.387493
# 3         191.979673   4.774027
# 4         142.771936   5.216053
# 5         141.718319   5.564822
# ...              ...        ...
# 14380     232.868013  10.468608
# 14381     232.868013  10.468608
# 14382     232.868013  10.468608
# 14383     232.868013  10.468608
# 14384     232.868013  10.468608
#
# [13423 rows x 27 columns]

# %%
df_after_2012.isna().sum()
# Out:
# 회사명                 0
# 거래소코드               0
# 회계년도                0
# 부가가치(백만원)           0
# 부채                  0
# 영업현금흐름              0
# 자산                  0
# 급여                  0
# 매출총이익               0
# 매출액                 0
# 매출채권 및 기타유동채권       0
# 매입채무 및 기타유동채무       0
# 재고자산                0
# 매출원가                0
# 판매비와 관리비            0
# 금융비용                0
# 인건비                 0
# 이자비용                0
# 전기매출액             786
# 매출액증가율            788
# 전기말자산             786
# 총자본증가율(%)         786
# 영업현금흐름 대 차입금비율      0
# 매출액총이익률(%)          9
# 노동소득분배율             0
# 매출채권 대 매입채무비율       0
# 재고자산회전율             5
# dtype: int64

# %%
# 결과를 새로운 파일로 저장
df_after_2012.to_excel('코스닥개별연결그룹화(최종).xlsx', index=False)

# %%
df_after_2012.describe()
# Out:
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# C:\Users\SAMSUNG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                거래소코드                           회계년도     부가가치(백만원)  \
# count   13423.000000                          13423  1.342300e+04
# mean   111974.264322  2018-05-14 16:48:57.286746624  3.989220e+04
# min       250.000000            2012-03-01 00:00:00 -7.107779e+05
# 25%     42075.000000            2015-12-01 00:00:00  6.588250e+03
# 50%     75970.000000            2018-12-01 00:00:00  1.985949e+04
# 75%    139670.000000            2020-12-01 00:00:00  4.539477e+04
# max    950220.000000            2022-12-01 00:00:00  2.189782e+06
# std    119168.201318                            NaN  8.858700e+04
#
#                  부채        영업현금흐름            자산            급여         매출총이익  \
# count  1.342300e+04  1.342300e+04  1.342300e+04  1.342300e+04  1.342300e+04
# mean   1.283590e+08  9.700240e+06  2.542736e+08  8.875693e+06  4.390099e+07
# min    6.989380e+05 -3.421598e+09  1.473202e+06  0.000000e+00 -1.296306e+08
# 25%    2.199540e+07 -2.092882e+06  6.970657e+07  2.620854e+06  7.893859e+06
# 50%    4.374306e+07  3.850784e+06  1.214291e+08  4.653052e+06  1.916461e+07
# 75%    1.007100e+08  1.423435e+07  2.322375e+08  9.152992e+06  4.432721e+07
# max    4.443757e+10  1.650761e+09  4.987493e+10  3.966866e+08  2.492160e+09
# std    9.013856e+08  7.168661e+07  1.060725e+09  1.619744e+07  1.046755e+08
#
#                 매출액  매출채권 및 기타유동채권  ...          이자비용         전기매출액  \
# count  1.342300e+04   1.342300e+04  ...  1.342300e+04  1.263700e+04
# mean   1.876714e+08   3.657814e+07  ...  2.272295e+06  1.832772e+08
# min    0.000000e+00   0.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%    3.845258e+07   6.877103e+06  ...  2.210230e+05  3.898176e+07
# 50%    8.335792e+07   1.513164e+07  ...  9.171320e+05  8.432942e+07
# 75%    1.859890e+08   3.451146e+07  ...  2.415770e+06  1.828511e+08
# max    1.377530e+10   4.637332e+09  ...  2.228780e+08  1.080870e+10
# std    4.143427e+08   9.964299e+07  ...  5.509530e+06  3.880287e+08
#
#              매출액증가율         전기말자산     총자본증가율(%)  영업현금흐름 대 차입금비율    매출액총이익률(%)  \
# count  1.263500e+04  1.263700e+04  12637.000000    13423.000000  13414.000000
# mean            inf  2.478522e+08      9.607374        0.128728     28.064737
# min   -1.000000e+02  1.473202e+06    -99.753423      -29.680404  -3097.372431
# 25%   -4.331656e+00  6.875016e+07     -0.798756       -0.051481     12.273449
# 50%    0.000000e+00  1.190503e+08      0.000000        0.085079     21.865599
# 75%    1.508427e+01  2.275806e+08     12.386384        0.273403     39.631671
# max             inf  4.987493e+10   6181.288402        6.334435    100.000000
# std             NaN  1.077591e+09     77.265345        0.625588     40.491085
#
#              노동소득분배율  매출채권 대 매입채무비율       재고자산회전율
# count   13423.000000   1.342300e+04  1.341800e+04
# mean       63.905772            inf           inf
# min    -55652.788714   0.000000e+00  0.000000e+00
# 25%        36.912364   8.526864e+01  4.664161e+00
# 50%        56.662048   1.264862e+02  8.327767e+00
# 75%        76.800083   1.923608e+02  2.291341e+01
# max    116879.942693            inf           inf
# std      1556.789272            NaN           NaN
#
# [8 rows x 26 columns]
