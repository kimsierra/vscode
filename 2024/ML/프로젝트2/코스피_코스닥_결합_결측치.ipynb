# %%
import pandas as pd
all_features2 = pd.read_csv('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스피_코스닥_결합_결측치.csv', index_col=0)
all_features2
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_10944\5507628.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#               회사명   거래소코드     회계년도     총자본증가율  정상영업이익증가율       순이익증가율  \
# 0         (주)ES큐브   50120  2012/12 -16.575097        0.0    92.510776
# 1         (주)ES큐브   50120  2013/12   1.849357        0.0 -4481.062648
# 2         (주)ES큐브   50120  2014/12  20.099174        0.0    96.260255
# 3         (주)ES큐브   50120  2015/12  -1.751499        0.0  -274.898482
# 4         (주)ES큐브   50120  2016/12  89.076046        0.0  1033.661139
# ...

# %%
missing_values_counts = all_features2.isnull().sum()
missing_values_counts
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 총자본증가율               0
# 정상영업이익증가율            0
# 순이익증가율               0
# 자기자본증가율              0
# 매출액증가율               0
# 종업원수증가율              0
# 매출액총이익률              0
# 매출액정상영업이익률           0
# 매출액순이익률              0
# 자기자본정상영업이익률          0
# 자기자본순이익률             0
# 금융비용부담률              0
# 수지비율(관계기업투자손익 제외)    0
# 사내유보 대 자기자본비율        0
# 총자본회전률               0
# 자기자본회전률              0
# 타인자본회전률              0
# 유동자산회전률              0
# 당좌자산회전률              0
# 재고자산회전률              0
# 매출채권회전률              0
# 순운전자본회전률             0
# 운전자본회전률              0
# 종업원1인당 부가가치          0
# 노동장비율                0
# 기계장비율                0
# 자본집약도                0
# 총자본투자효율              0
# 설비투자효율               0
# 1주당순이익               0
# 1주당 CASH FLOW        0
# 유보율                  0
# 기계투자효율               0
# 부가가치율                0
# 노동소득분배율              0
# 자기자본구성비율             0
# 유동비율                 0
# ...

# %%
all_features3 = pd.read_csv('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/코스피_코스닥_결합_결측치_시장지표_결합.csv', index_col=0)
all_features3
# Out:
#               회사명   거래소코드  회계년도     총자본증가율  정상영업이익증가율       순이익증가율    자기자본증가율  \
# 0         (주)ES큐브   50120  2012 -16.575097        0.0    92.510776   1.564118
# 1         (주)ES큐브   50120  2013   1.849357        0.0 -4481.062648   6.304012
# 2         (주)ES큐브   50120  2014  20.099174        0.0    96.260255  17.123515
# 3         (주)ES큐브   50120  2015  -1.751499        0.0  -274.898482   0.053133
# 4         (주)ES큐브   50120  2016  89.076046        0.0  1033.661139  44.390095
# ...           ...     ...   ...        ...        ...          ...        ...
# 12460  한화화인케미칼(주)   25850  2013   0.000000        0.0     0.000000   0.000000
# 12461  핸즈코퍼레이션(주)  143210  2022  -3.617503        0.0   -21.656986 -25.683177
# 12462     현대로템(주)   64350  2015  14.613589        0.0 -1915.359835 -17.312414
# 12463    현대페인트(주)   11720  2012   0.000000        0.0     0.000000   0.000000
# 12464     흥아해운(주)    3280  2018  -5.331246        0.0   -17.741050 -37.418411
#
# ...

# %%
missing_values_counts = all_features3.isnull().sum()
missing_values_counts
# Out:
# 회사명           0
# 거래소코드         0
# 회계년도          0
# 총자본증가율        0
# 정상영업이익증가율     0
#              ..
# 수출물가지수증감률     0
# 수입물가지수증감률     0
# 3년국고채수익률      0
# 생산자물가지수       0
# 생산자물가지수증감률    0
# Length: 75, dtype: int64

# %%
all_features3.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '총자본증가율', '정상영업이익증가율', '순이익증가율', '자기자본증가율',
#        '매출액증가율', '종업원수증가율', '매출액총이익률', '매출액정상영업이익률', '매출액순이익률', '자기자본정상영업이익률',
#        '자기자본순이익률', '금융비용부담률', '수지비율(관계기업투자손익 제외)', '사내유보 대 자기자본비율', '총자본회전률',
#        '자기자본회전률', '타인자본회전률', '유동자산회전률', '당좌자산회전률', '재고자산회전률', '매출채권회전률',
#        '순운전자본회전률', '운전자본회전률', '종업원1인당 부가가치', '노동장비율', '기계장비율', '자본집약도',
#        '총자본투자효율', '설비투자효율', '1주당순이익', '1주당 CASH FLOW', '유보율', '기계투자효율',
#        '부가가치율', '노동소득분배율', '자기자본구성비율', '유동비율', '당좌비율', '현금비율',
#        '재고자산 대 순운전자본비율', '매출채권 대 매입채무비율', '부채비율', 'CASH FLOW 대 부채비율',
#        'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '1주당매출액',
#        '1주당순자산', '총자산영업이익률', '총자산순이익률', '부실', 'CP전년대비증가율', '경기선행지수', '경기동행지수',
#        'GDP대비국가부채비율', 'CPI', 'CPI증감률', '실질GDP성장률', '코스닥연수익률 (%)', '코스피연수익률(%)',
#        '코스닥변동성', '코스피변동성', '장단기금리차(전월차)(%p)', '실업률', '외환보유액(천달러)', 'CD이자율',
#        '환율', '수출물가지수증감률', '수입물가지수증감률', '3년국고채수익률', '생산자물가지수', '생산자물가지수증감률'],
# ...
