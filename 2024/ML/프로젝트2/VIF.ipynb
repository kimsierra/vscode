# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split,GridSearchCV


all_features = pd.read_csv('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/data/윈저라이징_inf제거.csv',index_col=0)
all_features = all_features.drop(columns = ['코스닥연수익률 (%)', '코스피연수익률(%)','코스닥변동성', '코스피변동성'])
X_data = all_features.drop(columns=['회사명', '거래소코  드', '회계년도', '부실'])
y_data = all_features['부실']
X_train,X_test,y_train,y_test = train_test_split(X_data,y_data,test_size=0.3, stratify=y_data,random_state = 42)

feature =['순이익증가율',
        '종업원수증가율',
        #'외환보유액(천달러)',
        #'환율',
        '총자본투자효율',
        '부가가치율',
        '매출액순이익률',
        '자기자본정상영업이익률',
        'CASH FLOW 대 매출액비율',
        'CASH FLOW 대 차입금비율']

X_train  = X_train.loc[:,feature]

vif_data = pd.DataFrame()
vif_data["feature"] = X_train.columns
vif_data["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]

vif_data.sort_values('VIF' , ascending=False).reset_index(drop=True)
# Out:
#              feature       VIF
# 0            총자본투자효율  7.541229
# 1              부가가치율  7.442638
# 2        자기자본정상영업이익률  3.182181
# 3  CASH FLOW 대 매출액비율  2.688186
# 4            매출액순이익률  1.995791
# 5             순이익증가율  1.115256
# 6  CASH FLOW 대 차입금비율  1.093726
# 7            종업원수증가율  1.072000
