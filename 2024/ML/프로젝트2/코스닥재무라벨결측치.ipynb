# %%
import pandas as pd

# 파일을 불러옵니다 (엑셀 파일의 경우)
df = pd.read_csv('C:/Users/SAMSUNG/Documents/vscode/2024/ML/프로젝트2/코스닥_재무_라벨_결측치처리전.csv')
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_5608\863209055.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df
# Out:
#        Unnamed: 0       회사명  거래소코드     회계년도  총자본증가율  정상영업이익증가율  순이익증가율  \
# 0               0  (주)CMG제약  58820  2012/12  109.15       0.00    0.00
# 1               1  (주)CMG제약  58820  2013/12   -2.09       0.00    0.00
# 2               2  (주)CMG제약  58820  2014/12    3.86     -44.10  -46.64
# 3               3  (주)CMG제약  58820  2015/12   -2.64       0.00    0.00
# 4               4  (주)CMG제약  58820  2016/12   96.31       0.00    0.00
# ...           ...       ...    ...      ...     ...        ...     ...
# 16499       16499   흥구석유(주)  24060  2018/12   -5.89      45.37   14.78
# 16500       16500   흥구석유(주)  24060  2019/12   11.24     -54.16  249.94
# 16501       16501   흥구석유(주)  24060  2020/12    0.07       0.00  -42.22
# 16502       16502   흥구석유(주)  24060  2021/12   -1.28       0.00  -70.81
# 16503       16503   흥구석유(주)  24060  2022/12   13.66       0.00   89.95
#
#        자기자본증가율  매출액증가율  종업원수증가율  ...  CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  \
# ...

# %%
df1 = pd.DataFrame(df)

# '회계년도'가 '2012/12'이고 '부실'이 1인 데이터 필터링
result = df[(df['회계년도'] == '2012/12') & (df['부실'] == 1)]

# %%
result
# Out:
#        Unnamed: 0           회사명  거래소코드     회계년도  총자본증가율  정상영업이익증가율  순이익증가율  \
# 0               0      (주)CMG제약  58820  2012/12  109.15       0.00     0.0
# 247           247         (주)금빛  45890  2012/12  -10.15       0.00     0.0
# 330           330       (주)나노엔텍  39860  2012/12    0.00       0.00     0.0
# 341           341     (주)나노트로닉스  10670  2012/12    6.24     670.24     0.0
# 757           757        (주)뉴인텍  12340  2012/12  -17.03       0.00     0.0
# ...           ...           ...    ...      ...     ...        ...     ...
# 15178       15178       잘만테크(주)  90120  2012/12    0.00       0.00     0.0
# 15247       15247    제이스코홀딩스(주)  23440  2012/12   28.26       0.00     0.0
# 15753       15753        큐렉소(주)  60280  2012/12  -41.60       0.00     0.0
# 16197       16197      한성크린텍(주)  66980  2012/12  -32.37       0.00     0.0
# 16368       16368  현대바이오사이언스(주)  48410  2012/12    5.21       0.00     0.0
#
# ...

# %%
insolvent_2012_companies = df[(df['회계년도'] == '2012/12') & (df['부실'] == 1)]['회사명']

# 2012년도 이후 해당 회사들의 행 제거
df_filtered = df[~((df['회사명'].isin(insolvent_2012_companies)) & (df['회계년도'] > '2012/12'))]

# %%
df_filtered
# Out:
#        Unnamed: 0       회사명  거래소코드     회계년도  총자본증가율  정상영업이익증가율  순이익증가율  \
# 0               0  (주)CMG제약  58820  2012/12  109.15       0.00    0.00
# 11             11   (주)ES큐브  50120  2012/12    0.00       0.00    0.00
# 12             12   (주)ES큐브  50120  2013/12    1.85       0.00    0.00
# 13             13   (주)ES큐브  50120  2014/12   20.10       0.00    0.00
# 14             14   (주)ES큐브  50120  2015/12   -1.75       0.00    0.00
# ...           ...       ...    ...      ...     ...        ...     ...
# 16499       16499   흥구석유(주)  24060  2018/12   -5.89      45.37   14.78
# 16500       16500   흥구석유(주)  24060  2019/12   11.24     -54.16  249.94
# 16501       16501   흥구석유(주)  24060  2020/12    0.07       0.00  -42.22
# 16502       16502   흥구석유(주)  24060  2021/12   -1.28       0.00  -70.81
# 16503       16503   흥구석유(주)  24060  2022/12   13.66       0.00   89.95
#
#        자기자본증가율  매출액증가율  종업원수증가율  ...  CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  \
# ...

# %%
num_rows_with_nan = df.isna().any(axis=1).sum()

# %%
num_rows_with_nan
# Out:
# 2248
