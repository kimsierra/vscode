# %% [markdown]
# #### Data Scaling(편차가 심할 때)
# - 표준화 : 평균 0 표준편차 1
# - 정규화 : 제일 큰 값 1 작은값 0
#   - min-max scaling
# - Robust : 이상치에 민감하지 않다.

# %% [markdown]
# #### sklearn.preprocessing.StandardScaler
# - class sklearn.preprocessing.StandardScaler(*, copy=True, with_mean=True, with_std=True)
# - 실수형 변수들만 스케일링
# - 카테고리는 스케일링 할 수 없다.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

iris = load_iris()
dt_clf = DecisionTreeClassifier()
X = iris.data
y = iris.target

X_train , X_test , y_train, y_test = train_test_split(X, y , test_size=0.3 , random_state=0)

train_df = pd.DataFrame(X_train, columns=iris.feature_names)
train_df['label'] = y_train
train_df.describe()
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_4432\1199636677.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         105.000000        105.000000         105.000000
# mean            5.893333          3.044762           3.828571
# std             0.876868          0.441366           1.804573
# min             4.300000          2.000000           1.100000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.400000
# 75%             6.500000          3.300000           5.200000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)       label
# count        105.000000  105.000000
# mean           1.227619    1.047619
# std            0.780100    0.836441
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.900000    2.000000
# max            2.500000    2.000000

# %%
scaler = StandardScaler()
scaler.fit(X_train)
scaled_X_train = scaler.transform(X_train)
scaled_train_df = pd.DataFrame(scaled_X_train, columns=iris.feature_names)

# %%
scaled_train_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count       1.050000e+02      1.050000e+02       1.050000e+02
# mean        2.816794e-15     -1.023520e-15      -3.573861e-16
# std         1.004796e+00      1.004796e+00       1.004796e+00
# min        -1.825788e+00     -2.378463e+00      -1.519284e+00
# 25%        -9.090745e-01     -5.572150e-01      -1.240881e+00
# 50%        -1.069499e-01     -1.019031e-01       3.181746e-01
# 75%         6.951746e-01      5.810647e-01       7.636190e-01
# max         2.299424e+00      3.085280e+00       1.710188e+00
#
#        petal width (cm)
# count      1.050000e+02
# mean       2.749124e-17
# std        1.004796e+00
# min       -1.452412e+00
# 25%       -1.194805e+00
# 50%        9.322915e-02
# 75%        8.660497e-01
# max        1.638870e+00

# %%
from sklearn.metrics import accuracy_score
dt_clf.fit(scaled_X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
scaled_X_test = scaler.transform(X_test)
pred = dt_clf.predict(scaled_X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9777777777777777

# %%
from sklearn.metrics import accuracy_score
dt_clf.fit(X_train, y_train)
pred = dt_clf.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9777777777777777

# %% [markdown]
# #### sklearn.preprocessing.MinMaxScaler
# - class sklearn.preprocessing.MinMaxScaler(feature_range=(0, 1), *, copy=True, clip=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
scaled_X_train = scaler.transform(X_train)

# %%
from sklearn.metrics import accuracy_score
dt_clf.fit(scaled_X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
scaled_X_test = scaler.transform(X_test)
pred = dt_clf.predict(scaled_X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9777777777777777

# %% [markdown]
# #### sklearn.preprocessing.RobustScaler
# - class sklearn.preprocessing.RobustScaler(*, with_centering=True, with_scaling=True, quantile_range=(25.0, 75.0), copy=True, unit_variance=False)

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(X_train)
scaled_X_train = scaler.transform(X_train)

# %%
from sklearn.metrics import accuracy_score
dt_clf.fit(scaled_X_train, y_train)
scaled_X_test = scaler.transform(X_test)
pred = dt_clf.predict(scaled_X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9777777777777777
