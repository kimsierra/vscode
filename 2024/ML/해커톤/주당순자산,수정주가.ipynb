# %%
from pykrx import stock
import pandas as pd
import time

# %%
df = stock.get_market_ohlcv_by_ticker("20221229", market="KOSPI")

# %%
df.head()
# Out:
#             시가      고가      저가      종가      거래량         거래대금   등락률
# 티커
# 095570    5700    5750    5510    5720   112525    631964430 -0.17
# 006840   17250   17250   16600   17200    11782    198942500 -0.86
# 027410    4355    4360    4255    4305   144565    624224765 -0.92
# 282330  207000  212500  206500  210500    33874   7124135000 -0.71
# 138930    6560    6580    6470    6500  3097584  20179012670 -2.11

# %%
df = stock.get_market_fundamental_by_ticker("20221229")
print(df.head())
# Out:
#           BPS    PER   PBR   EPS   DIV   DPS
# 티커
# 095570   8075   3.35  0.71  1707  4.72   270
# 006840  45961   0.00  0.37     0  1.16   200
# 027410  16393   6.29  0.26   684  2.56   110
# 282330  46849  24.63  4.49  8547  1.43  3000
# 138930  28745   2.78  0.23  2341  8.62   560

# %%
df = stock.get_market_fundamental_by_date("20000101", "20230331", "ALL", freq="m")
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
code = pd.read_csv('csv/code.csv')
code
# Out:
#      Unnamed: 0    종목코드       종목명
# 0             0    5930      삼성전자
# 1             1  207940  삼성바이오로직스
# 2             2    6400     삼성SDI
# 3             3     270        기아
# 4             4   35720       카카오
# ..          ...     ...       ...
# 538         538    1210      금호전기
# 539         539   25620   제이준코스메틱
# 540         540   71950       코아스
# 541         541    8500      일정실업
# 542         542   30790     비케이탑스
#
# [543 rows x 3 columns]

# %%
code = pd.read_csv('csv/code.csv')
a = []

for i in code.index :
    df = stock.get_market_fundamental_by_date("20240101", "20240327",str(code.loc[i, '종목코드']), freq="m")
    a.append(df)
a
# Out:
# [Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
# ...

# %%
df = stock.get_market_fundamental_by_ticker("20231228")
print(df.head())
# Out:
#           BPS    PER   PBR    EPS   DIV   DPS
# 티커
# 095570   8076  24.78  0.62    201  5.42   270
# 006840  41948   0.00  0.41      0  1.17   200
# 027410  16528  15.43  0.23    247  2.89   110
# 282330  55724  11.72  2.36  11203  3.12  4100
# 138930  30468   2.97  0.23   2404  8.75   625

# %%
df["BPS"].value_counts()
# Out:
# BPS
# 0          28
# 416335     13
# 112952     12
# 39406      12
# 37528      12
# 35342      12
# 1156530    12
# 1016129    12
# 953266     12
# 848999     12
# 688251     12
# 573668     12
# 623257     12
# 508420     12
# 355355     12
# 302817     12
# 223844     12
# 182655     12
# 158691     12
# 457368     11
# 28126      11
# 43611      11
# 1406276     1
# Name: count, dtype: int64

# %%
#frequency 파라미터(d/m/y)를 추가
df = stock.get_market_fundamental_by_date("20200101", "20200430", "005930", freq="m")
print(df.head(2))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from pykrx import stock
import pandas as pd

# 코스피(KOSPI) 종목 코드 가져오기
try:
    kospi_codes = stock.get_index_portfolio_deposit_file("1028")
except IndexError:
    kospi_codes = []

# 각 종목에 대해 월별 시장 기초 정보 가져오기
for code in kospi_codes:
    # 재무 데이터 가져오기 (2020년 1월 1일부터 2020년 4월 30일까지)
    df = stock.get_market_fundamental_by_date("20230101", "20231231", code, freq="m")
    # 가져온 데이터에 종목 코드 추가
    df['종목코드'] = code
    # 가져온 데이터가 비어 있지 않으면 리스트에 추가
    if not df.empty:
        kospi_codes.append(df)

# 모든 종목의 데이터를 하나의 DataFrame으로 병합
result = pd.concat(kospi_codes)
print(result.tail(30))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 21
#      18         kospi_codes.append(df)
#      20 # 모든 종목의 데이터를 하나의 DataFrame으로 병합
# ---> 21 result = pd.concat(kospi_codes)
#      22 print(result.tail(30))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
# ...

# %%
from pykrx import stock
import pandas as pd

# 코스피(KOSPI) 종목 코드 가져오기
try:
    kospi_codes = stock.get_index_portfolio_deposit_file("1028")
except IndexError:
    kospi_codes = []

# 각 종목에 대해 종목 코드 리스트 구성
codes_list = []
for code in kospi_codes:
    codes_list.append(code)

# 각 종목에 대해 월별 시장 기초 정보 가져오기
dfs = []
for code in codes_list:
    try:
        df = stock.get_market_fundamental_by_date("20230101", "20230430", code, freq="m")
        dfs.append(df)
        print("Code:", code)
        print(df)
        # 여기에 원하는 작업을 수행하세요
    except Exception as e:
        print(f"Error fetching data for {code}: {e}")

# 모든 종목의 데이터를 하나의 DataFrame으로 병합
result = pd.concat(dfs)
print(result.tail(30))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 28
#      25         print(f"Error fetching data for {code}: {e}")
#      27 # 모든 종목의 데이터를 하나의 DataFrame으로 병합
# ---> 28 result = pd.concat(dfs)
#      29 print(result.tail(30))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
# ...

# %%
from pykrx import stock
import pandas as pd

# 코스피(KOSPI) 종목 코드 가져오기
try:
    kospi_codes = stock.get_index_portfolio_deposit_file("1028")
except IndexError:
    kospi_codes = []

# 각 종목에 대해 종목 코드 리스트 구성
codes_list = []
for code in kospi_codes:
    codes_list.append(code)

# 각 종목에 대해 월별 시장 기초 정보 가져오기
dfs = []
for code in codes_list:
    try:
        df = stock.get_market_fundamental_by_date("20200101", "20200430", code, freq="m")
        if not df.empty:  # 데이터프레임이 비어 있지 않은 경우에만 추가
            dfs.append(df)
            print("Code:", code)
            print(df)
            # 여기에 원하는 작업을 수행하세요
    except Exception as e:
        print(f"Error fetching data for {code}: {e}")

# 모든 종목의 데이터가 있는 경우에만 하나의 DataFrame으로 병합
if dfs:
    result = pd.concat(dfs)
    print(result.tail(30))
else:
    print("No data available for concatenation.")
# Out:
# No data available for concatenation.
