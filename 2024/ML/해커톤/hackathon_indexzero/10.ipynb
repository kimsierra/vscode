# %%
from pykrx import stock
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
df1 = pd.read_csv("하이닉스 다항.csv", encoding='cp949')

X = df1.drop(['날짜','target'], axis=1)
y = df1['target']

# Calculating correlations for Forward Selection
correlations = X.corrwith(y).abs().sort_values(ascending=False).reset_index()
correlations.columns = ['Feature', 'Correlation']

# Performing T-tests
t_tests = {column: ttest_ind(X[column][y == 1], X[column][y == -1], nan_policy='omit') for column in X.columns}
t_tests_sorted = sorted(t_tests.items(), key=lambda x: x[1].pvalue)
t_tests_df = pd.DataFrame(t_tests_sorted, columns=['Feature', 'T-test'])
t_tests_df['T-test'] = t_tests_df['T-test'].apply(lambda x: x.pvalue)  # Only keep p-value for simplicity

# Lasso and Ridge regression
lasso = LassoCV().fit(X, y)
ridge = RidgeCV().fit(X, y)

lasso_importance = np.abs(lasso.coef_)
ridge_importance = np.abs(ridge.coef_)

features_lasso_sorted = sorted(zip(X.columns, lasso_importance), key=lambda x: x[1], reverse=True)
features_ridge_sorted = sorted(zip(X.columns, ridge_importance), key=lambda x: x[1], reverse=True)

features_lasso_df = pd.DataFrame(features_lasso_sorted, columns=['Feature', 'Lasso Importance'])
features_ridge_df = pd.DataFrame(features_ridge_sorted, columns=['Feature', 'Ridge Importance'])

# Random Forest for feature importance
rf = RandomForestRegressor()
rf.fit(X, y)

features_rf_sorted = sorted(zip(X.columns, rf.feature_importances_), key=lambda x: x[1], reverse=True)
features_rf_df = pd.DataFrame(features_rf_sorted, columns=['Feature', 'RF Importance'])

# Combining all the data into a single dataframe without merging by feature
final_df = pd.concat([correlations, t_tests_df.drop('Feature', axis=1), features_lasso_df.drop('Feature', axis=1), 
                      features_ridge_df.drop('Feature', axis=1), features_rf_df.drop('Feature', axis=1)], axis=1)

csv_file_path = "C:/apps/h1/1_하이닉스_importance_data.csv"  # 저장할 파일 경로 및 이름 설정
final_df.to_csv(csv_file_path, encoding='cp949')
# Out:
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0172803510672566, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.431425036632618, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.28151056673687, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.550887174489162, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.634353412789551, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.660044366363536, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.667673062642507, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.669441238562513, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.669131312158015, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.667955010599599, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.6663339236074535, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.664441379101163, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.662368029444224, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.660173128248516, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.657900994134479, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.655586791471478, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.653258974467235, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.650940610306179, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.648650280019638, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.6464028017560395, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.644209812228837, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.642080272676594, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.640020889615016, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.638036498550036, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.63613034596915, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.634304399073471, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.632559532514051, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.6308957432206626, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.629312340698334, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.627808029651078, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3014902859208632, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.791948513001898, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.264132176528165, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.404115863556399, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.445162731964729, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.4571207976307505, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.46033458351144, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.460254075713237, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.457179793782643, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.455337044667203, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.453697256002215, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.452003789220498, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.4502149678428395, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.448345395735032, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.44642126375561, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.4444681932341155, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.442508352896766, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.44056008903749, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.4386382847706045, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.436754805540431, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.434918938690771, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.43313780855874, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.431416716543026, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.429759426236842, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.428168438514831, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.426645197262815, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.4251902795388105, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.423803548540036, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.422484306498973, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.421231384532803, tolerance: 0.19666293848500246
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5684117395358044, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.560975329210578, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.2015909087292584, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.379837202884119, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.429035484918131, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.443064277027133, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.447096330332897, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.4478903224455735, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.447336391273893, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.446030475258112, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.444214112186273, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.44202268980689, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.439552308710745, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.436878917609647, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.434064737708695, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.431161175892385, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.42821062691587, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.42524787398861, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.422301234055112, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.419393532145932, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.416542939763303, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.4137636922059755, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.411066710153364, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.408460135743553, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.405949776006764, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.403539492157961, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.40123154956359, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.399026869836462, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.396925303988382, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.394925833628349, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.3930267162163545, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.391225687521455, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.3895200142844715, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.387906667929201, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.386382383220962, tolerance: 0.1966987290289782
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21241645244435858, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.2922282640006415, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.39339831785287, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19.88081409388292, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22.103089629781607, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.16534665708855, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.6659134503534, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.9000915220322, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.008997223083725, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.059189166420992, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.081887569914898, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.09170622919237, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.095484195168638, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.096425873637372, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.096036858357365, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.095028212806255, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.093738634860756, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.0923317989907, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.09088850440571, tolerance: 0.196699542450432
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.85108606491508, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.6336294605500825, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.962025396064519, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.878815262041371, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.222458348634746, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.349456050712206, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.395961025948509, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.4124306496376, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.41743692579189, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.417851500280676, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.416265366357948, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.413698067414089, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.410585522271276, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.407140884190767, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.403487212837717, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.399706992964639, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.395861278756684, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.391997649923724, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.388153919809838, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.384360272254526, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.380640620385066, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.377013652996766, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.373493723488536, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.370091526533542, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.366814673005138, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.363668270754943, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.360655296296272, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.357777006643573, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.355033228462844, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.352422625159761, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.349942997183234, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.347591336932737, tolerance: 0.1967997967479674
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.415e+02, tolerance: 2.459e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
from pykrx import stock
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
df1 = pd.read_csv("하이닉스 다항.csv", encoding='cp949')

X = df1.drop(['날짜','target'], axis=1)
y = df1['target']
results_list = []
# Calculating correlations for Forward Selection
correlations = X.corrwith(y).abs().sort_values(ascending=False).reset_index()
correlations.columns = ['Feature', 'Correlation']

# # Performing T-tests
# t_tests = {column: ttest_ind(X[column][y == 1], X[column][y == -1], nan_policy='omit') for column in X.columns}
# t_tests_sorted = sorted(t_tests.items(), key=lambda x: x[1].pvalue)
# t_tests_df = pd.DataFrame(t_tests_sorted, columns=['Feature', 'T-test'])
# t_tests_df['T-test'] = t_tests_df['T-test'].apply(lambda x: x.pvalue)  # Only keep p-value for simplicity

# # Lasso and Ridge regression
# lasso = LassoCV().fit(X, y)
# ridge = RidgeCV().fit(X, y)

# lasso_importance = np.abs(lasso.coef_)
# ridge_importance = np.abs(ridge.coef_)

# features_lasso_sorted = sorted(zip(X.columns, lasso_importance), key=lambda x: x[1], reverse=True)
# features_ridge_sorted = sorted(zip(X.columns, ridge_importance), key=lambda x: x[1], reverse=True)

# features_lasso_df = pd.DataFrame(features_lasso_sorted, columns=['Feature', 'Lasso Importance'])
# features_ridge_df = pd.DataFrame(features_ridge_sorted, columns=['Feature', 'Ridge Importance'])

# Random Forest for feature importance
# rf = RandomForestRegressor()
# rf.fit(X, y)

# features_rf_sorted = sorted(zip(X.columns, rf.feature_importances_), key=lambda x: x[1], reverse=True)
# features_rf_df = pd.DataFrame(features_rf_sorted, columns=['Feature', 'RF Importance'])

# # Combining all the data into a single dataframe without merging by feature
# final_df = pd.concat([correlations, t_tests_df.drop('Feature', axis=1), features_lasso_df.drop('Feature', axis=1), 
#                       features_ridge_df.drop('Feature', axis=1), features_rf_df.drop('Feature', axis=1)], axis=1)

# csv_file_path = "C:/apps/h1/1_하이닉스_importance_data.csv"  # 저장할 파일 경로 및 이름 설정

# final_df.to_csv(csv_file_path, encoding='cp949')
correlations = X.corrwith(y).abs().sort_values(ascending=False).reset_index()
correlations.columns = ['Feature', 'Correlation']

top_8_features = correlations.sort_values(by='Correlation', ascending=False).head(8)['Feature']

        # X와 y 정의 (df2와 이전 코드에서의 처리 과정을 바탕으로)
X_top8 = X[top_8_features]
y = df1['target']  # y 값을 0과 1로 조정

        # 데이터를 학습 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X_top8, y, test_size=0.25, random_state=42)

        # 모델 초기화
rf_model = RandomForestClassifier()
dt_model = DecisionTreeClassifier()
lr_model = LogisticRegression()
svm_model = SVC()

        # 모델 학습
rf_model.fit(X_train, y_train)
dt_model.fit(X_train, y_train)
lr_model.fit(X_train, y_train)
svm_model.fit(X_train, y_train)

        # 예측
y_pred_rf = rf_model.predict(X_test)
y_pred_dt = dt_model.predict(X_test)
y_pred_lr = lr_model.predict(X_test)
y_pred_svm = svm_model.predict(X_test)

        # Precision 계산
precision_rf = precision_score(y_test, y_pred_rf, average='macro')
precision_dt = precision_score(y_test, y_pred_dt, average='macro')
precision_lr = precision_score(y_test, y_pred_lr, average='macro')
precision_svm = precision_score(y_test, y_pred_svm, average='macro')

        # 결과 저장
results_list.append({
    'Precision_RF': precision_rf,
    'Precision_DT': precision_dt,
    'Precision_LR': precision_lr,
    'Precision_SVM': precision_svm
    })

# %%
results_df = pd.DataFrame(results_list).sort_values(by='Precision_SVM', ascending=False)

# %%
csv_file_path = "C:/apps/h1/2하이닉스_precision score_data.csv"  # 저장할 파일 경로 및 이름 설정
results_df.to_csv(csv_file_path, encoding='utf-8-sig')

# %%
from pykrx import stock
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

df1 = pd.read_csv("하이닉스 임시.csv", encoding='cp949')

X = df1.drop(['날짜','target'], axis=1)
y = df1['target']

# Calculating correlations for Forward Selection
correlations = X.corrwith(y).abs().sort_values(ascending=False).reset_index()
correlations.columns = ['Feature', 'Correlation']

# 상관관계가 가장 높은 상위 8개의 피처를 선정
top_8_features = correlations.sort_values(by='Correlation', ascending=False).head(8)['Feature']

# X와 y 정의 (df2와 이전 코드에서의 처리 과정을 바탕으로)
X_top8 = X[top_8_features]
y = df1['target'].map({-1: 0, 1: 1})  # y 값을 0과 1로 조정

# 데이터를 학습 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X_top8, y, test_size=0.3, random_state=42)

# 모델 초기화
models = {
    'SVC': SVC(),
    'LogisticRegression': LogisticRegression(),
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'RandomForestClassifier': RandomForestClassifier()
}

# 점수를 저장할 딕셔너리
scores = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1_Score': []
}

# 각 모델에 대해 학습 및 평가
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    scores['Model'].append(model_name)
    scores['Accuracy'].append(accuracy_score(y_test, y_pred))
    scores['Precision'].append(precision_score(y_test, y_pred, average='macro'))
    scores['Recall'].append(recall_score(y_test, y_pred, average='macro'))
    scores['F1_Score'].append(f1_score(y_test, y_pred, average='macro'))

# 점수 딕셔너리를 데이터프레임으로 변환
scores_df = pd.DataFrame(scores)
scores_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 20
#      17 y = df1['target']
#      19 # Calculating correlations for Forward Selection
# ---> 20 correlations = X.corrwith(y).abs().sort_values(ascending=False).reset_index()
#      21 correlations.columns = ['Feature', 'Correlation']
#      23 # 상관관계가 가장 높은 상위 8개의 피처를 선정
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\frame.py:10301, in DataFrame.corrwith(self, other, axis, drop, method, numeric_only)
#   10298 this = self._get_numeric_data() if numeric_only else self
#   10300 if isinstance(other, Series):
# > 10301     return this.apply(lambda x: other.corr(x, method=method), axis=axis)
#   10303 if numeric_only:
#   10304     other = other._get_numeric_data()
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\frame.py:10301, in DataFrame.corrwith.<locals>.<lambda>(x)
#   10298 this = self._get_numeric_data() if numeric_only else self
#   10300 if isinstance(other, Series):
# > 10301     return this.apply(lambda x: other.corr(x, method=method), axis=axis)
#   10303 if numeric_only:
#   10304     other = other._get_numeric_data()
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\series.py:2727, in Series.corr(self, other, method, min_periods)
#    2724     return np.nan
#    2726 if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2727     return nanops.nancorr(
#    2728         this.values, other.values, method=method, min_periods=min_periods
#    2729     )
#    2731 raise ValueError(
#    2732     "method must be either 'pearson', "
#    2733     "'spearman', 'kendall', or a callable, "
#    2734     f"'{method}' was supplied"
#    2735 )
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\nanops.py:1614, in nancorr(a, b, method, min_periods)
#    1611     return np.nan
#    1613 f = get_corr_func(method)
# -> 1614 return f(a, b)
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\pandas\core\nanops.py:1637, in get_corr_func.<locals>.func(a, b)
#    1636 def func(a, b):
# -> 1637     return np.corrcoef(a, b)[0, 1]
#
# File <__array_function__ internals>:200, in corrcoef(*args, **kwargs)
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2846, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2842 if bias is not np._NoValue or ddof is not np._NoValue:
#    2843     # 2015-03-15, 1.10
#    2844     warnings.warn('bias and ddof have no effect and are deprecated',
#    2845                   DeprecationWarning, stacklevel=3)
# -> 2846 c = cov(x, y, rowvar, dtype=dtype)
#    2847 try:
#    2848     d = diag(c)
#
# File <__array_function__ internals>:200, in cov(*args, **kwargs)
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2681, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2678     else:
#    2679         w *= aweights
# -> 2681 avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2682 w_sum = w_sum[0]
#    2684 # Determine the normalization
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\numpy\lib\function_base.py:518, in average(a, axis, weights, returned, keepdims)
#     515     keepdims_kw = {'keepdims': keepdims}
#     517 if weights is None:
# --> 518     avg = a.mean(axis, **keepdims_kw)
#     519     avg_as_array = np.asanyarray(avg)
#     520     scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
#
# File c:\Users\yeotaekyeong\anaconda3\Lib\site-packages\numpy\core\_methods.py:184, in _mean(a, axis, dtype, out, keepdims, where)
#     182 if isinstance(ret, mu.ndarray):
#     183     with _no_nep50_warning():
# --> 184         ret = um.true_divide(
#     185                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     186     if is_float16_result and out is None:
#     187         ret = arr.dtype.type(ret)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
