# %%
import pandas as pd
import time
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_2656\1582058754.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('C:/Users/SAMSUNG/Documents/vscode/2024/ML/해커톤/CSV/20년배당성향.자본2.csv',encoding='cp949')
df
# Out:
#             회사명  거래소코드     회계년도   배당성향  자본(*)(IFRS연결)(천원)  자본(*)(IFRS)(천원)
# 0      (주)DB하이텍    990  2000/12  22.00                NaN              NaN
# 1      (주)DB하이텍    990  2001/12  20.00                NaN              NaN
# 2      (주)DB하이텍    990  2002/12  29.36                NaN              NaN
# 3      (주)DB하이텍    990  2003/12  36.68                NaN              NaN
# 4      (주)DB하이텍    990  2004/12  11.68                NaN              NaN
# ...         ...    ...      ...    ...                ...              ...
# 16264   흥아해운(주)   3280  2019/12   0.00         30919383.0       17632229.0
# 16265   흥아해운(주)   3280  2020/12   0.00        -26283865.0      -20161176.0
# 16266   흥아해운(주)   3280  2021/12   0.00        102939788.0      108146996.0
# 16267   흥아해운(주)   3280  2022/12   0.00        135304736.0      128025089.0
# 16268   흥아해운(주)   3280  2023/12    NaN        170714206.0      150901297.0
#
# [16269 rows x 6 columns]

# %%
df = pd.read_csv('./CSV/20년배당성향.자본2.csv',encoding='cp949')
df
# Out:
#             회사명  거래소코드     회계년도   배당성향  자본(*)(IFRS연결)(천원)  자본(*)(IFRS)(천원)
# 0      (주)DB하이텍    990  2000/12  22.00                NaN              NaN
# 1      (주)DB하이텍    990  2001/12  20.00                NaN              NaN
# 2      (주)DB하이텍    990  2002/12  29.36                NaN              NaN
# 3      (주)DB하이텍    990  2003/12  36.68                NaN              NaN
# 4      (주)DB하이텍    990  2004/12  11.68                NaN              NaN
# ...         ...    ...      ...    ...                ...              ...
# 16264   흥아해운(주)   3280  2019/12   0.00         30919383.0       17632229.0
# 16265   흥아해운(주)   3280  2020/12   0.00        -26283865.0      -20161176.0
# 16266   흥아해운(주)   3280  2021/12   0.00        102939788.0      108146996.0
# 16267   흥아해운(주)   3280  2022/12   0.00        135304736.0      128025089.0
# 16268   흥아해운(주)   3280  2023/12    NaN        170714206.0      150901297.0
#
# [16269 rows x 6 columns]

# %%
df_copy = df.copy()
df_copy
# Out:
#             회사명  거래소코드     회계년도   배당성향  자본(*)(IFRS연결)(천원)  자본(*)(IFRS)(천원)
# 0      (주)DB하이텍    990  2000/12  22.00                NaN              NaN
# 1      (주)DB하이텍    990  2001/12  20.00                NaN              NaN
# 2      (주)DB하이텍    990  2002/12  29.36                NaN              NaN
# 3      (주)DB하이텍    990  2003/12  36.68                NaN              NaN
# 4      (주)DB하이텍    990  2004/12  11.68                NaN              NaN
# ...         ...    ...      ...    ...                ...              ...
# 16264   흥아해운(주)   3280  2019/12   0.00         30919383.0       17632229.0
# 16265   흥아해운(주)   3280  2020/12   0.00        -26283865.0      -20161176.0
# 16266   흥아해운(주)   3280  2021/12   0.00        102939788.0      108146996.0
# 16267   흥아해운(주)   3280  2022/12   0.00        135304736.0      128025089.0
# 16268   흥아해운(주)   3280  2023/12    NaN        170714206.0      150901297.0
#
# [16269 rows x 6 columns]

# %%
# NaN 값을 포함하는 행 출력
df_cleaned = df_copy.dropna(subset=['자본(*)(IFRS연결)(천원)', '자본(*)(IFRS)(천원)'], how='all')


# 결과 출력
print("NaN 값을 포함하는 행:")
print(df_cleaned)
# Out:
# NaN 값을 포함하는 행:
#             회사명  거래소코드     회계년도  배당성향  자본(*)(IFRS연결)(천원)  자본(*)(IFRS)(천원)
# 7      (주)DB하이텍    990  2007/12   0.0        835716158.0      884960459.0
# 8      (주)DB하이텍    990  2008/12   0.0        844331741.0      860588250.0
# 9      (주)DB하이텍    990  2009/12   0.0        607545037.0      630803625.0
# 10     (주)DB하이텍    990  2010/12   0.0        398016157.0      376915607.0
# 11     (주)DB하이텍    990  2011/12   0.0        308061688.0      291709498.0
# ...         ...    ...      ...   ...                ...              ...
# 16264   흥아해운(주)   3280  2019/12   0.0         30919383.0       17632229.0
# 16265   흥아해운(주)   3280  2020/12   0.0        -26283865.0      -20161176.0
# 16266   흥아해운(주)   3280  2021/12   0.0        102939788.0      108146996.0
# 16267   흥아해운(주)   3280  2022/12   0.0        135304736.0      128025089.0
# 16268   흥아해운(주)   3280  2023/12   NaN        170714206.0      150901297.0
#
# [11670 rows x 6 columns]

# %%
df1 = df_cleaned[df_cleaned[['자본(*)(IFRS연결)(천원)']].isna().any(axis=1)]

df1.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '배당성향', '자본(*)(IFRS연결)(천원)', '자본(*)(IFRS)(천원)'], dtype='object')

# %%
df1['자본(*)(IFRS연결)(천원)'] = df1['자본(*)(IFRS)(천원)']
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_2656\636133457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['자본(*)(IFRS연결)(천원)'] = df1['자본(*)(IFRS)(천원)']

# %%
df_cleaned.iloc[np.where(df_cleaned['자본(*)(IFRS연결)(천원)'].isna())]['자본(*)(IFRS연결)(천원)'] = df1['자본(*)(IFRS연결)(천원)']
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_2656\661213262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.iloc[np.where(df_cleaned['자본(*)(IFRS연결)(천원)'].isna())]['자본(*)(IFRS연결)(천원)'] = df1['자본(*)(IFRS연결)(천원)']

# %%
df_cleaned.isna().sum()
# Out:
# 회사명                     0
# 거래소코드                   0
# 회계년도                    0
# 배당성향                 1091
# 자본(*)(IFRS연결)(천원)    2273
# 자본(*)(IFRS)(천원)        14
# dtype: int64

# %%
# '자본(*)(IFRS연결)(천원)' 열의 NaN 값을 '자본(*)(IFRS)(천원)' 열의 값으로 대체
df_cleaned['자본(*)(IFRS연결)(천원)'].fillna(df_cleaned['자본(*)(IFRS)(천원)'], inplace=True)

# 결과 출력
print(df_cleaned)
# Out:
#             회사명  거래소코드     회계년도  배당성향  자본(*)(IFRS연결)(천원)  자본(*)(IFRS)(천원)
# 7      (주)DB하이텍    990  2007/12   0.0        835716158.0      884960459.0
# 8      (주)DB하이텍    990  2008/12   0.0        844331741.0      860588250.0
# 9      (주)DB하이텍    990  2009/12   0.0        607545037.0      630803625.0
# 10     (주)DB하이텍    990  2010/12   0.0        398016157.0      376915607.0
# 11     (주)DB하이텍    990  2011/12   0.0        308061688.0      291709498.0
# ...         ...    ...      ...   ...                ...              ...
# 16264   흥아해운(주)   3280  2019/12   0.0         30919383.0       17632229.0
# 16265   흥아해운(주)   3280  2020/12   0.0        -26283865.0      -20161176.0
# 16266   흥아해운(주)   3280  2021/12   0.0        102939788.0      108146996.0
# 16267   흥아해운(주)   3280  2022/12   0.0        135304736.0      128025089.0
# 16268   흥아해운(주)   3280  2023/12   NaN        170714206.0      150901297.0
#
# [11670 rows x 6 columns]
# ...

# %%
df_cleaned.isna().sum()
# Out:
# 회사명                     0
# 거래소코드                   0
# 회계년도                    0
# 배당성향                 1091
# 자본(*)(IFRS연결)(천원)       0
# 자본(*)(IFRS)(천원)        14
# dtype: int64

# %%
df_cleaned2 = df_cleaned.drop(columns=['자본(*)(IFRS)(천원)'])
df_cleaned2
# Out:
#             회사명  거래소코드     회계년도  배당성향  자본(*)(IFRS연결)(천원)
# 7      (주)DB하이텍    990  2007/12   0.0        835716158.0
# 8      (주)DB하이텍    990  2008/12   0.0        844331741.0
# 9      (주)DB하이텍    990  2009/12   0.0        607545037.0
# 10     (주)DB하이텍    990  2010/12   0.0        398016157.0
# 11     (주)DB하이텍    990  2011/12   0.0        308061688.0
# ...         ...    ...      ...   ...                ...
# 16264   흥아해운(주)   3280  2019/12   0.0         30919383.0
# 16265   흥아해운(주)   3280  2020/12   0.0        -26283865.0
# 16266   흥아해운(주)   3280  2021/12   0.0        102939788.0
# 16267   흥아해운(주)   3280  2022/12   0.0        135304736.0
# 16268   흥아해운(주)   3280  2023/12   NaN        170714206.0
#
# [11670 rows x 5 columns]

# %%
df_cleaned2.reset_index(inplace=True,drop=True)
df_cleaned2
# Out:
#             회사명   거래소코드     회계년도  배당성향  자본(*)(IFRS연결)(천원)
# 0      (주)DB하이텍  000990  2007/12   0.0        835716158.0
# 1      (주)DB하이텍  000990  2008/12   0.0        844331741.0
# 2      (주)DB하이텍  000990  2009/12   0.0        607545037.0
# 3      (주)DB하이텍  000990  2010/12   0.0        398016157.0
# 4      (주)DB하이텍  000990  2011/12   0.0        308061688.0
# ...         ...     ...      ...   ...                ...
# 11665   흥아해운(주)  003280  2019/12   0.0         30919383.0
# 11666   흥아해운(주)  003280  2020/12   0.0        -26283865.0
# 11667   흥아해운(주)  003280  2021/12   0.0        102939788.0
# 11668   흥아해운(주)  003280  2022/12   0.0        135304736.0
# 11669   흥아해운(주)  003280  2023/12   NaN        170714206.0
#
# [11670 rows x 5 columns]

# %%
df_cleaned2["회계년도"] =pd.to_datetime(df_cleaned2["회계년도"])
df_cleaned2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11670 entries, 0 to 11669
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   회사명                11670 non-null  object
#  1   거래소코드              11670 non-null  object
#  2   회계년도               11670 non-null  datetime64[ns]
#  3   배당성향               10579 non-null  float64
#  4   자본(*)(IFRS연결)(천원)  11670 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 456.0+ KB
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_2656\3030863818.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_cleaned2["회계년도"] =pd.to_datetime(df_cleaned2["회계년도"])

# %%
import datetime as dt
df_cleaned2["회계년도"].dt.year
# Out:
# 0        2007
# 1        2008
# 2        2009
# 3        2010
# 4        2011
#          ...
# 11665    2019
# 11666    2020
# 11667    2021
# 11668    2022
# 11669    2023
# Name: 회계년도, Length: 11670, dtype: int32

# %%
df_cleaned2["회계년"]= df_cleaned2["회계년도"].dt.year
df_cleaned2
# Out:
#             회사명   거래소코드       회계년도  배당성향  자본(*)(IFRS연결)(천원)   회계년
# 0      (주)DB하이텍  000990 2007-12-01   0.0        835716158.0  2007
# 1      (주)DB하이텍  000990 2008-12-01   0.0        844331741.0  2008
# 2      (주)DB하이텍  000990 2009-12-01   0.0        607545037.0  2009
# 3      (주)DB하이텍  000990 2010-12-01   0.0        398016157.0  2010
# 4      (주)DB하이텍  000990 2011-12-01   0.0        308061688.0  2011
# ...         ...     ...        ...   ...                ...   ...
# 11665   흥아해운(주)  003280 2019-12-01   0.0         30919383.0  2019
# 11666   흥아해운(주)  003280 2020-12-01   0.0        -26283865.0  2020
# 11667   흥아해운(주)  003280 2021-12-01   0.0        102939788.0  2021
# 11668   흥아해운(주)  003280 2022-12-01   0.0        135304736.0  2022
# 11669   흥아해운(주)  003280 2023-12-01   NaN        170714206.0  2023
#
# [11670 rows x 6 columns]

# %%
df_cleaned2[df_cleaned2["회계년"] == 2007]
# Out:
#               회사명   거래소코드       회계년도   배당성향  자본(*)(IFRS연결)(천원)   회계년
# 0        (주)DB하이텍  000990 2007-12-01   0.00        835716158.0  2007
# 17       (주)HJ중공업  097230 2007-12-01  74.97        936466000.0  2007
# 33       (주)MH에탄올  023150 2007-12-01  40.36         36597472.0  2007
# 50     (주)SH에너지화학  002360 2007-12-01   0.00         64164020.0  2007
# 67      (주)SIMPAC  009160 2007-12-01  14.22         68929199.0  2007
# ...           ...     ...        ...    ...                ...   ...
# 11561     화천기계(주)  010660 2007-12-01  30.30         73749514.0  2007
# 11578     화천기공(주)  000850 2007-12-01  17.54        142647863.0  2007
# 11595     환인제약(주)  016580 2007-12-01  26.90         95030041.0  2007
# 11612  효성아이티엑스(주)  094280 2007-12-01   0.20         37435929.0  2007
# 11653     흥아해운(주)  003280 2007-12-01   0.00         87795057.0  2007
#
# [591 rows x 6 columns]

# %%
marcap = pd.read_csv("C:/Users/SAMSUNG/Documents/vscode/2024/ML/해커톤/CSV/marcap_2001_2023.csv",index_col=0)
marcap.reset_index(drop=True, inplace=True)
marcap
# Out:
#        종목코드            시가총액    연도    종목명 기업구분
# 0      5930  42220609650000  2001   삼성전자    B
# 1       270   3274633451300  2001     기아    B
# 2      9150   3271583884800  2001   삼성전기    B
# 3      6400   2690720746000  2001  삼성SDI    B
# 4      4170   2065609500000  2001    신세계    B
# ...     ...             ...   ...    ...  ...
# 9233   2870     27617373000  2015     신풍    S
# 9234  10580     22585834200  2015  에스엠벡셀    S
# 9235   1140     19981062800  2015     국보    S
# 9236   2420     19503277200  2015   세기상사    S
# 9237   7280     11950000000  2015   한국특강    S
#
# [9238 rows x 5 columns]

# %%
marcap['종목코드'] = marcap['종목코드'].astype(str).str.zfill(6)
marcap
# Out:
#         종목코드            시가총액    연도    종목명 기업구분
# 0     005930  42220609650000  2001   삼성전자    B
# 1     000270   3274633451300  2001     기아    B
# 2     009150   3271583884800  2001   삼성전기    B
# 3     006400   2690720746000  2001  삼성SDI    B
# 4     004170   2065609500000  2001    신세계    B
# ...      ...             ...   ...    ...  ...
# 9233  002870     27617373000  2015     신풍    S
# 9234  010580     22585834200  2015  에스엠벡셀    S
# 9235  001140     19981062800  2015     국보    S
# 9236  002420     19503277200  2015   세기상사    S
# 9237  007280     11950000000  2015   한국특강    S
#
# [9238 rows x 5 columns]

# %%
marcap.columns
# Out:
# Index(['종목코드', '시가총액', '연도', '종목명', '기업구분'], dtype='object')

# %%
marcap.columns =['거래소코드', '시가총액', '회계년', '종목명', '기업구분']

# %%
marcap
# Out:
#        거래소코드            시가총액   회계년    종목명 기업구분
# 0     005930  42220609650000  2001   삼성전자    B
# 1     000270   3274633451300  2001     기아    B
# 2     009150   3271583884800  2001   삼성전기    B
# 3     006400   2690720746000  2001  삼성SDI    B
# 4     004170   2065609500000  2001    신세계    B
# ...      ...             ...   ...    ...  ...
# 9233  002870     27617373000  2015     신풍    S
# 9234  010580     22585834200  2015  에스엠벡셀    S
# 9235  001140     19981062800  2015     국보    S
# 9236  002420     19503277200  2015   세기상사    S
# 9237  007280     11950000000  2015   한국특강    S
#
# [9238 rows x 5 columns]

# %%
df_cleaned2
# Out:
#             회사명   거래소코드       회계년도  배당성향  자본(*)(IFRS연결)(천원)   회계년
# 0      (주)DB하이텍  000990 2007-12-01   0.0        835716158.0  2007
# 1      (주)DB하이텍  000990 2008-12-01   0.0        844331741.0  2008
# 2      (주)DB하이텍  000990 2009-12-01   0.0        607545037.0  2009
# 3      (주)DB하이텍  000990 2010-12-01   0.0        398016157.0  2010
# 4      (주)DB하이텍  000990 2011-12-01   0.0        308061688.0  2011
# ...         ...     ...        ...   ...                ...   ...
# 11665   흥아해운(주)  003280 2019-12-01   0.0         30919383.0  2019
# 11666   흥아해운(주)  003280 2020-12-01   0.0        -26283865.0  2020
# 11667   흥아해운(주)  003280 2021-12-01   0.0        102939788.0  2021
# 11668   흥아해운(주)  003280 2022-12-01   0.0        135304736.0  2022
# 11669   흥아해운(주)  003280 2023-12-01   NaN        170714206.0  2023
#
# [11670 rows x 6 columns]

# %%
marcap[marcap.duplicated()]
# Out:
# Empty DataFrame
# Columns: [거래소코드, 시가총액, 회계년, 종목명, 기업구분]
# Index: []

# %%
marcap['거래소코드'] = marcap['거래소코드'].astype(str).str.zfill(6)

# %%
marcap = marcap.drop_duplicates()
marcap.reset_index(drop=True, inplace=True)
marcap
# Out:
#        거래소코드            시가총액   회계년    종목명 기업구분
# 0     005930  42220609650000  2001   삼성전자    B
# 1     000270   3274633451300  2001     기아    B
# 2     009150   3271583884800  2001   삼성전기    B
# 3     006400   2690720746000  2001  삼성SDI    B
# 4     004170   2065609500000  2001    신세계    B
# ...      ...             ...   ...    ...  ...
# 9233  002870     27617373000  2015     신풍    S
# 9234  010580     22585834200  2015  에스엠벡셀    S
# 9235  001140     19981062800  2015     국보    S
# 9236  002420     19503277200  2015   세기상사    S
# 9237  007280     11950000000  2015   한국특강    S
#
# [9238 rows x 5 columns]

# %%
len(marcap["거래소코드"].unique())
# Out:
# 438

# %%
all_data = pd.merge(df_cleaned2,marcap, on=["거래소코드","회계년"],how='left')
all_data
# Out:
#             회사명   거래소코드       회계년도  배당성향  자본(*)(IFRS연결)(천원)   회계년  \
# 0      (주)DB하이텍  000990 2007-12-01   0.0        835716158.0  2007
# 1      (주)DB하이텍  000990 2008-12-01   0.0        844331741.0  2008
# 2      (주)DB하이텍  000990 2009-12-01   0.0        607545037.0  2009
# 3      (주)DB하이텍  000990 2010-12-01   0.0        398016157.0  2010
# 4      (주)DB하이텍  000990 2011-12-01   0.0        308061688.0  2011
# ...         ...     ...        ...   ...                ...   ...
# 11665   흥아해운(주)  003280 2019-12-01   0.0         30919383.0  2019
# 11666   흥아해운(주)  003280 2020-12-01   0.0        -26283865.0  2020
# 11667   흥아해운(주)  003280 2021-12-01   0.0        102939788.0  2021
# 11668   흥아해운(주)  003280 2022-12-01   0.0        135304736.0  2022
# 11669   흥아해운(주)  003280 2023-12-01   NaN        170714206.0  2023
#
#                시가총액    종목명 기업구분
# 0      3.585737e+11  DB하이텍    B
# 1      1.406043e+11  DB하이텍    S
# 2      2.668661e+11  DB하이텍    S
# 3      4.570225e+11  DB하이텍    B
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11670 entries, 0 to 11669
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   회사명                11670 non-null  object
#  1   거래소코드              11670 non-null  object
#  2   회계년도               11670 non-null  datetime64[ns]
#  3   배당성향               10579 non-null  float64
#  4   자본(*)(IFRS연결)(천원)  11670 non-null  float64
#  5   회계년                11670 non-null  int32
#  6   시가총액               7102 non-null   float64
#  7   종목명                7102 non-null   object
#  8   기업구분               7102 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(1), object(4)
# memory usage: 775.1+ KB

# %%
all_data.dropna(subset='시가총액',inplace=True)
all_data
# Out:
#             회사명   거래소코드       회계년도  배당성향  자본(*)(IFRS연결)(천원)   회계년  \
# 0      (주)DB하이텍  000990 2007-12-01   0.0        835716158.0  2007
# 1      (주)DB하이텍  000990 2008-12-01   0.0        844331741.0  2008
# 2      (주)DB하이텍  000990 2009-12-01   0.0        607545037.0  2009
# 3      (주)DB하이텍  000990 2010-12-01   0.0        398016157.0  2010
# 4      (주)DB하이텍  000990 2011-12-01   0.0        308061688.0  2011
# ...         ...     ...        ...   ...                ...   ...
# 11665   흥아해운(주)  003280 2019-12-01   0.0         30919383.0  2019
# 11666   흥아해운(주)  003280 2020-12-01   0.0        -26283865.0  2020
# 11667   흥아해운(주)  003280 2021-12-01   0.0        102939788.0  2021
# 11668   흥아해운(주)  003280 2022-12-01   0.0        135304736.0  2022
# 11669   흥아해운(주)  003280 2023-12-01   NaN        170714206.0  2023
#
#                시가총액    종목명 기업구분
# 0      3.585737e+11  DB하이텍    B
# 1      1.406043e+11  DB하이텍    S
# 2      2.668661e+11  DB하이텍    S
# 3      4.570225e+11  DB하이텍    B
# ...

# %%
all_data[all_data["회계년"]==2007]
# Out:
#               회사명   거래소코드       회계년도   배당성향  자본(*)(IFRS연결)(천원)   회계년  \
# 0        (주)DB하이텍  000990 2007-12-01   0.00        835716158.0  2007
# 17       (주)HJ중공업  097230 2007-12-01  74.97        936466000.0  2007
# 33       (주)MH에탄올  023150 2007-12-01  40.36         36597472.0  2007
# 50     (주)SH에너지화학  002360 2007-12-01   0.00         64164020.0  2007
# 67      (주)SIMPAC  009160 2007-12-01  14.22         68929199.0  2007
# ...           ...     ...        ...    ...                ...   ...
# 11544     화성산업(주)  002460 2007-12-01  15.10        350177646.0  2007
# 11561     화천기계(주)  010660 2007-12-01  30.30         73749514.0  2007
# 11578     화천기공(주)  000850 2007-12-01  17.54        142647863.0  2007
# 11595     환인제약(주)  016580 2007-12-01  26.90         95030041.0  2007
# 11653     흥아해운(주)  003280 2007-12-01   0.00         87795057.0  2007
#
#                시가총액      종목명 기업구분
# 0      3.585737e+11    DB하이텍    B
# 17     3.261542e+12    HJ중공업    B
# ...

# %%
all_data[all_data["회계년"]==2021]
# Out:
#               회사명   거래소코드       회계년도    배당성향  자본(*)(IFRS연결)(천원)   회계년  \
# 14       (주)DB하이텍  000990 2021-12-01    6.17       1.106050e+09  2021
# 31       (주)HJ중공업  097230 2021-12-01    0.00       4.320050e+08  2021
# 47       (주)MH에탄올  023150 2021-12-01   46.13       8.470334e+07  2021
# 64     (주)SH에너지화학  002360 2021-12-01  145.60       9.173910e+07  2021
# 81      (주)SIMPAC  009160 2021-12-01   17.11       5.466623e+08  2021
# ...           ...     ...        ...     ...                ...   ...
# 11558     화성산업(주)  002460 2021-12-01   40.54       4.169809e+08  2021
# 11575     화천기계(주)  010660 2021-12-01    3.68       1.258116e+08  2021
# 11592     화천기공(주)  000850 2021-12-01   30.55       3.083491e+08  2021
# 11609     환인제약(주)  016580 2021-12-01   17.38       3.172257e+08  2021
# 11667     흥아해운(주)  003280 2021-12-01    0.00       1.029398e+08  2021
#
#                시가총액      종목명 기업구분
# 14     3.227777e+12    DB하이텍    B
# 31     6.695252e+11    HJ중공업    S
# ...

# %%
all_data["PBR"] = all_data["시가총액"]/(all_data["자본(*)(IFRS연결)(천원)"]*1000)

# %%
all_data
# Out:
#             회사명   거래소코드       회계년도  배당성향  자본(*)(IFRS연결)(천원)   회계년  \
# 0      (주)DB하이텍  000990 2007-12-01   0.0        835716158.0  2007
# 1      (주)DB하이텍  000990 2008-12-01   0.0        844331741.0  2008
# 2      (주)DB하이텍  000990 2009-12-01   0.0        607545037.0  2009
# 3      (주)DB하이텍  000990 2010-12-01   0.0        398016157.0  2010
# 4      (주)DB하이텍  000990 2011-12-01   0.0        308061688.0  2011
# ...         ...     ...        ...   ...                ...   ...
# 11665   흥아해운(주)  003280 2019-12-01   0.0         30919383.0  2019
# 11666   흥아해운(주)  003280 2020-12-01   0.0        -26283865.0  2020
# 11667   흥아해운(주)  003280 2021-12-01   0.0        102939788.0  2021
# 11668   흥아해운(주)  003280 2022-12-01   0.0        135304736.0  2022
# 11669   흥아해운(주)  003280 2023-12-01   NaN        170714206.0  2023
#
#                시가총액    종목명 기업구분       PBR
# 0      3.585737e+11  DB하이텍    B  0.429062
# 1      1.406043e+11  DB하이텍    S  0.166527
# 2      2.668661e+11  DB하이텍    S  0.439253
# ...

# %%
all_data.to_csv("./real_data.csv",index=0)

# %%
marcap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9220 entries, 0 to 9219
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종목코드    9220 non-null   object
#  1   시가총액    9220 non-null   int64
#  2   연도      9220 non-null   int64
#  3   종목명     9220 non-null   object
#  4   기업구분    9220 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 360.3+ KB

# %%
df_cleaned2['거래소코드'] = df_cleaned2['거래소코드'].astype(str).str.zfill(6)
df_cleaned2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11670 entries, 0 to 11669
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   회사명                11670 non-null  object
#  1   거래소코드              11670 non-null  object
#  2   회계년도               11670 non-null  datetime64[ns]
#  3   배당성향               10579 non-null  float64
#  4   자본(*)(IFRS연결)(천원)  11670 non-null  float64
#  5   회계년                11670 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), object(2)
# memory usage: 501.6+ KB

# %%
df['거래소코드'] = df['거래소코드'].astype(str).str.zfill(6)

# %%
# '회계년도'를 기준으로 데이터프레임을 년도별로 묶기
grouped_df = df_cleaned2.groupby('회계년도')

# 년도별로 묶인 데이터프레임 출력
for year, group_df in grouped_df:
    print(f"Year: {year}")
    print(group_df)
    print("\n")
# Out:
# Year: 2007/03
#                 회사명   거래소코드     회계년도   배당성향  자본(*)(IFRS연결)(천원)
# 895        (주)대구백화점  006370  2007/03  17.71        274161449.0
# 1014          (주)대웅  003090  2007/03  10.29        294162854.0
# 1035        (주)대웅제약  069620  2007/03  15.04        212492941.0
# 2198        (주)사조대림  003960  2007/03   0.00         34448239.0
# 2222        (주)사조오양  006090  2007/03   0.00          9996810.0
# 4250     (주)오리엔트바이오  002630  2007/03   0.00         44862350.0
# 4682        (주)유유제약  000220  2007/03  18.48         63299681.0
# 7921        국제약품(주)  002720  2007/03  18.81         54695397.0
# 8123        기신정기(주)  092440  2007/03  25.80         95210527.0
# 8403        대동전자(주)  008110  2007/03   0.00         82795504.0
# 8807        대한제강(주)  084010  2007/03  11.00        195610575.0
# 9113        동원금속(주)  018500  2007/03  52.45         30614189.0
# 9269        동화약품(주)  000020  2007/03  41.56        160998236.0
# 10043       부광약품(주)  003000  2007/03  36.41        124179521.0
# ...
